# %%
# Clone your GitHub repo (you’ll be prompted to authorize if it's private)
# !git clone https://github.com/colterwood/LHL-final-final-project.git
# Out:
# Cloning into 'LHL-final-final-project'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 91 (delta 43), reused 20 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (91/91), 1.14 MiB | 1.06 MiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
from io import StringIO
import numpy as np

# %%
# List of team codes for 2024 season
teams = ['ATL', 'CHI', 'CON', 'DAL', 'IND', 'LAS', 'MIN', 'NYL', 'PHO', 'SEA', 'WAS', 'LVA']

# Base URL pattern for advanced game logs
base_url = "https://www.basketball-reference.com/wnba/teams/{team}/2024/gamelog-advanced/"

frames = []

for team in teams:
    url = base_url.format(team=team)
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    table = soup.find("table", id="wnba_tgl_advanced")

    if table is not None:
        df_team = pd.read_html(StringIO(str(table)))[0]

        # Combine multi-level headers
        df_team.columns = [f"{a}_{b}" for a, b in df_team.columns]

        # Add team column as first column
        df_team.insert(0, "Team", team)

        frames.append(df_team)
    else:
        print(f"No advanced table found for {team}")

# Combine into single DataFrame
df = pd.concat(frames, ignore_index=True)

# %%
df.head()
# Out:
#   Team Unnamed: 0_level_0_Rk Unnamed: 1_level_0_Date  \
# 0  ATL                     1              2024-05-15
# 1  ATL                     2              2024-05-18
# 2  ATL                     3              2024-05-21
# 3  ATL                     4              2024-05-26
# 4  ATL                     5              2024-05-29
#
#   Unnamed: 2_level_0_Unnamed: 2_level_1 Unnamed: 3_level_0_Opp  \
# 0                                     @                    LAS
# 1                                     @                    PHO
# 2                                   NaN                    DAL
# 3                                   NaN                    MIN
# 4                                     @                    WAS
#
#   Unnamed: 4_level_0_W/L Unnamed: 5_level_0_Tm Unnamed: 6_level_0_Opp  \
# 0                      W                    92                     81
# 1                      L                    85                     88
# 2                      W                    83                     78
# 3                      L                    79                     92
# 4                      W                    73                     67
#
#    Unnamed: 7_level_0_Unnamed: 7_level_1 Advanced_ORtg  ...  \
# 0                                    NaN         114.0  ...
# 1                                    NaN         103.6  ...
# 2                                    NaN         107.0  ...
# 3                                    NaN         107.0  ...
# 4                                    NaN          92.0  ...
#
#   Unnamed: 18_level_0_Unnamed: 18_level_1 Offensive Four Factors_eFG%  \
# 0                                     NaN                        .567
# 1                                     NaN                        .485
# 2                                     NaN                        .465
# 3                                     NaN                        .500
# 4                                     NaN                        .468
#
#   Offensive Four Factors_TOV% Offensive Four Factors_ORB%  \
# 0                        14.7                        20.6
# 1                        14.3                        18.4
# 2                        12.8                        35.1
# 3                        11.9                        27.8
# 4                        19.3                        18.5
#
#   Offensive Four Factors_FT/FGA Unnamed: 23_level_0_Unnamed: 23_level_1  \
# 0                          .239                                     NaN
# 1                          .318                                     NaN
# 2                          .222                                     NaN
# 3                          .162                                     NaN
# 4                          .242                                     NaN
#
#   Defensive Four Factors_eFG% Defensive Four Factors_TOV%  \
# 0                        .472                        11.9
# 1                        .455                        13.0
# 2                        .443                        15.1
# 3                        .605                        12.2
# 4                        .405                        14.4
#
#   Defensive Four Factors_DRB%  Defensive Four Factors_FT/FGA
# 0                        77.1                           .181
# 1                        78.8                           .424
# 2                        67.6                           .229
# 3                        81.5                           .274
# 4                        77.5                           .095
#
# [5 rows x 29 columns]

# %%
# Drop unnecessary columns
drop_cols = [
    'Unnamed: 7_level_0_Unnamed: 7_level_1',
    'Unnamed: 18_level_0_Unnamed: 18_level_1',
    'Unnamed: 23_level_0_Unnamed: 23_level_1'
]
df = df.drop(columns=drop_cols, errors='ignore')

# Rename key columns
df = df.rename(columns={
    'Unnamed: 0_level_0_Rk': 'Rk',
    'Unnamed: 1_level_0_Date': 'Date',
    'Unnamed: 3_level_0_Opp': 'Opp',
    'Unnamed: 4_level_0_W/L': 'W/L',
    'Unnamed: 5_level_0_Tm': 'Team_Score',
    'Unnamed: 6_level_0_Opp': 'Opp_Score'
})

# rename the messy column name to 'home_away'
df = df.rename(columns={'Unnamed: 2_level_0_Unnamed: 2_level_1': 'home_away'})

# convert values: '@' becomes 2 (away), everything else becomes 1 (home)
df['home_away'] = df['home_away'].apply(lambda x: 2 if x == '@' else 1)

# %%
df.head()
# Out:
#   Team Rk        Date  home_away  Opp W/L Team_Score Opp_Score Advanced_ORtg  \
# 0  ATL  1  2024-05-15          1  LAS   W         92        81         114.0
# 1  ATL  2  2024-05-18          1  PHO   L         85        88         103.6
# 2  ATL  3  2024-05-21          1  DAL   W         83        78         107.0
# 3  ATL  4  2024-05-26          1  MIN   L         79        92         107.0
# 4  ATL  5  2024-05-29          1  WAS   W         73        67          92.0
#
#   Advanced_DRtg  ... Advanced_STL% Advanced_BLK% Offensive Four Factors_eFG%  \
# 0         100.4  ...           9.9          22.0                        .567
# 1         107.3  ...           9.8          11.6                        .485
# 2         100.5  ...          11.6           5.6                        .465
# 3         124.6  ...          12.2           3.0                        .500
# 4          84.4  ...          11.3           4.3                        .468
#
#   Offensive Four Factors_TOV% Offensive Four Factors_ORB%  \
# 0                        14.7                        20.6
# 1                        14.3                        18.4
# 2                        12.8                        35.1
# 3                        11.9                        27.8
# 4                        19.3                        18.5
#
#   Offensive Four Factors_FT/FGA Defensive Four Factors_eFG%  \
# 0                          .239                        .472
# 1                          .318                        .455
# 2                          .222                        .443
# 3                          .162                        .605
# 4                          .242                        .405
#
#   Defensive Four Factors_TOV% Defensive Four Factors_DRB%  \
# 0                        11.9                        77.1
# 1                        13.0                        78.8
# 2                        15.1                        67.6
# 3                        12.2                        81.5
# 4                        14.4                        77.5
#
#   Defensive Four Factors_FT/FGA
# 0                          .181
# 1                          .424
# 2                          .229
# 3                          .274
# 4                          .095
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (504, 26)

# %%
# Print each column name on its own line
for col in df.columns:
    print(col)
# Out:
# Team
# Rk
# Date
# home_away
# Opp
# W/L
# Team_Score
# Opp_Score
# Advanced_ORtg
# Advanced_DRtg
# Advanced_Pace
# Advanced_FTr
# Advanced_3PAr
# Advanced_TS%
# Advanced_TRB%
# Advanced_AST%
# Advanced_STL%
# Advanced_BLK%
# Offensive Four Factors_eFG%
# Offensive Four Factors_TOV%
# Offensive Four Factors_ORB%
# Offensive Four Factors_FT/FGA
# Defensive Four Factors_eFG%
# Defensive Four Factors_TOV%
# Defensive Four Factors_DRB%
# Defensive Four Factors_FT/FGA

# %%
# Save to data folder
df.to_csv(r"C:\Users\colte\LHL-final-project\LHL-final-final-project\data\2024_basketball_reference_gamelog-advanced.csv", index=False)

# %%
# make all column headers lowercase
df.columns = df.columns.str.lower()

# %%
# replace '%' with '_pct' in column names
df.columns = df.columns.str.replace('%', '_pct', regex=False)

# %%
# rename w/l to win_loss
df = df.rename(columns={'w/l': 'win_loss'})

# %%
# convert values: W becomes 1 (win), everything else becomes 2 (loss)
df['win_loss'] = df['win_loss'].apply(lambda x: 1 if x == 'W' else 2)

# %%
# print each column with its dtype
for col in df.columns:
    print(f"- {col}: {df[col].dtype}")
# Out:
# - team: object
# - rk: object
# - date: object
# - home_away: int64
# - opp: object
# - win_loss: int64
# - team_score: object
# - opp_score: object
# - advanced_ortg: object
# - advanced_drtg: object
# - advanced_pace: object
# - advanced_ftr: object
# - advanced_3par: object
# - advanced_ts_pct: object
# - advanced_trb_pct: object
# - advanced_ast_pct: object
# - advanced_stl_pct: object
# - advanced_blk_pct: object
# - offensive four factors_efg_pct: object
# - offensive four factors_tov_pct: object
# - offensive four factors_orb_pct: object
# - offensive four factors_ft/fga: object
# - defensive four factors_efg_pct: object
# - defensive four factors_tov_pct: object
# - defensive four factors_drb_pct: object
# - defensive four factors_ft/fga: object

# %%
# show columns with > 0 null values
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# rk            12
# date          12
# opp           12
# team_score    12
# opp_score     12
# dtype: int64

# %%
# drop rows where 'g#' is null
df = df[df['date'].notnull()]

# %%
# show columns with > 0 null values
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
# show rows where 'date' column is literally 'Date'
df[df['date'] == 'Date']
# Out:
#     team  rk  date  home_away  opp  win_loss team_score opp_score  \
# 21   ATL  Rk  Date          1  Opp         2         Tm       Opp
# 63   CHI  Rk  Date          1  Opp         2         Tm       Opp
# 105  CON  Rk  Date          1  Opp         2         Tm       Opp
# 147  DAL  Rk  Date          1  Opp         2         Tm       Opp
# 189  IND  Rk  Date          1  Opp         2         Tm       Opp
# 231  LAS  Rk  Date          1  Opp         2         Tm       Opp
# 273  MIN  Rk  Date          1  Opp         2         Tm       Opp
# 315  NYL  Rk  Date          1  Opp         2         Tm       Opp
# 357  PHO  Rk  Date          1  Opp         2         Tm       Opp
# 399  SEA  Rk  Date          1  Opp         2         Tm       Opp
# 441  WAS  Rk  Date          1  Opp         2         Tm       Opp
# 483  LVA  Rk  Date          1  Opp         2         Tm       Opp
#
#     advanced_ortg advanced_drtg  ... advanced_stl_pct advanced_blk_pct  \
# 21           ORtg          DRtg  ...             STL%             BLK%
# 63           ORtg          DRtg  ...             STL%             BLK%
# 105          ORtg          DRtg  ...             STL%             BLK%
# 147          ORtg          DRtg  ...             STL%             BLK%
# 189          ORtg          DRtg  ...             STL%             BLK%
# 231          ORtg          DRtg  ...             STL%             BLK%
# 273          ORtg          DRtg  ...             STL%             BLK%
# 315          ORtg          DRtg  ...             STL%             BLK%
# 357          ORtg          DRtg  ...             STL%             BLK%
# 399          ORtg          DRtg  ...             STL%             BLK%
# 441          ORtg          DRtg  ...             STL%             BLK%
# 483          ORtg          DRtg  ...             STL%             BLK%
#
#     offensive four factors_efg_pct offensive four factors_tov_pct  \
# 21                            eFG%                           TOV%
# 63                            eFG%                           TOV%
# 105                           eFG%                           TOV%
# 147                           eFG%                           TOV%
# 189                           eFG%                           TOV%
# 231                           eFG%                           TOV%
# 273                           eFG%                           TOV%
# 315                           eFG%                           TOV%
# 357                           eFG%                           TOV%
# 399                           eFG%                           TOV%
# 441                           eFG%                           TOV%
# 483                           eFG%                           TOV%
#
#     offensive four factors_orb_pct offensive four factors_ft/fga  \
# 21                            ORB%                        FT/FGA
# 63                            ORB%                        FT/FGA
# 105                           ORB%                        FT/FGA
# 147                           ORB%                        FT/FGA
# 189                           ORB%                        FT/FGA
# 231                           ORB%                        FT/FGA
# 273                           ORB%                        FT/FGA
# 315                           ORB%                        FT/FGA
# 357                           ORB%                        FT/FGA
# 399                           ORB%                        FT/FGA
# 441                           ORB%                        FT/FGA
# 483                           ORB%                        FT/FGA
#
#     defensive four factors_efg_pct defensive four factors_tov_pct  \
# 21                            eFG%                           TOV%
# 63                            eFG%                           TOV%
# 105                           eFG%                           TOV%
# 147                           eFG%                           TOV%
# 189                           eFG%                           TOV%
# 231                           eFG%                           TOV%
# 273                           eFG%                           TOV%
# 315                           eFG%                           TOV%
# 357                           eFG%                           TOV%
# 399                           eFG%                           TOV%
# 441                           eFG%                           TOV%
# 483                           eFG%                           TOV%
#
#     defensive four factors_drb_pct defensive four factors_ft/fga
# 21                            DRB%                        FT/FGA
# 63                            DRB%                        FT/FGA
# 105                           DRB%                        FT/FGA
# 147                           DRB%                        FT/FGA
# 189                           DRB%                        FT/FGA
# 231                           DRB%                        FT/FGA
# 273                           DRB%                        FT/FGA
# 315                           DRB%                        FT/FGA
# 357                           DRB%                        FT/FGA
# 399                           DRB%                        FT/FGA
# 441                           DRB%                        FT/FGA
# 483                           DRB%                        FT/FGA
#
# [12 rows x 26 columns]

# %%
# drop rows where 'date' is the string 'Date'
df = df[df['date'] != 'Date']

# %%
# convert to datetime (if not already)
df['date'] = pd.to_datetime(df['date'])

# split into year, month, day
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day

# %%
# drop 'date' column
df = df.drop(columns=['date'])

# build new column order without year/month/day
cols = [col for col in df.columns if col not in ['year', 'month', 'day']]

# find where to insert
insert_at = cols.index('home_away')

# insert year/month/day before 'age'
new_order = cols[:insert_at] + ['year', 'month', 'day'] + cols[insert_at:]

# reorder
df = df[new_order]

# %%
df.head()
# Out:
#   team rk  year  month  day  home_away  opp  win_loss team_score opp_score  \
# 0  ATL  1  2024      5   15          1  LAS         1         92        81
# 1  ATL  2  2024      5   18          1  PHO         2         85        88
# 2  ATL  3  2024      5   21          1  DAL         1         83        78
# 3  ATL  4  2024      5   26          1  MIN         2         79        92
# 4  ATL  5  2024      5   29          1  WAS         1         73        67
#
#    ... advanced_stl_pct advanced_blk_pct offensive four factors_efg_pct  \
# 0  ...              9.9             22.0                           .567
# 1  ...              9.8             11.6                           .485
# 2  ...             11.6              5.6                           .465
# 3  ...             12.2              3.0                           .500
# 4  ...             11.3              4.3                           .468
#
#   offensive four factors_tov_pct offensive four factors_orb_pct  \
# 0                           14.7                           20.6
# 1                           14.3                           18.4
# 2                           12.8                           35.1
# 3                           11.9                           27.8
# 4                           19.3                           18.5
#
#   offensive four factors_ft/fga defensive four factors_efg_pct  \
# 0                          .239                           .472
# 1                          .318                           .455
# 2                          .222                           .443
# 3                          .162                           .605
# 4                          .242                           .405
#
#   defensive four factors_tov_pct defensive four factors_drb_pct  \
# 0                           11.9                           77.1
# 1                           13.0                           78.8
# 2                           15.1                           67.6
# 3                           12.2                           81.5
# 4                           14.4                           77.5
#
#   defensive four factors_ft/fga
# 0                          .181
# 1                          .424
# 2                          .229
# 3                          .274
# 4                          .095
#
# [5 rows x 28 columns]

# %%
# drop the 'rk' column
df = df.drop(columns=['rk'])

# %%
# print each column with its dtype
for col in df.columns:
    print(f"- {col}: {df[col].dtype}")
# Out:
# - team: object
# - year: int32
# - month: int32
# - day: int32
# - home_away: int64
# - opp: object
# - win_loss: int64
# - team_score: object
# - opp_score: object
# - advanced_ortg: object
# - advanced_drtg: object
# - advanced_pace: object
# - advanced_ftr: object
# - advanced_3par: object
# - advanced_ts_pct: object
# - advanced_trb_pct: object
# - advanced_ast_pct: object
# - advanced_stl_pct: object
# - advanced_blk_pct: object
# - offensive four factors_efg_pct: object
# - offensive four factors_tov_pct: object
# - offensive four factors_orb_pct: object
# - offensive four factors_ft/fga: object
# - defensive four factors_efg_pct: object
# - defensive four factors_tov_pct: object
# - defensive four factors_drb_pct: object
# - defensive four factors_ft/fga: object

# %%
# reset index and drop the old index
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#   team  year  month  day  home_away  opp  win_loss team_score opp_score  \
# 0  ATL  2024      5   15          1  LAS         1         92        81
# 1  ATL  2024      5   18          1  PHO         2         85        88
# 2  ATL  2024      5   21          1  DAL         1         83        78
# 3  ATL  2024      5   26          1  MIN         2         79        92
# 4  ATL  2024      5   29          1  WAS         1         73        67
#
#   advanced_ortg  ... advanced_stl_pct advanced_blk_pct  \
# 0         114.0  ...              9.9             22.0
# 1         103.6  ...              9.8             11.6
# 2         107.0  ...             11.6              5.6
# 3         107.0  ...             12.2              3.0
# 4          92.0  ...             11.3              4.3
#
#   offensive four factors_efg_pct offensive four factors_tov_pct  \
# 0                           .567                           14.7
# 1                           .485                           14.3
# 2                           .465                           12.8
# 3                           .500                           11.9
# 4                           .468                           19.3
#
#   offensive four factors_orb_pct offensive four factors_ft/fga  \
# 0                           20.6                          .239
# 1                           18.4                          .318
# 2                           35.1                          .222
# 3                           27.8                          .162
# 4                           18.5                          .242
#
#   defensive four factors_efg_pct defensive four factors_tov_pct  \
# 0                           .472                           11.9
# 1                           .455                           13.0
# 2                           .443                           15.1
# 3                           .605                           12.2
# 4                           .405                           14.4
#
#   defensive four factors_drb_pct defensive four factors_ft/fga
# 0                           77.1                          .181
# 1                           78.8                          .424
# 2                           67.6                          .229
# 3                           81.5                          .274
# 4                           77.5                          .095
#
# [5 rows x 27 columns]

# %%
# show columns with > 0 null values
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
# Replace '/' with _per_
df.columns = df.columns.str.replace('/', '_per_', regex=False)

# Replace ' ' with '_'
df.columns = df.columns.str.replace(' ', '_', regex=False)

# %%
# print each column with its dtype
for col in df.columns:
    print(f"- {col}: {df[col].dtype}")
# Out:
# - team: object
# - year: int32
# - month: int32
# - day: int32
# - home_away: int64
# - opp: object
# - win_loss: int64
# - team_score: object
# - opp_score: object
# - advanced_ortg: object
# - advanced_drtg: object
# - advanced_pace: object
# - advanced_ftr: object
# - advanced_3par: object
# - advanced_ts_pct: object
# - advanced_trb_pct: object
# - advanced_ast_pct: object
# - advanced_stl_pct: object
# - advanced_blk_pct: object
# - offensive_four_factors_efg_pct: object
# - offensive_four_factors_tov_pct: object
# - offensive_four_factors_orb_pct: object
# - offensive_four_factors_ft_per_fga: object
# - defensive_four_factors_efg_pct: object
# - defensive_four_factors_tov_pct: object
# - defensive_four_factors_drb_pct: object
# - defensive_four_factors_ft_per_fga: object

# %%
df.to_csv("2024_basketball_reference_gamelog-advanced.csv", index=False)

from google.colab import files

files.download("2024_basketball_reference_gamelog-advanced.csv")

# %%
# list of columns that should be numeric
cols_to_convert = [col for col in df.columns if col not in ['team', 'opp']]

# convert all non-string columns to numeric, coercing errors
df[cols_to_convert] = df[cols_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
# show columns with > 0 null values
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
# print each column with its dtype in a readable list
for col in df.columns:
    print(f"- {col}: {df[col].dtype}")
# Out:
# - team: object
# - year: int32
# - month: int32
# - day: int32
# - home_away: int64
# - opp: object
# - win_loss: int64
# - team_score: int64
# - opp_score: int64
# - advanced_ortg: float64
# - advanced_drtg: float64
# - advanced_pace: float64
# - advanced_ftr: float64
# - advanced_3par: float64
# - advanced_ts_pct: float64
# - advanced_trb_pct: float64
# - advanced_ast_pct: float64
# - advanced_stl_pct: float64
# - advanced_blk_pct: float64
# - offensive_four_factors_efg_pct: float64
# - offensive_four_factors_tov_pct: float64
# - offensive_four_factors_orb_pct: float64
# - offensive_four_factors_ft_per_fga: float64
# - defensive_four_factors_efg_pct: float64
# - defensive_four_factors_tov_pct: float64
# - defensive_four_factors_drb_pct: float64
# - defensive_four_factors_ft_per_fga: float64

# %%
df.to_csv("2024_basketball_reference_gamelog-advanced.csv", index=False)

from google.colab import files

files.download("2024_basketball_reference_gamelog-advanced.csv")
