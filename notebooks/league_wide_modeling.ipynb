# %%
# Clone your GitHub repo (you’ll be prompted to authorize if it's private)
# !git clone https://github.com/colterwood/LHL-final-final-project.git
# Out:
# Cloning into 'LHL-final-final-project'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 119 (delta 64), reused 19 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.27 MiB | 2.60 MiB/s, done.
# Resolving deltas: 100% (64/64), done.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GroupShuffleSplit
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split

# %%
# load the player game logs CSV from the data folder
df = pd.read_csv("LHL-final-final-project/data/2024_merged_gamelogs.csv")


# preview
df.head()
# Out:
#   team  g_num  month  day  home_away  opp  win_loss  team_score  opp_score  \
# 0  ATL      1      5   15          2  LAS         1          92         81
# 1  ATL      2      5   18          2  PHO         2          85         88
# 2  ATL      3      5   21          1  DAL         1          83         78
# 3  ATL      4      5   26          1  MIN         2          79         92
# 4  ATL      5      5   29          2  WAS         1          73         67
#
#    team_fg  ...  day_of_week_by_team_travel_distance  \
# 0       34  ...                                  3.0
# 1       27  ...                                  2.0
# 2       30  ...                                  4.0
# 3       31  ...                                  3.0
# 4       26  ...                                  4.0
#
#    team_vs_opp_median_score_by_team_travel_distance  \
# 0                                              75.0
# 1                                              76.0
# 2                                              81.0
# 3                                              75.0
# 4                                              75.0
#
#    team_vs_opp_homeaway_median_score_by_team_travel_distance  \
# 0                                               70.0
# 1                                               76.0
# 2                                               75.5
# 3                                               70.0
# 4                                               76.5
#
#    team_home_or_away_median_score_by_team_travel_distance  \
# 0                                               78.5
# 1                                               78.0
# 2                                               78.0
# 3                                               78.5
# 4                                               78.0
#
#    team_home_or_away_median_allowed_by_team_travel_distance  \
# 0                                               79.5
# 1                                               80.5
# 2                                               80.5
# 3                                               79.5
# 4                                               80.5
#
#    team_day_median_score_by_team_travel_distance  \
# 0                                           76.0
# 1                                           76.0
# 2                                           73.0
# 3                                           76.0
# 4                                           76.0
#
#    team_day_median_allowed_by_team_travel_distance  \
# 0                                             80.0
# 1                                             80.0
# 2                                             78.0
# 3                                             80.0
# 4                                             80.0
#
#    travel_distance_by_team_travel_distance  \
# 0                                      0.0
# 1                                      1.0
# 2                                      3.0
# 3                                      0.0
# 4                                      2.0
#
#    median_score_for_by_team_travel_distance  \
# 0                                      77.0
# 1                                      77.5
# 2                                      81.0
# 3                                      77.0
# 4                                      78.0
#
#    median_score_against_by_team_travel_distance
# 0                                          79.5
# 1                                          77.5
# 2                                          85.0
# 3                                          79.5
# 4                                          80.0
#
# [5 rows x 261 columns]

# %%
# features (drop identifiers and targets)
features = df.drop(columns=['team_score', 'opp_score', 'team', 'opp'])

# targets
targets = df[['team_score', 'opp_score']]

# group-aware split
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, test_idx = next(gss.split(features, groups=df['team']))

X_train = features.iloc[train_idx]
X_test = features.iloc[test_idx]
y_train = targets.iloc[train_idx]
y_test = targets.iloc[test_idx]

# model
model = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(random_state=42))

# %%
# get feature importances for team_score prediction
team_score_importance = model.estimators_[0].feature_importances_

# get feature importances for opp_score prediction
opp_score_importance = model.estimators_[1].feature_importances_

# match to feature names
feature_names = features.columns

# build DataFrame
importances_df = (
    pd.DataFrame({
        'feature': feature_names,
        'team_score_importance': team_score_importance,
        'opp_score_importance': opp_score_importance
    })
    .sort_values(by='team_score_importance', ascending=False)
)

importances_df.head(20)  # or whatever number you want to view
# Out:
#                                feature  team_score_importance  \
# 37                       advanced_ortg               0.771811
# 57   team_vs_opp_homeaway_median_score               0.063060
# 39                       advanced_pace               0.051088
# 5                              team_fg               0.028227
# 42                     advanced_ts_pct               0.005816
# 56            team_vs_opp_median_score               0.004108
# 16                            team_ast               0.003441
# 19                            team_tov               0.002953
# 7                          team_fg_pct               0.002157
# 33                        opponent_stl               0.001959
# 47      offensive_four_factors_efg_pct               0.001730
# 21                         opponent_fg               0.001408
# 22                        opponent_fga               0.001393
# 17                            team_stl               0.001365
# 11                             team_ft               0.001081
# 12                            team_fta               0.000945
# 167  advanced_pace_by_team_day_of_week               0.000938
# 25                        opponent_3pa               0.000878
# 10                         team_3p_pct               0.000869
# 50   offensive_four_factors_ft_per_fga               0.000852
#
#      opp_score_importance
# 37               0.000807
# 57               0.001122
# 39               0.068585
# 5                0.001548
# 42               0.000612
# 56               0.000472
# 16               0.000471
# 19               0.001352
# 7                0.000643
# 33               0.001807
# 47               0.000350
# 21               0.067323
# 22               0.000882
# 17               0.001874
# 11               0.000272
# 12               0.000445
# 167              0.001041
# 25               0.000443
# 10               0.000555
# 50               0.000309

# %%
# show all or more of the ranked features
importances_df.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 37                                       advanced_ortg               0.771811
# 57                   team_vs_opp_homeaway_median_score               0.063060
# 39                                       advanced_pace               0.051088
# 5                                              team_fg               0.028227
# 42                                     advanced_ts_pct               0.005816
# 56                            team_vs_opp_median_score               0.004108
# 16                                            team_ast               0.003441
# 19                                            team_tov               0.002953
# 7                                          team_fg_pct               0.002157
# 33                                        opponent_stl               0.001959
# 47                      offensive_four_factors_efg_pct               0.001730
# 21                                         opponent_fg               0.001408
# 22                                        opponent_fga               0.001393
# 17                                            team_stl               0.001365
# 11                                             team_ft               0.001081
# 12                                            team_fta               0.000945
# 167                  advanced_pace_by_team_day_of_week               0.000938
# 25                                        opponent_3pa               0.000878
# 10                                         team_3p_pct               0.000869
# 50                   offensive_four_factors_ft_per_fga               0.000852
# 154                opponent_3p_pct_by_team_day_of_week               0.000828
# 6                                             team_fga               0.000819
# 40                                        advanced_ftr               0.000808
# 8                                              team_3p               0.000803
# 15                                            team_trb               0.000768
# 26                                     opponent_3p_pct               0.000724
# 0                                                g_num               0.000709
# 35                                        opponent_tov               0.000667
# 29                                     opponent_ft_pct               0.000647
# 93                   opponent_ft_pct_by_team_home_away               0.000630
# 213                opponent_fg_by_team_travel_distance               0.000606
# 44                                    advanced_ast_pct               0.000563
# 174               advanced_blk_pct_by_team_day_of_week               0.000554
# 181  defensive_four_factors_drb_pct_by_team_day_of_...               0.000553
# 27                                         opponent_ft               0.000547
# 185  team_vs_opp_homeaway_median_score_by_team_day_...               0.000537
# 186  team_home_or_away_median_score_by_team_day_of_...               0.000531
# 18                                            team_blk               0.000518
# 201                   team_3pa_by_team_travel_distance               0.000509
# 13                                         team_ft_pct               0.000483
# 52                      defensive_four_factors_tov_pct               0.000469
# 170                advanced_ts_pct_by_team_day_of_week               0.000465
# 133                        team_fg_by_team_day_of_week               0.000462
# 218            opponent_3p_pct_by_team_travel_distance               0.000461
# 130                            day_by_team_day_of_week               0.000460
# 166                  advanced_drtg_by_team_day_of_week               0.000452
# 34                                        opponent_blk               0.000451
# 138                    team_3p_pct_by_team_day_of_week               0.000442
# 30                                        opponent_orb               0.000434
# 231              advanced_pace_by_team_travel_distance               0.000433
#
#      opp_score_importance
# 37               0.000807
# 57               0.001122
# 39               0.068585
# 5                0.001548
# 42               0.000612
# 56               0.000472
# 16               0.000471
# 19               0.001352
# 7                0.000643
# 33               0.001807
# 47               0.000350
# 21               0.067323
# 22               0.000882
# 17               0.001874
# 11               0.000272
# 12               0.000445
# 167              0.001041
# 25               0.000443
# 10               0.000555
# 50               0.000309
# 154              0.000283
# 6                0.000608
# 40               0.000417
# 8                0.000504
# 15               0.000206
# 26               0.000580
# 0                0.000813
# 35               0.000263
# 29               0.000633
# 93               0.000149
# 213              0.000244
# 44               0.000572
# 174              0.000201
# 181              0.000432
# 27               0.002232
# 185              0.000400
# 186              0.000275
# 18               0.000216
# 201              0.000086
# 13               0.000423
# 52               0.000292
# 170              0.000219
# 133              0.000076
# 218              0.000727
# 130              0.000364
# 166              0.000323
# 34               0.000280
# 138              0.000189
# 30               0.000294
# 231              0.000613

# %%
# show all or more of the ranked features
importances_df.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 38                                       advanced_drtg               0.000367
# 39                                       advanced_pace               0.051088
# 21                                         opponent_fg               0.001408
# 23                                     opponent_fg_pct               0.000315
# 51                      defensive_four_factors_efg_pct               0.000313
# 27                                         opponent_ft               0.000547
# 17                                            team_stl               0.001365
# 33                                        opponent_stl               0.001959
# 5                                              team_fg               0.028227
# 19                                            team_tov               0.002953
# 54                   defensive_four_factors_ft_per_fga               0.000251
# 24                                         opponent_3p               0.000351
# 57                   team_vs_opp_homeaway_median_score               0.063060
# 167                  advanced_pace_by_team_day_of_week               0.000938
# 49                      offensive_four_factors_orb_pct               0.000428
# 22                                        opponent_fga               0.001393
# 0                                                g_num               0.000709
# 37                                       advanced_ortg               0.771811
# 28                                        opponent_fta               0.000355
# 103                    advanced_pace_by_team_home_away               0.000423
# 218            opponent_3p_pct_by_team_travel_distance               0.000461
# 32                                        opponent_ast               0.000336
# 172               advanced_ast_pct_by_team_day_of_week               0.000351
# 7                                          team_fg_pct               0.002157
# 86                      opponent_fga_by_team_home_away               0.000130
# 29                                     opponent_ft_pct               0.000647
# 191               median_score_for_by_team_day_of_week               0.000134
# 231              advanced_pace_by_team_travel_distance               0.000433
# 42                                     advanced_ts_pct               0.005816
# 6                                             team_fga               0.000819
# 26                                     opponent_3p_pct               0.000724
# 44                                    advanced_ast_pct               0.000563
# 10                                         team_3p_pct               0.000869
# 256       median_score_against_by_team_travel_distance               0.000152
# 192           median_score_against_by_team_day_of_week               0.000218
# 8                                              team_3p               0.000803
# 216                opponent_3p_by_team_travel_distance               0.000364
# 159                   opponent_trb_by_team_day_of_week               0.000104
# 20                                             team_pf               0.000265
# 230              advanced_drtg_by_team_travel_distance               0.000119
# 56                            team_vs_opp_median_score               0.004108
# 16                                            team_ast               0.003441
# 48                      offensive_four_factors_tov_pct               0.000329
# 153                   opponent_3pa_by_team_day_of_week               0.000350
# 12                                            team_fta               0.000945
# 25                                        opponent_3pa               0.000878
# 181  defensive_four_factors_drb_pct_by_team_day_of_...               0.000553
# 13                                         team_ft_pct               0.000483
# 53                      defensive_four_factors_drb_pct               0.000248
# 40                                        advanced_ftr               0.000808
#
#      opp_score_importance
# 38               0.786820
# 39               0.068585
# 21               0.067323
# 23               0.007825
# 51               0.002968
# 27               0.002232
# 17               0.001874
# 33               0.001807
# 5                0.001548
# 19               0.001352
# 54               0.001136
# 24               0.001135
# 57               0.001122
# 167              0.001041
# 49               0.001009
# 22               0.000882
# 0                0.000813
# 37               0.000807
# 28               0.000807
# 103              0.000753
# 218              0.000727
# 32               0.000726
# 172              0.000673
# 7                0.000643
# 86               0.000636
# 29               0.000633
# 191              0.000617
# 231              0.000613
# 42               0.000612
# 6                0.000608
# 26               0.000580
# 44               0.000572
# 10               0.000555
# 256              0.000552
# 192              0.000515
# 8                0.000504
# 216              0.000493
# 159              0.000481
# 20               0.000476
# 230              0.000472
# 56               0.000472
# 16               0.000471
# 48               0.000453
# 153              0.000451
# 12               0.000445
# 25               0.000443
# 181              0.000432
# 13               0.000423
# 53               0.000419
# 40               0.000417

# %%
# define substrings that identify counting stats
counting_keywords = ['fg', 'fga', '3p', '3pa', 'ft', 'fta', 'orb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf']

# drop columns where the name contains any of those keywords but NOT pct or rate stats
counting_cols = [col for col in df.columns if any(k in col for k in counting_keywords)
                 and not col.endswith('_pct')
                 and 'four_factors' not in col
                 and 'advanced' not in col
                 and col not in ['team_score', 'opp_score']]

# %%
print(counting_cols)
# Out:
# ['team_fg', 'team_fga', 'team_3p', 'team_3pa', 'team_ft', 'team_fta', 'team_orb', 'team_trb', 'team_ast', 'team_stl', 'team_blk', 'team_tov', 'team_pf', 'opponent_fg', 'opponent_fga', 'opponent_3p', 'opponent_3pa', 'opponent_ft', 'opponent_fta', 'opponent_orb', 'opponent_trb', 'opponent_ast', 'opponent_stl', 'opponent_blk', 'opponent_tov', 'opponent_pf', 'team_fg_by_team_home_away', 'team_fga_by_team_home_away', 'team_fg_pct_by_team_home_away', 'team_3p_by_team_home_away', 'team_3pa_by_team_home_away', 'team_3p_pct_by_team_home_away', 'team_ft_by_team_home_away', 'team_fta_by_team_home_away', 'team_ft_pct_by_team_home_away', 'team_orb_by_team_home_away', 'team_trb_by_team_home_away', 'team_ast_by_team_home_away', 'team_stl_by_team_home_away', 'team_blk_by_team_home_away', 'team_tov_by_team_home_away', 'team_pf_by_team_home_away', 'opponent_fg_by_team_home_away', 'opponent_fga_by_team_home_away', 'opponent_fg_pct_by_team_home_away', 'opponent_3p_by_team_home_away', 'opponent_3pa_by_team_home_away', 'opponent_3p_pct_by_team_home_away', 'opponent_ft_by_team_home_away', 'opponent_fta_by_team_home_away', 'opponent_ft_pct_by_team_home_away', 'opponent_orb_by_team_home_away', 'opponent_trb_by_team_home_away', 'opponent_ast_by_team_home_away', 'opponent_stl_by_team_home_away', 'opponent_blk_by_team_home_away', 'opponent_tov_by_team_home_away', 'opponent_pf_by_team_home_away', 'team_fg_by_team_day_of_week', 'team_fga_by_team_day_of_week', 'team_fg_pct_by_team_day_of_week', 'team_3p_by_team_day_of_week', 'team_3pa_by_team_day_of_week', 'team_3p_pct_by_team_day_of_week', 'team_ft_by_team_day_of_week', 'team_fta_by_team_day_of_week', 'team_ft_pct_by_team_day_of_week', 'team_orb_by_team_day_of_week', 'team_trb_by_team_day_of_week', 'team_ast_by_team_day_of_week', 'team_stl_by_team_day_of_week', 'team_blk_by_team_day_of_week', 'team_tov_by_team_day_of_week', 'team_pf_by_team_day_of_week', 'opponent_fg_by_team_day_of_week', 'opponent_fga_by_team_day_of_week', 'opponent_fg_pct_by_team_day_of_week', 'opponent_3p_by_team_day_of_week', 'opponent_3pa_by_team_day_of_week', 'opponent_3p_pct_by_team_day_of_week', 'opponent_ft_by_team_day_of_week', 'opponent_fta_by_team_day_of_week', 'opponent_ft_pct_by_team_day_of_week', 'opponent_orb_by_team_day_of_week', 'opponent_trb_by_team_day_of_week', 'opponent_ast_by_team_day_of_week', 'opponent_stl_by_team_day_of_week', 'opponent_blk_by_team_day_of_week', 'opponent_tov_by_team_day_of_week', 'opponent_pf_by_team_day_of_week', 'team_fg_by_team_travel_distance', 'team_fga_by_team_travel_distance', 'team_fg_pct_by_team_travel_distance', 'team_3p_by_team_travel_distance', 'team_3pa_by_team_travel_distance', 'team_3p_pct_by_team_travel_distance', 'team_ft_by_team_travel_distance', 'team_fta_by_team_travel_distance', 'team_ft_pct_by_team_travel_distance', 'team_orb_by_team_travel_distance', 'team_trb_by_team_travel_distance', 'team_ast_by_team_travel_distance', 'team_stl_by_team_travel_distance', 'team_blk_by_team_travel_distance', 'team_tov_by_team_travel_distance', 'team_pf_by_team_travel_distance', 'opponent_fg_by_team_travel_distance', 'opponent_fga_by_team_travel_distance', 'opponent_fg_pct_by_team_travel_distance', 'opponent_3p_by_team_travel_distance', 'opponent_3pa_by_team_travel_distance', 'opponent_3p_pct_by_team_travel_distance', 'opponent_ft_by_team_travel_distance', 'opponent_fta_by_team_travel_distance', 'opponent_ft_pct_by_team_travel_distance', 'opponent_orb_by_team_travel_distance', 'opponent_trb_by_team_travel_distance', 'opponent_ast_by_team_travel_distance', 'opponent_stl_by_team_travel_distance', 'opponent_blk_by_team_travel_distance', 'opponent_tov_by_team_travel_distance', 'opponent_pf_by_team_travel_distance']

# %%
df = df.drop(columns=counting_cols)

# %%
# make sure we only use numeric features (exclude targets and IDs)
X = df.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
X = X.select_dtypes(include='number')

# compute correlation matrix
corr_matrix = X.corr().abs()

# keep upper triangle only (to avoid duplicate pairs)
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# flatten and filter for high correlation pairs
high_corr_pairs = (
    upper.stack()
    .reset_index()
    .rename(columns={'level_0': 'feature_1', 'level_1': 'feature_2', 0: 'correlation'})
    .query('correlation > 0.9')
    .sort_values(by='correlation', ascending=False)
)

high_corr_pairs
# Out:
#                                               feature_1  \
# 436                                           home_away
# 3823                     team_home_or_away_median_score
# 3543                                        day_of_week
# 4058                              team_day_median_score
# 4484                               median_score_against
# 4387                                   median_score_for
# 4289                                    travel_distance
# 3925                   team_home_or_away_median_allowed
# 4158                            team_day_median_allowed
# 0                                                 g_num
# 2028                                    advanced_ts_pct
# 6769          team_day_median_allowed_by_team_home_away
# 6634  team_home_or_away_median_allowed_by_team_home_...
# 3930                   team_home_or_away_median_allowed
# 5280                    advanced_3par_by_team_home_away
# 6830          team_day_median_allowed_by_team_home_away
# 675                                         team_fg_pct
# 1060                                    opponent_fg_pct
# 3904                   team_home_or_away_median_allowed
# 4970                    advanced_drtg_by_team_home_away
# 3989                   team_home_or_away_median_allowed
# 6693  team_home_or_away_median_allowed_by_team_home_...
# 1794                                       advanced_ftr
# 3927                   team_home_or_away_median_allowed
# 6631  team_home_or_away_median_allowed_by_team_home_...
# 7025             median_score_against_by_team_home_away
# 6796          team_day_median_allowed_by_team_home_away
# 3957                   team_home_or_away_median_allowed
# 6661  team_home_or_away_median_allowed_by_team_home_...
# 7023             median_score_against_by_team_home_away
# 6991             median_score_against_by_team_home_away
# 8796            advanced_ts_pct_by_team_travel_distance
# 6828          team_day_median_allowed_by_team_home_away
# 6489  team_vs_opp_homeaway_median_score_by_team_home...
# 3822                     team_home_or_away_median_score
# 6762            team_day_median_score_by_team_home_away
# 670                                         team_fg_pct
# 5034                    advanced_drtg_by_team_home_away
# 8375  team_home_or_away_median_allowed_by_team_day_o...
# 7564                advanced_ts_pct_by_team_day_of_week
# 5308                  advanced_ts_pct_by_team_home_away
# 8373  team_home_or_away_median_allowed_by_team_day_o...
#
#                                               feature_2  correlation
# 436                         home_away_by_team_home_away     1.000000
# 3823   team_home_or_away_median_score_by_team_home_away     1.000000
# 3543                    day_of_week_by_team_day_of_week     1.000000
# 4058          team_day_median_score_by_team_day_of_week     1.000000
# 4484       median_score_against_by_team_travel_distance     1.000000
# 4387           median_score_for_by_team_travel_distance     1.000000
# 4289            travel_distance_by_team_travel_distance     1.000000
# 3925  team_home_or_away_median_allowed_by_team_home_...     1.000000
# 4158        team_day_median_allowed_by_team_day_of_week     1.000000
# 0                                                 month     0.974134
# 2028                     offensive_four_factors_efg_pct     0.962090
# 6769             median_score_against_by_team_home_away     0.956237
# 6634             median_score_against_by_team_home_away     0.953689
# 3930             median_score_against_by_team_home_away     0.953689
# 5280              advanced_3par_by_team_travel_distance     0.949303
# 6830    team_day_median_allowed_by_team_travel_distance     0.946778
# 675                      offensive_four_factors_efg_pct     0.945075
# 1060                     defensive_four_factors_efg_pct     0.945075
# 3904                    advanced_drtg_by_team_home_away     0.943072
# 4970  team_home_or_away_median_allowed_by_team_home_...     0.943072
# 3989  team_home_or_away_median_allowed_by_team_trave...     0.940094
# 6693  team_home_or_away_median_allowed_by_team_trave...     0.940094
# 1794                  offensive_four_factors_ft_per_fga     0.938536
# 3927          team_day_median_allowed_by_team_home_away     0.928641
# 6631          team_day_median_allowed_by_team_home_away     0.928641
# 7025    team_day_median_allowed_by_team_travel_distance     0.926846
# 6796  team_home_or_away_median_allowed_by_team_day_o...     0.926359
# 3957  team_home_or_away_median_allowed_by_team_day_o...     0.925752
# 6661  team_home_or_away_median_allowed_by_team_day_o...     0.925752
# 7023  team_home_or_away_median_allowed_by_team_trave...     0.923045
# 6991  team_home_or_away_median_allowed_by_team_day_o...     0.921508
# 8796  offensive_four_factors_efg_pct_by_team_travel_...     0.916892
# 6828  team_home_or_away_median_allowed_by_team_trave...     0.913808
# 6489   team_home_or_away_median_score_by_team_home_away     0.912328
# 3822  team_vs_opp_homeaway_median_score_by_team_home...     0.912328
# 6762      team_day_median_score_by_team_travel_distance     0.911558
# 670                                     advanced_ts_pct     0.910941
# 5034  team_home_or_away_median_allowed_by_team_trave...     0.905772
# 8375    team_day_median_allowed_by_team_travel_distance     0.905711
# 7564  offensive_four_factors_efg_pct_by_team_day_of_...     0.904420
# 5308   offensive_four_factors_efg_pct_by_team_home_away     0.903674
# 8373  team_home_or_away_median_allowed_by_team_trave...     0.903340

# %%
# always keep these no matter what
must_keep = ['advanced_ortg', 'advanced_drtg']

def auto_select_drops(high_corr_df):
    drop_cols = []

    for _, row in high_corr_df.iterrows():
        f1, f2 = row['feature_1'], row['feature_2']

        # skip if either feature is protected
        if f1 in must_keep or f2 in must_keep:
            continue

        # drop the more engineered-looking one
        if '_by_' in f1 or 'median' in f1:
            drop_cols.append(f1)
        elif '_by_' in f2 or 'median' in f2:
            drop_cols.append(f2)
        else:
            # fallback: drop longer one
            drop_cols.append(f1 if len(f1) > len(f2) else f2)

    return list(set(drop_cols))

# %%
# create drop list
auto_drop_cols = auto_select_drops(high_corr_pairs)

# %%
# View suggested drop list
print(auto_drop_cols)
# Out:
# ['team_day_median_allowed_by_team_home_away', 'advanced_ts_pct_by_team_travel_distance', 'median_score_against', 'team_day_median_score_by_team_home_away', 'team_day_median_allowed', 'offensive_four_factors_efg_pct', 'month', 'defensive_four_factors_efg_pct', 'offensive_four_factors_ft_per_fga', 'median_score_against_by_team_home_away', 'advanced_ts_pct_by_team_day_of_week', 'travel_distance_by_team_travel_distance', 'advanced_ts_pct', 'team_vs_opp_homeaway_median_score_by_team_home_away', 'day_of_week_by_team_day_of_week', 'team_home_or_away_median_allowed', 'advanced_3par_by_team_home_away', 'advanced_ts_pct_by_team_home_away', 'team_home_or_away_median_allowed_by_team_home_away', 'home_away_by_team_home_away', 'team_day_median_score', 'team_home_or_away_median_allowed_by_team_day_of_week', 'team_home_or_away_median_score', 'median_score_for', 'advanced_drtg_by_team_home_away']

# %%
# Manually built drop list
drop_list = [
    'home_away_by_team_home_away',
    'team_home_or_away_median_score_by_team_home_away',
    'day_of_week_by_team_day_of_week',
    'team_day_median_score_by_team_day_of_week',
    'median_score_against_by_team_travel_distance',
    'median_score_for_by_team_travel_distance',
    'travel_distance_by_team_travel_distance',
    'team_home_or_away_median_allowed_by_team_home_away',
    'team_day_median_allowed_by_team_day_of_week',
    'g_num',
    'offensive_four_factors_efg_pct',
    'team_day_median_allowed_by_team_home_away',
    'team_home_or_away_median_allowed_by_team_home_away',
    'team_home_or_away_median_allowed',
    'team_home_or_away_median_allowed_by_team_travel_distance',
    'offensive_four_factors_ft_per_fga',
    'team_day_median_allowed_by_team_home_away',
    'team_home_or_away_median_allowed_by_team_day_of_week',
    'offensive_four_factors_efg_pct_by_team_travel_distance',
    'team_home_or_away_median_score_by_team_home_away',
    'team_vs_opp_homeaway_median_score_by_team_home_away',
    'team_fg_pct',
    'offensive_four_factors_efg_pct_by_team_day_of_week',
    'offensive_four_factors_efg_pct_by_team_home_away'
]

# %%
# drop from df
df = df.drop(columns=drop_list, errors='ignore')

# %%
# filter to numeric features only (excluding IDs and targets)
X = df.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
X = X.select_dtypes(include='number')

# compute VIFs
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_data = vif_data.sort_values(by='VIF', ascending=False)

vif_data
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                                               feature       VIF
# 2                                           home_away       inf
# 49  offensive_four_factors_ft_per_fga_by_team_home...       inf
# 34                            month_by_team_home_away       inf
# 35                              day_by_team_home_away       inf
# 36                         win_loss_by_team_home_away       inf
# ..                                                ...       ...
# 16                                   advanced_ast_pct  1.842376
# 18                                   advanced_blk_pct  1.638229
# 5                                         team_ft_pct  1.480301
# 1                                                 day  1.472835
# 0                                               month  1.404025
#
# [114 rows x 2 columns]

# %%
X.corr()['home_away'].sort_values(ascending=False)
# Out:
# home_away                                              1.000000
# travel_distance_by_team_home_away                      0.807283
# home_away_by_team_travel_distance                      0.508346
# travel_distance                                        0.390108
# home_away_by_team_day_of_week                          0.323630
#                                                          ...
# advanced_ortg_by_team_home_away                       -0.217181
# offensive_four_factors_orb_pct_by_team_home_away      -0.227798
# defensive_four_factors_drb_pct_by_team_home_away      -0.253229
# offensive_four_factors_ft_per_fga_by_team_home_away   -0.295397
# advanced_trb_pct_by_team_home_away                    -0.321299
# Name: home_away, Length: 114, dtype: float64

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor

# define features and targets
features = df.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets = df[['team_score', 'opp_score']]

# stratified split by team
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, test_idx = next(gss.split(features, groups=df['team']))

X_train = features.iloc[train_idx]
X_test = features.iloc[test_idx]
y_train = targets.iloc[train_idx]
y_test = targets.iloc[test_idx]

# train model
model = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(random_state=42))

# %%
# get feature importances for team_score prediction
team_score_importance = model.estimators_[0].feature_importances_

# get feature importances for opp_score prediction
opp_score_importance = model.estimators_[1].feature_importances_

# match to feature names
feature_names = features.columns

# build DataFrame
importances_df = (
    pd.DataFrame({
        'feature': feature_names,
        'team_score_importance': team_score_importance,
        'opp_score_importance': opp_score_importance
    })
    .sort_values(by='team_score_importance', ascending=False)
)

importances_df.head(20)  # or whatever number you want to view
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.789104
# 27                   team_vs_opp_homeaway_median_score               0.071171
# 11                                       advanced_pace               0.063676
# 14                                     advanced_ts_pct               0.008506
# 26                            team_vs_opp_median_score               0.004471
# 19                      offensive_four_factors_tov_pct               0.003621
# 4                                          team_3p_pct               0.002133
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.002000
# 66                   advanced_pace_by_team_day_of_week               0.001366
# 68                   advanced_3par_by_team_day_of_week               0.001342
# 7                                      opponent_3p_pct               0.001297
# 17                                    advanced_stl_pct               0.001242
# 23                      defensive_four_factors_drb_pct               0.001200
# 10                                       advanced_drtg               0.001143
# 18                                    advanced_blk_pct               0.001090
# 101  offensive_four_factors_tov_pct_by_team_travel_...               0.001081
# 51    defensive_four_factors_tov_pct_by_team_home_away               0.001010
# 22                      defensive_four_factors_tov_pct               0.000982
# 65                   advanced_drtg_by_team_day_of_week               0.000936
# 24                   defensive_four_factors_ft_per_fga               0.000916
#
#      opp_score_importance
# 9                0.001860
# 27               0.002426
# 11               0.080030
# 14               0.001539
# 26               0.001566
# 19               0.004165
# 4                0.000915
# 79               0.000753
# 66               0.002547
# 68               0.000196
# 7                0.000798
# 17               0.001621
# 23               0.000815
# 10               0.842567
# 18               0.000540
# 101              0.000469
# 51               0.000382
# 22               0.000694
# 65               0.000751
# 24               0.002101

# %%
# show all or more of the ranked features
importances_df.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.789104
# 27                   team_vs_opp_homeaway_median_score               0.071171
# 11                                       advanced_pace               0.063676
# 14                                     advanced_ts_pct               0.008506
# 26                            team_vs_opp_median_score               0.004471
# 19                      offensive_four_factors_tov_pct               0.003621
# 4                                          team_3p_pct               0.002133
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.002000
# 66                   advanced_pace_by_team_day_of_week               0.001366
# 68                   advanced_3par_by_team_day_of_week               0.001342
# 7                                      opponent_3p_pct               0.001297
# 17                                    advanced_stl_pct               0.001242
# 23                      defensive_four_factors_drb_pct               0.001200
# 10                                       advanced_drtg               0.001143
# 18                                    advanced_blk_pct               0.001090
# 101  offensive_four_factors_tov_pct_by_team_travel_...               0.001081
# 51    defensive_four_factors_tov_pct_by_team_home_away               0.001010
# 22                      defensive_four_factors_tov_pct               0.000982
# 65                   advanced_drtg_by_team_day_of_week               0.000936
# 24                   defensive_four_factors_ft_per_fga               0.000916
# 98            advanced_ast_pct_by_team_travel_distance               0.000902
# 15                                    advanced_trb_pct               0.000891
# 16                                    advanced_ast_pct               0.000884
# 12                                        advanced_ftr               0.000871
# 20                      offensive_four_factors_orb_pct               0.000849
# 83   team_home_or_away_median_score_by_team_day_of_...               0.000844
# 39                     advanced_pace_by_team_home_away               0.000840
# 73                advanced_blk_pct_by_team_day_of_week               0.000829
# 0                                                month               0.000807
# 21                      defensive_four_factors_efg_pct               0.000796
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.000780
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.000762
# 69                 advanced_ts_pct_by_team_day_of_week               0.000746
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.000745
# 30                             team_day_median_allowed               0.000742
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.000684
# 100           advanced_blk_pct_by_team_travel_distance               0.000676
# 71                advanced_ast_pct_by_team_day_of_week               0.000672
# 47    offensive_four_factors_tov_pct_by_team_home_away               0.000643
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000626
# 106  defensive_four_factors_drb_pct_by_team_travel_...               0.000620
# 5                                          team_ft_pct               0.000617
# 61                             day_by_team_day_of_week               0.000605
# 6                                      opponent_fg_pct               0.000596
# 86            median_score_against_by_team_day_of_week               0.000589
# 93               advanced_pace_by_team_travel_distance               0.000563
# 8                                      opponent_ft_pct               0.000562
# 13                                       advanced_3par               0.000555
# 95               advanced_3par_by_team_travel_distance               0.000553
# 88                         day_by_team_travel_distance               0.000552
#
#      opp_score_importance
# 9                0.001860
# 27               0.002426
# 11               0.080030
# 14               0.001539
# 26               0.001566
# 19               0.004165
# 4                0.000915
# 79               0.000753
# 66               0.002547
# 68               0.000196
# 7                0.000798
# 17               0.001621
# 23               0.000815
# 10               0.842567
# 18               0.000540
# 101              0.000469
# 51               0.000382
# 22               0.000694
# 65               0.000751
# 24               0.002101
# 98               0.000608
# 15               0.000631
# 16               0.001106
# 12               0.001001
# 20               0.001407
# 83               0.000312
# 39               0.001355
# 73               0.000358
# 0                0.000590
# 21               0.004106
# 104              0.000536
# 82               0.000801
# 69               0.000650
# 105              0.000210
# 30               0.000534
# 77               0.000518
# 100              0.000274
# 71               0.001165
# 47               0.000169
# 76               0.001095
# 106              0.000350
# 5                0.000708
# 61               0.000939
# 6                0.008254
# 86               0.000355
# 93               0.001114
# 8                0.000777
# 13               0.000644
# 95               0.000472
# 88               0.000215

# %%
# show all or more of the ranked features
importances_df.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.001143
# 11                                       advanced_pace               0.063676
# 6                                      opponent_fg_pct               0.000596
# 19                      offensive_four_factors_tov_pct               0.003621
# 21                      defensive_four_factors_efg_pct               0.000796
# 66                   advanced_pace_by_team_day_of_week               0.001366
# 27                   team_vs_opp_homeaway_median_score               0.071171
# 24                   defensive_four_factors_ft_per_fga               0.000916
# 9                                        advanced_ortg               0.789104
# 17                                    advanced_stl_pct               0.001242
# 26                            team_vs_opp_median_score               0.004471
# 14                                     advanced_ts_pct               0.008506
# 20                      offensive_four_factors_orb_pct               0.000849
# 39                     advanced_pace_by_team_home_away               0.000840
# 71                advanced_ast_pct_by_team_day_of_week               0.000672
# 93               advanced_pace_by_team_travel_distance               0.000563
# 16                                    advanced_ast_pct               0.000884
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000626
# 85                median_score_for_by_team_day_of_week               0.000273
# 12                                        advanced_ftr               0.000871
# 61                             day_by_team_day_of_week               0.000605
# 33                                median_score_against               0.000408
# 4                                          team_3p_pct               0.002133
# 67                    advanced_ftr_by_team_day_of_week               0.000543
# 92               advanced_drtg_by_team_travel_distance               0.000320
# 23                      defensive_four_factors_drb_pct               0.001200
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.000762
# 7                                      opponent_3p_pct               0.001297
# 8                                      opponent_ft_pct               0.000562
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.002000
# 65                   advanced_drtg_by_team_day_of_week               0.000936
# 1                                                  day               0.000479
# 5                                          team_ft_pct               0.000617
# 81        team_vs_opp_median_score_by_team_day_of_week               0.000292
# 22                      defensive_four_factors_tov_pct               0.000982
# 72                advanced_stl_pct_by_team_day_of_week               0.000272
# 48    offensive_four_factors_orb_pct_by_team_home_away               0.000395
# 69                 advanced_ts_pct_by_team_day_of_week               0.000746
# 96             advanced_ts_pct_by_team_travel_distance               0.000328
# 13                                       advanced_3par               0.000555
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.000409
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.000537
# 15                                    advanced_trb_pct               0.000891
# 98            advanced_ast_pct_by_team_travel_distance               0.000902
# 0                                                month               0.000807
# 50    defensive_four_factors_efg_pct_by_team_home_away               0.000378
# 18                                    advanced_blk_pct               0.001090
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.000381
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.000780
# 30                             team_day_median_allowed               0.000742
#
#      opp_score_importance
# 10               0.842567
# 11               0.080030
# 6                0.008254
# 19               0.004165
# 21               0.004106
# 66               0.002547
# 27               0.002426
# 24               0.002101
# 9                0.001860
# 17               0.001621
# 26               0.001566
# 14               0.001539
# 20               0.001407
# 39               0.001355
# 71               0.001165
# 93               0.001114
# 16               0.001106
# 76               0.001095
# 85               0.001066
# 12               0.001001
# 61               0.000939
# 33               0.000927
# 4                0.000915
# 67               0.000896
# 92               0.000853
# 23               0.000815
# 82               0.000801
# 7                0.000798
# 8                0.000777
# 79               0.000753
# 65               0.000751
# 1                0.000735
# 5                0.000708
# 81               0.000702
# 22               0.000694
# 72               0.000666
# 48               0.000660
# 69               0.000650
# 96               0.000649
# 13               0.000644
# 75               0.000639
# 80               0.000635
# 15               0.000631
# 98               0.000608
# 0                0.000590
# 50               0.000549
# 18               0.000540
# 78               0.000539
# 104              0.000536
# 30               0.000534

# %%
from google.colab import files
df.to_csv("wnba_model_ready_v1.csv", index=False)
files.download("wnba_model_ready_v1.csv")

# %%
from google.colab import files
# save feature importances
importances_df.to_csv("league_importances.csv", index=False)
files.download("league_importances.csv")

# %%
# Create ATL data subset
df_atl = df[df['team'] == 'ATL'].copy()

# define features and target
features_atl = df_atl.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_atl = df_atl[['team_score', 'opp_score']]

# %%
X_train, X_test, y_train, y_test = train_test_split(features_atl, targets_atl, test_size=0.2, random_state=42)

model_atl = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_atl.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(random_state=42))

# %%
importances_atl = pd.DataFrame({
    'feature': features_atl.columns,
    'team_score_importance': model_atl.estimators_[0].feature_importances_,
    'opp_score_importance': model_atl.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

importances_atl.head(20)
# Out:
#                               feature  team_score_importance  \
# 14                    advanced_ts_pct               0.450337
# 9                       advanced_ortg               0.251102
# 19     offensive_four_factors_tov_pct               0.053520
# 16                   advanced_ast_pct               0.018078
# 20     offensive_four_factors_orb_pct               0.017525
# 27  team_vs_opp_homeaway_median_score               0.017474
# 7                     opponent_3p_pct               0.017239
# 10                      advanced_drtg               0.013249
# 8                     opponent_ft_pct               0.012864
# 4                         team_3p_pct               0.012468
# 1                                 day               0.010692
# 12                       advanced_ftr               0.010029
# 24  defensive_four_factors_ft_per_fga               0.009664
# 17                   advanced_stl_pct               0.009164
# 15                   advanced_trb_pct               0.008807
# 21     defensive_four_factors_efg_pct               0.008195
# 18                   advanced_blk_pct               0.007143
# 13                      advanced_3par               0.005450
# 5                         team_ft_pct               0.004781
# 61            day_by_team_day_of_week               0.004315
#
#     opp_score_importance
# 14              0.004531
# 9               0.012536
# 19              0.020985
# 16              0.007542
# 20              0.011316
# 27              0.003593
# 7               0.002882
# 10              0.641198
# 8               0.001647
# 4               0.003753
# 1               0.007123
# 12              0.011276
# 24              0.006037
# 17              0.033740
# 15              0.006551
# 21              0.009751
# 18              0.007338
# 13              0.004029
# 5               0.007327
# 61              0.001114

# %%
# show all or more of the ranked features
importances_atl.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 14                                     advanced_ts_pct               0.450337
# 9                                        advanced_ortg               0.251102
# 19                      offensive_four_factors_tov_pct               0.053520
# 16                                    advanced_ast_pct               0.018078
# 20                      offensive_four_factors_orb_pct               0.017525
# 27                   team_vs_opp_homeaway_median_score               0.017474
# 7                                      opponent_3p_pct               0.017239
# 10                                       advanced_drtg               0.013249
# 8                                      opponent_ft_pct               0.012864
# 4                                          team_3p_pct               0.012468
# 1                                                  day               0.010692
# 12                                        advanced_ftr               0.010029
# 24                   defensive_four_factors_ft_per_fga               0.009664
# 17                                    advanced_stl_pct               0.009164
# 15                                    advanced_trb_pct               0.008807
# 21                      defensive_four_factors_efg_pct               0.008195
# 18                                    advanced_blk_pct               0.007143
# 13                                       advanced_3par               0.005450
# 5                                          team_ft_pct               0.004781
# 61                             day_by_team_day_of_week               0.004315
# 23                      defensive_four_factors_drb_pct               0.004095
# 6                                      opponent_fg_pct               0.003872
# 70                advanced_trb_pct_by_team_day_of_week               0.003329
# 29                               team_day_median_score               0.002833
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.002738
# 22                      defensive_four_factors_tov_pct               0.002706
# 73                advanced_blk_pct_by_team_day_of_week               0.002540
# 26                            team_vs_opp_median_score               0.002024
# 60                           month_by_team_day_of_week               0.001833
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.001776
# 91               advanced_ortg_by_team_travel_distance               0.001608
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.001596
# 81        team_vs_opp_median_score_by_team_day_of_week               0.001548
# 107  defensive_four_factors_ft_per_fga_by_team_trav...               0.001541
# 69                 advanced_ts_pct_by_team_day_of_week               0.001483
# 67                    advanced_ftr_by_team_day_of_week               0.001428
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.001414
# 88                         day_by_team_travel_distance               0.001403
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.001309
# 66                   advanced_pace_by_team_day_of_week               0.001209
# 11                                       advanced_pace               0.001110
# 64                   advanced_ortg_by_team_day_of_week               0.000932
# 72                advanced_stl_pct_by_team_day_of_week               0.000796
# 30                             team_day_median_allowed               0.000684
# 71                advanced_ast_pct_by_team_day_of_week               0.000630
# 3                                             win_loss               0.000540
# 62                       home_away_by_team_day_of_week               0.000538
# 65                   advanced_drtg_by_team_day_of_week               0.000529
# 96             advanced_ts_pct_by_team_travel_distance               0.000447
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000398
#
#      opp_score_importance
# 14               0.004531
# 9                0.012536
# 19               0.020985
# 16               0.007542
# 20               0.011316
# 27               0.003593
# 7                0.002882
# 10               0.641198
# 8                0.001647
# 4                0.003753
# 1                0.007123
# 12               0.011276
# 24               0.006037
# 17               0.033740
# 15               0.006551
# 21               0.009751
# 18               0.007338
# 13               0.004029
# 5                0.007327
# 61               0.001114
# 23               0.001970
# 6                0.046115
# 70               0.002307
# 29               0.002372
# 82               0.003767
# 22               0.008346
# 73               0.001176
# 26               0.002345
# 60               0.000586
# 75               0.005690
# 91               0.000158
# 80               0.000432
# 81               0.005298
# 107              0.000601
# 69               0.000875
# 67               0.000987
# 78               0.001811
# 88               0.000030
# 104              0.000083
# 66               0.000802
# 11               0.048323
# 64               0.000546
# 72               0.001222
# 30               0.000163
# 71               0.000720
# 3                0.005910
# 62               0.001036
# 65               0.000434
# 96               0.000211
# 76               0.001898

# %%
# show all or more of the ranked features
importances_atl.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.013249
# 11                                       advanced_pace               0.001110
# 6                                      opponent_fg_pct               0.003872
# 17                                    advanced_stl_pct               0.009164
# 0                                                month               0.000360
# 19                      offensive_four_factors_tov_pct               0.053520
# 9                                        advanced_ortg               0.251102
# 20                      offensive_four_factors_orb_pct               0.017525
# 12                                        advanced_ftr               0.010029
# 21                      defensive_four_factors_efg_pct               0.008195
# 22                      defensive_four_factors_tov_pct               0.002706
# 16                                    advanced_ast_pct               0.018078
# 18                                    advanced_blk_pct               0.007143
# 5                                          team_ft_pct               0.004781
# 1                                                  day               0.010692
# 15                                    advanced_trb_pct               0.008807
# 24                   defensive_four_factors_ft_per_fga               0.009664
# 3                                             win_loss               0.000540
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.001776
# 81        team_vs_opp_median_score_by_team_day_of_week               0.001548
# 14                                     advanced_ts_pct               0.450337
# 13                                       advanced_3par               0.005450
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.002738
# 4                                          team_3p_pct               0.012468
# 27                   team_vs_opp_homeaway_median_score               0.017474
# 7                                      opponent_3p_pct               0.017239
# 68                   advanced_3par_by_team_day_of_week               0.000255
# 29                               team_day_median_score               0.002833
# 26                            team_vs_opp_median_score               0.002024
# 70                advanced_trb_pct_by_team_day_of_week               0.003329
# 23                      defensive_four_factors_drb_pct               0.004095
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000398
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.001414
# 106  defensive_four_factors_drb_pct_by_team_travel_...               0.000090
# 8                                      opponent_ft_pct               0.012864
# 37                     advanced_ortg_by_team_home_away               0.000367
# 72                advanced_stl_pct_by_team_day_of_week               0.000796
# 73                advanced_blk_pct_by_team_day_of_week               0.002540
# 61                             day_by_team_day_of_week               0.004315
# 62                       home_away_by_team_day_of_week               0.000538
# 108                day_of_week_by_team_travel_distance               0.000104
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.000152
# 67                    advanced_ftr_by_team_day_of_week               0.001428
# 94                advanced_ftr_by_team_travel_distance               0.000080
# 69                 advanced_ts_pct_by_team_day_of_week               0.001483
# 66                   advanced_pace_by_team_day_of_week               0.001209
# 55          team_vs_opp_median_score_by_team_home_away               0.000095
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.000283
# 71                advanced_ast_pct_by_team_day_of_week               0.000630
# 98            advanced_ast_pct_by_team_travel_distance               0.000185
#
#      opp_score_importance
# 10               0.641198
# 11               0.048323
# 6                0.046115
# 17               0.033740
# 0                0.026202
# 19               0.020985
# 9                0.012536
# 20               0.011316
# 12               0.011276
# 21               0.009751
# 22               0.008346
# 16               0.007542
# 18               0.007338
# 5                0.007327
# 1                0.007123
# 15               0.006551
# 24               0.006037
# 3                0.005910
# 75               0.005690
# 81               0.005298
# 14               0.004531
# 13               0.004029
# 82               0.003767
# 4                0.003753
# 27               0.003593
# 7                0.002882
# 68               0.002501
# 29               0.002372
# 26               0.002345
# 70               0.002307
# 23               0.001970
# 76               0.001898
# 78               0.001811
# 106              0.001777
# 8                0.001647
# 37               0.001490
# 72               0.001222
# 73               0.001176
# 61               0.001114
# 62               0.001036
# 108              0.001030
# 105              0.001008
# 67               0.000987
# 94               0.000888
# 69               0.000875
# 66               0.000802
# 55               0.000749
# 74               0.000731
# 71               0.000720
# 98               0.000646

# %%
from google.colab import files
# save feature importances
importances_df.to_csv("atl_importances.csv", index=False)
files.download("atl_importances.csv")
