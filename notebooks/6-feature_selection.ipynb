# %%
# Clone your GitHub repo (you’ll be prompted to authorize if it's private)
# !git clone https://github.com/colterwood/LHL-final-final-project.git
# Out:
# Cloning into 'LHL-final-final-project'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 131 (delta 70), reused 23 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (131/131), 1.33 MiB | 2.28 MiB/s, done.
# Resolving deltas: 100% (70/70), done.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GroupShuffleSplit
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split

# %%
# load the player game logs CSV from the data folder
df = pd.read_csv("LHL-final-final-project/data/2024_merged_gamelogs.csv")


# preview
df.head()
# Out:
#   team  g_num  month  day  home_away  opp  win_loss  team_score  opp_score  \
# 0  ATL      1      5   15          2  LAS         1          92         81
# 1  ATL      2      5   18          2  PHO         2          85         88
# 2  ATL      3      5   21          1  DAL         1          83         78
# 3  ATL      4      5   26          1  MIN         2          79         92
# 4  ATL      5      5   29          2  WAS         1          73         67
#
#    team_fg  ...  day_of_week_by_team_travel_distance  \
# 0       34  ...                                  3.0
# 1       27  ...                                  2.0
# 2       30  ...                                  4.0
# 3       31  ...                                  3.0
# 4       26  ...                                  4.0
#
#    team_vs_opp_median_score_by_team_travel_distance  \
# 0                                              75.0
# 1                                              76.0
# 2                                              81.0
# 3                                              75.0
# 4                                              75.0
#
#    team_vs_opp_homeaway_median_score_by_team_travel_distance  \
# 0                                               70.0
# 1                                               76.0
# 2                                               75.5
# 3                                               70.0
# 4                                               76.5
#
#    team_home_or_away_median_score_by_team_travel_distance  \
# 0                                               78.5
# 1                                               78.0
# 2                                               78.0
# 3                                               78.5
# 4                                               78.0
#
#    team_home_or_away_median_allowed_by_team_travel_distance  \
# 0                                               79.5
# 1                                               80.5
# 2                                               80.5
# 3                                               79.5
# 4                                               80.5
#
#    team_day_median_score_by_team_travel_distance  \
# 0                                           76.0
# 1                                           76.0
# 2                                           73.0
# 3                                           76.0
# 4                                           76.0
#
#    team_day_median_allowed_by_team_travel_distance  \
# 0                                             80.0
# 1                                             80.0
# 2                                             78.0
# 3                                             80.0
# 4                                             80.0
#
#    travel_distance_by_team_travel_distance  \
# 0                                      0.0
# 1                                      1.0
# 2                                      3.0
# 3                                      0.0
# 4                                      2.0
#
#    median_score_for_by_team_travel_distance  \
# 0                                      77.0
# 1                                      77.5
# 2                                      81.0
# 3                                      77.0
# 4                                      78.0
#
#    median_score_against_by_team_travel_distance
# 0                                          79.5
# 1                                          77.5
# 2                                          85.0
# 3                                          79.5
# 4                                          80.0
#
# [5 rows x 261 columns]

# %%
# features (drop identifiers and targets)
features = df.drop(columns=['team_score', 'opp_score', 'team', 'opp'])

# targets
targets = df[['team_score', 'opp_score']]

# group-aware split
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, test_idx = next(gss.split(features, groups=df['team']))

X_train = features.iloc[train_idx]
X_test = features.iloc[test_idx]
y_train = targets.iloc[train_idx]
y_test = targets.iloc[test_idx]

# model
model = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(random_state=42))

# %%
# get feature importances for team_score prediction
team_score_importance = model.estimators_[0].feature_importances_

# get feature importances for opp_score prediction
opp_score_importance = model.estimators_[1].feature_importances_

# match to feature names
feature_names = features.columns

# build DataFrame
importances_df = (
    pd.DataFrame({
        'feature': feature_names,
        'team_score_importance': team_score_importance,
        'opp_score_importance': opp_score_importance
    })
    .sort_values(by='team_score_importance', ascending=False)
)

importances_df.head(20)  # or whatever number you want to view
# Out:
#                                feature  team_score_importance  \
# 37                       advanced_ortg               0.771811
# 57   team_vs_opp_homeaway_median_score               0.063060
# 39                       advanced_pace               0.051088
# 5                              team_fg               0.028227
# 42                     advanced_ts_pct               0.005816
# 56            team_vs_opp_median_score               0.004108
# 16                            team_ast               0.003441
# 19                            team_tov               0.002953
# 7                          team_fg_pct               0.002157
# 33                        opponent_stl               0.001959
# 47      offensive_four_factors_efg_pct               0.001730
# 21                         opponent_fg               0.001408
# 22                        opponent_fga               0.001393
# 17                            team_stl               0.001365
# 11                             team_ft               0.001081
# 12                            team_fta               0.000945
# 167  advanced_pace_by_team_day_of_week               0.000938
# 25                        opponent_3pa               0.000878
# 10                         team_3p_pct               0.000869
# 50   offensive_four_factors_ft_per_fga               0.000852
#
#      opp_score_importance
# 37               0.000807
# 57               0.001122
# 39               0.068585
# 5                0.001548
# 42               0.000612
# 56               0.000472
# 16               0.000471
# 19               0.001352
# 7                0.000643
# 33               0.001807
# 47               0.000350
# 21               0.067323
# 22               0.000882
# 17               0.001874
# 11               0.000272
# 12               0.000445
# 167              0.001041
# 25               0.000443
# 10               0.000555
# 50               0.000309

# %%
# show all or more of the ranked features
importances_df.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 37                                       advanced_ortg               0.771811
# 57                   team_vs_opp_homeaway_median_score               0.063060
# 39                                       advanced_pace               0.051088
# 5                                              team_fg               0.028227
# 42                                     advanced_ts_pct               0.005816
# 56                            team_vs_opp_median_score               0.004108
# 16                                            team_ast               0.003441
# 19                                            team_tov               0.002953
# 7                                          team_fg_pct               0.002157
# 33                                        opponent_stl               0.001959
# 47                      offensive_four_factors_efg_pct               0.001730
# 21                                         opponent_fg               0.001408
# 22                                        opponent_fga               0.001393
# 17                                            team_stl               0.001365
# 11                                             team_ft               0.001081
# 12                                            team_fta               0.000945
# 167                  advanced_pace_by_team_day_of_week               0.000938
# 25                                        opponent_3pa               0.000878
# 10                                         team_3p_pct               0.000869
# 50                   offensive_four_factors_ft_per_fga               0.000852
# 154                opponent_3p_pct_by_team_day_of_week               0.000828
# 6                                             team_fga               0.000819
# 40                                        advanced_ftr               0.000808
# 8                                              team_3p               0.000803
# 15                                            team_trb               0.000768
# 26                                     opponent_3p_pct               0.000724
# 0                                                g_num               0.000709
# 35                                        opponent_tov               0.000667
# 29                                     opponent_ft_pct               0.000647
# 93                   opponent_ft_pct_by_team_home_away               0.000630
# 213                opponent_fg_by_team_travel_distance               0.000606
# 44                                    advanced_ast_pct               0.000563
# 174               advanced_blk_pct_by_team_day_of_week               0.000554
# 181  defensive_four_factors_drb_pct_by_team_day_of_...               0.000553
# 27                                         opponent_ft               0.000547
# 185  team_vs_opp_homeaway_median_score_by_team_day_...               0.000537
# 186  team_home_or_away_median_score_by_team_day_of_...               0.000531
# 18                                            team_blk               0.000518
# 201                   team_3pa_by_team_travel_distance               0.000509
# 13                                         team_ft_pct               0.000483
# 52                      defensive_four_factors_tov_pct               0.000469
# 170                advanced_ts_pct_by_team_day_of_week               0.000465
# 133                        team_fg_by_team_day_of_week               0.000462
# 218            opponent_3p_pct_by_team_travel_distance               0.000461
# 130                            day_by_team_day_of_week               0.000460
# 166                  advanced_drtg_by_team_day_of_week               0.000452
# 34                                        opponent_blk               0.000451
# 138                    team_3p_pct_by_team_day_of_week               0.000442
# 30                                        opponent_orb               0.000434
# 231              advanced_pace_by_team_travel_distance               0.000433
#
#      opp_score_importance
# 37               0.000807
# 57               0.001122
# 39               0.068585
# 5                0.001548
# 42               0.000612
# 56               0.000472
# 16               0.000471
# 19               0.001352
# 7                0.000643
# 33               0.001807
# 47               0.000350
# 21               0.067323
# 22               0.000882
# 17               0.001874
# 11               0.000272
# 12               0.000445
# 167              0.001041
# 25               0.000443
# 10               0.000555
# 50               0.000309
# 154              0.000283
# 6                0.000608
# 40               0.000417
# 8                0.000504
# 15               0.000206
# 26               0.000580
# 0                0.000813
# 35               0.000263
# 29               0.000633
# 93               0.000149
# 213              0.000244
# 44               0.000572
# 174              0.000201
# 181              0.000432
# 27               0.002232
# 185              0.000400
# 186              0.000275
# 18               0.000216
# 201              0.000086
# 13               0.000423
# 52               0.000292
# 170              0.000219
# 133              0.000076
# 218              0.000727
# 130              0.000364
# 166              0.000323
# 34               0.000280
# 138              0.000189
# 30               0.000294
# 231              0.000613

# %%
# show all or more of the ranked features
importances_df.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 38                                       advanced_drtg               0.000367
# 39                                       advanced_pace               0.051088
# 21                                         opponent_fg               0.001408
# 23                                     opponent_fg_pct               0.000315
# 51                      defensive_four_factors_efg_pct               0.000313
# 27                                         opponent_ft               0.000547
# 17                                            team_stl               0.001365
# 33                                        opponent_stl               0.001959
# 5                                              team_fg               0.028227
# 19                                            team_tov               0.002953
# 54                   defensive_four_factors_ft_per_fga               0.000251
# 24                                         opponent_3p               0.000351
# 57                   team_vs_opp_homeaway_median_score               0.063060
# 167                  advanced_pace_by_team_day_of_week               0.000938
# 49                      offensive_four_factors_orb_pct               0.000428
# 22                                        opponent_fga               0.001393
# 0                                                g_num               0.000709
# 37                                       advanced_ortg               0.771811
# 28                                        opponent_fta               0.000355
# 103                    advanced_pace_by_team_home_away               0.000423
# 218            opponent_3p_pct_by_team_travel_distance               0.000461
# 32                                        opponent_ast               0.000336
# 172               advanced_ast_pct_by_team_day_of_week               0.000351
# 7                                          team_fg_pct               0.002157
# 86                      opponent_fga_by_team_home_away               0.000130
# 29                                     opponent_ft_pct               0.000647
# 191               median_score_for_by_team_day_of_week               0.000134
# 231              advanced_pace_by_team_travel_distance               0.000433
# 42                                     advanced_ts_pct               0.005816
# 6                                             team_fga               0.000819
# 26                                     opponent_3p_pct               0.000724
# 44                                    advanced_ast_pct               0.000563
# 10                                         team_3p_pct               0.000869
# 256       median_score_against_by_team_travel_distance               0.000152
# 192           median_score_against_by_team_day_of_week               0.000218
# 8                                              team_3p               0.000803
# 216                opponent_3p_by_team_travel_distance               0.000364
# 159                   opponent_trb_by_team_day_of_week               0.000104
# 20                                             team_pf               0.000265
# 230              advanced_drtg_by_team_travel_distance               0.000119
# 56                            team_vs_opp_median_score               0.004108
# 16                                            team_ast               0.003441
# 48                      offensive_four_factors_tov_pct               0.000329
# 153                   opponent_3pa_by_team_day_of_week               0.000350
# 12                                            team_fta               0.000945
# 25                                        opponent_3pa               0.000878
# 181  defensive_four_factors_drb_pct_by_team_day_of_...               0.000553
# 13                                         team_ft_pct               0.000483
# 53                      defensive_four_factors_drb_pct               0.000248
# 40                                        advanced_ftr               0.000808
#
#      opp_score_importance
# 38               0.786820
# 39               0.068585
# 21               0.067323
# 23               0.007825
# 51               0.002968
# 27               0.002232
# 17               0.001874
# 33               0.001807
# 5                0.001548
# 19               0.001352
# 54               0.001136
# 24               0.001135
# 57               0.001122
# 167              0.001041
# 49               0.001009
# 22               0.000882
# 0                0.000813
# 37               0.000807
# 28               0.000807
# 103              0.000753
# 218              0.000727
# 32               0.000726
# 172              0.000673
# 7                0.000643
# 86               0.000636
# 29               0.000633
# 191              0.000617
# 231              0.000613
# 42               0.000612
# 6                0.000608
# 26               0.000580
# 44               0.000572
# 10               0.000555
# 256              0.000552
# 192              0.000515
# 8                0.000504
# 216              0.000493
# 159              0.000481
# 20               0.000476
# 230              0.000472
# 56               0.000472
# 16               0.000471
# 48               0.000453
# 153              0.000451
# 12               0.000445
# 25               0.000443
# 181              0.000432
# 13               0.000423
# 53               0.000419
# 40               0.000417

# %%
# define substrings that identify counting stats
counting_keywords = ['fg', 'fga', '3p', '3pa', 'ft', 'fta', 'orb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf']

# drop columns where the name contains any of those keywords but NOT pct or rate stats
counting_cols = [col for col in df.columns if any(k in col for k in counting_keywords)
                 and not col.endswith('_pct')
                 and 'four_factors' not in col
                 and 'advanced' not in col
                 and col not in ['team_score', 'opp_score']]

# %%
print(counting_cols)
# Out:
# ['team_fg', 'team_fga', 'team_3p', 'team_3pa', 'team_ft', 'team_fta', 'team_orb', 'team_trb', 'team_ast', 'team_stl', 'team_blk', 'team_tov', 'team_pf', 'opponent_fg', 'opponent_fga', 'opponent_3p', 'opponent_3pa', 'opponent_ft', 'opponent_fta', 'opponent_orb', 'opponent_trb', 'opponent_ast', 'opponent_stl', 'opponent_blk', 'opponent_tov', 'opponent_pf', 'team_fg_by_team_home_away', 'team_fga_by_team_home_away', 'team_fg_pct_by_team_home_away', 'team_3p_by_team_home_away', 'team_3pa_by_team_home_away', 'team_3p_pct_by_team_home_away', 'team_ft_by_team_home_away', 'team_fta_by_team_home_away', 'team_ft_pct_by_team_home_away', 'team_orb_by_team_home_away', 'team_trb_by_team_home_away', 'team_ast_by_team_home_away', 'team_stl_by_team_home_away', 'team_blk_by_team_home_away', 'team_tov_by_team_home_away', 'team_pf_by_team_home_away', 'opponent_fg_by_team_home_away', 'opponent_fga_by_team_home_away', 'opponent_fg_pct_by_team_home_away', 'opponent_3p_by_team_home_away', 'opponent_3pa_by_team_home_away', 'opponent_3p_pct_by_team_home_away', 'opponent_ft_by_team_home_away', 'opponent_fta_by_team_home_away', 'opponent_ft_pct_by_team_home_away', 'opponent_orb_by_team_home_away', 'opponent_trb_by_team_home_away', 'opponent_ast_by_team_home_away', 'opponent_stl_by_team_home_away', 'opponent_blk_by_team_home_away', 'opponent_tov_by_team_home_away', 'opponent_pf_by_team_home_away', 'team_fg_by_team_day_of_week', 'team_fga_by_team_day_of_week', 'team_fg_pct_by_team_day_of_week', 'team_3p_by_team_day_of_week', 'team_3pa_by_team_day_of_week', 'team_3p_pct_by_team_day_of_week', 'team_ft_by_team_day_of_week', 'team_fta_by_team_day_of_week', 'team_ft_pct_by_team_day_of_week', 'team_orb_by_team_day_of_week', 'team_trb_by_team_day_of_week', 'team_ast_by_team_day_of_week', 'team_stl_by_team_day_of_week', 'team_blk_by_team_day_of_week', 'team_tov_by_team_day_of_week', 'team_pf_by_team_day_of_week', 'opponent_fg_by_team_day_of_week', 'opponent_fga_by_team_day_of_week', 'opponent_fg_pct_by_team_day_of_week', 'opponent_3p_by_team_day_of_week', 'opponent_3pa_by_team_day_of_week', 'opponent_3p_pct_by_team_day_of_week', 'opponent_ft_by_team_day_of_week', 'opponent_fta_by_team_day_of_week', 'opponent_ft_pct_by_team_day_of_week', 'opponent_orb_by_team_day_of_week', 'opponent_trb_by_team_day_of_week', 'opponent_ast_by_team_day_of_week', 'opponent_stl_by_team_day_of_week', 'opponent_blk_by_team_day_of_week', 'opponent_tov_by_team_day_of_week', 'opponent_pf_by_team_day_of_week', 'team_fg_by_team_travel_distance', 'team_fga_by_team_travel_distance', 'team_fg_pct_by_team_travel_distance', 'team_3p_by_team_travel_distance', 'team_3pa_by_team_travel_distance', 'team_3p_pct_by_team_travel_distance', 'team_ft_by_team_travel_distance', 'team_fta_by_team_travel_distance', 'team_ft_pct_by_team_travel_distance', 'team_orb_by_team_travel_distance', 'team_trb_by_team_travel_distance', 'team_ast_by_team_travel_distance', 'team_stl_by_team_travel_distance', 'team_blk_by_team_travel_distance', 'team_tov_by_team_travel_distance', 'team_pf_by_team_travel_distance', 'opponent_fg_by_team_travel_distance', 'opponent_fga_by_team_travel_distance', 'opponent_fg_pct_by_team_travel_distance', 'opponent_3p_by_team_travel_distance', 'opponent_3pa_by_team_travel_distance', 'opponent_3p_pct_by_team_travel_distance', 'opponent_ft_by_team_travel_distance', 'opponent_fta_by_team_travel_distance', 'opponent_ft_pct_by_team_travel_distance', 'opponent_orb_by_team_travel_distance', 'opponent_trb_by_team_travel_distance', 'opponent_ast_by_team_travel_distance', 'opponent_stl_by_team_travel_distance', 'opponent_blk_by_team_travel_distance', 'opponent_tov_by_team_travel_distance', 'opponent_pf_by_team_travel_distance']

# %%
df = df.drop(columns=counting_cols)

# %%
# make sure we only use numeric features (exclude targets and IDs)
X = df.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
X = X.select_dtypes(include='number')

# compute correlation matrix
corr_matrix = X.corr().abs()

# keep upper triangle only (to avoid duplicate pairs)
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# flatten and filter for high correlation pairs
high_corr_pairs = (
    upper.stack()
    .reset_index()
    .rename(columns={'level_0': 'feature_1', 'level_1': 'feature_2', 0: 'correlation'})
    .query('correlation > 0.9')
    .sort_values(by='correlation', ascending=False)
)

high_corr_pairs
# Out:
#                                               feature_1  \
# 436                                           home_away
# 3823                     team_home_or_away_median_score
# 3543                                        day_of_week
# 4058                              team_day_median_score
# 4484                               median_score_against
# 4387                                   median_score_for
# 4289                                    travel_distance
# 3925                   team_home_or_away_median_allowed
# 4158                            team_day_median_allowed
# 0                                                 g_num
# 2028                                    advanced_ts_pct
# 6769          team_day_median_allowed_by_team_home_away
# 6634  team_home_or_away_median_allowed_by_team_home_...
# 3930                   team_home_or_away_median_allowed
# 5280                    advanced_3par_by_team_home_away
# 6830          team_day_median_allowed_by_team_home_away
# 675                                         team_fg_pct
# 1060                                    opponent_fg_pct
# 3904                   team_home_or_away_median_allowed
# 4970                    advanced_drtg_by_team_home_away
# 3989                   team_home_or_away_median_allowed
# 6693  team_home_or_away_median_allowed_by_team_home_...
# 1794                                       advanced_ftr
# 3927                   team_home_or_away_median_allowed
# 6631  team_home_or_away_median_allowed_by_team_home_...
# 7025             median_score_against_by_team_home_away
# 6796          team_day_median_allowed_by_team_home_away
# 3957                   team_home_or_away_median_allowed
# 6661  team_home_or_away_median_allowed_by_team_home_...
# 7023             median_score_against_by_team_home_away
# 6991             median_score_against_by_team_home_away
# 8796            advanced_ts_pct_by_team_travel_distance
# 6828          team_day_median_allowed_by_team_home_away
# 6489  team_vs_opp_homeaway_median_score_by_team_home...
# 3822                     team_home_or_away_median_score
# 6762            team_day_median_score_by_team_home_away
# 670                                         team_fg_pct
# 5034                    advanced_drtg_by_team_home_away
# 8375  team_home_or_away_median_allowed_by_team_day_o...
# 7564                advanced_ts_pct_by_team_day_of_week
# 5308                  advanced_ts_pct_by_team_home_away
# 8373  team_home_or_away_median_allowed_by_team_day_o...
#
#                                               feature_2  correlation
# 436                         home_away_by_team_home_away     1.000000
# 3823   team_home_or_away_median_score_by_team_home_away     1.000000
# 3543                    day_of_week_by_team_day_of_week     1.000000
# 4058          team_day_median_score_by_team_day_of_week     1.000000
# 4484       median_score_against_by_team_travel_distance     1.000000
# 4387           median_score_for_by_team_travel_distance     1.000000
# 4289            travel_distance_by_team_travel_distance     1.000000
# 3925  team_home_or_away_median_allowed_by_team_home_...     1.000000
# 4158        team_day_median_allowed_by_team_day_of_week     1.000000
# 0                                                 month     0.974134
# 2028                     offensive_four_factors_efg_pct     0.962090
# 6769             median_score_against_by_team_home_away     0.956237
# 6634             median_score_against_by_team_home_away     0.953689
# 3930             median_score_against_by_team_home_away     0.953689
# 5280              advanced_3par_by_team_travel_distance     0.949303
# 6830    team_day_median_allowed_by_team_travel_distance     0.946778
# 675                      offensive_four_factors_efg_pct     0.945075
# 1060                     defensive_four_factors_efg_pct     0.945075
# 3904                    advanced_drtg_by_team_home_away     0.943072
# 4970  team_home_or_away_median_allowed_by_team_home_...     0.943072
# 3989  team_home_or_away_median_allowed_by_team_trave...     0.940094
# 6693  team_home_or_away_median_allowed_by_team_trave...     0.940094
# 1794                  offensive_four_factors_ft_per_fga     0.938536
# 3927          team_day_median_allowed_by_team_home_away     0.928641
# 6631          team_day_median_allowed_by_team_home_away     0.928641
# 7025    team_day_median_allowed_by_team_travel_distance     0.926846
# 6796  team_home_or_away_median_allowed_by_team_day_o...     0.926359
# 3957  team_home_or_away_median_allowed_by_team_day_o...     0.925752
# 6661  team_home_or_away_median_allowed_by_team_day_o...     0.925752
# 7023  team_home_or_away_median_allowed_by_team_trave...     0.923045
# 6991  team_home_or_away_median_allowed_by_team_day_o...     0.921508
# 8796  offensive_four_factors_efg_pct_by_team_travel_...     0.916892
# 6828  team_home_or_away_median_allowed_by_team_trave...     0.913808
# 6489   team_home_or_away_median_score_by_team_home_away     0.912328
# 3822  team_vs_opp_homeaway_median_score_by_team_home...     0.912328
# 6762      team_day_median_score_by_team_travel_distance     0.911558
# 670                                     advanced_ts_pct     0.910941
# 5034  team_home_or_away_median_allowed_by_team_trave...     0.905772
# 8375    team_day_median_allowed_by_team_travel_distance     0.905711
# 7564  offensive_four_factors_efg_pct_by_team_day_of_...     0.904420
# 5308   offensive_four_factors_efg_pct_by_team_home_away     0.903674
# 8373  team_home_or_away_median_allowed_by_team_trave...     0.903340

# %%
# always keep these no matter what
must_keep = ['advanced_ortg', 'advanced_drtg']

def auto_select_drops(high_corr_df):
    drop_cols = []

    for _, row in high_corr_df.iterrows():
        f1, f2 = row['feature_1'], row['feature_2']

        # skip if either feature is protected
        if f1 in must_keep or f2 in must_keep:
            continue

        # drop the more engineered-looking one
        if '_by_' in f1 or 'median' in f1:
            drop_cols.append(f1)
        elif '_by_' in f2 or 'median' in f2:
            drop_cols.append(f2)
        else:
            # fallback: drop longer one
            drop_cols.append(f1 if len(f1) > len(f2) else f2)

    return list(set(drop_cols))

# %%
# create drop list
auto_drop_cols = auto_select_drops(high_corr_pairs)

# %%
# View suggested drop list
print(auto_drop_cols)
# Out:
# ['team_day_median_allowed_by_team_home_away', 'advanced_ts_pct_by_team_travel_distance', 'median_score_against', 'team_day_median_score_by_team_home_away', 'team_day_median_allowed', 'offensive_four_factors_efg_pct', 'month', 'defensive_four_factors_efg_pct', 'offensive_four_factors_ft_per_fga', 'median_score_against_by_team_home_away', 'advanced_ts_pct_by_team_day_of_week', 'travel_distance_by_team_travel_distance', 'advanced_ts_pct', 'team_vs_opp_homeaway_median_score_by_team_home_away', 'day_of_week_by_team_day_of_week', 'team_home_or_away_median_allowed', 'advanced_3par_by_team_home_away', 'advanced_ts_pct_by_team_home_away', 'team_home_or_away_median_allowed_by_team_home_away', 'home_away_by_team_home_away', 'team_day_median_score', 'team_home_or_away_median_allowed_by_team_day_of_week', 'team_home_or_away_median_score', 'median_score_for', 'advanced_drtg_by_team_home_away']

# %%
# Manually built drop list
drop_list = [
    'home_away_by_team_home_away',
    'team_home_or_away_median_score_by_team_home_away',
    'day_of_week_by_team_day_of_week',
    'team_day_median_score_by_team_day_of_week',
    'median_score_against_by_team_travel_distance',
    'median_score_for_by_team_travel_distance',
    'travel_distance_by_team_travel_distance',
    'team_home_or_away_median_allowed_by_team_home_away',
    'team_day_median_allowed_by_team_day_of_week',
    'g_num',
    'offensive_four_factors_efg_pct',
    'team_day_median_allowed_by_team_home_away',
    'team_home_or_away_median_allowed_by_team_home_away',
    'team_home_or_away_median_allowed',
    'team_home_or_away_median_allowed_by_team_travel_distance',
    'offensive_four_factors_ft_per_fga',
    'team_day_median_allowed_by_team_home_away',
    'team_home_or_away_median_allowed_by_team_day_of_week',
    'offensive_four_factors_efg_pct_by_team_travel_distance',
    'team_home_or_away_median_score_by_team_home_away',
    'team_vs_opp_homeaway_median_score_by_team_home_away',
    'team_fg_pct',
    'offensive_four_factors_efg_pct_by_team_day_of_week',
    'offensive_four_factors_efg_pct_by_team_home_away'
]

# %%
# drop from df
df = df.drop(columns=drop_list, errors='ignore')

# %%
# filter to numeric features only (excluding IDs and targets)
X = df.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
X = X.select_dtypes(include='number')

# compute VIFs
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_data = vif_data.sort_values(by='VIF', ascending=False)

vif_data
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                                               feature       VIF
# 2                                           home_away       inf
# 49  offensive_four_factors_ft_per_fga_by_team_home...       inf
# 34                            month_by_team_home_away       inf
# 35                              day_by_team_home_away       inf
# 36                         win_loss_by_team_home_away       inf
# ..                                                ...       ...
# 16                                   advanced_ast_pct  1.842376
# 18                                   advanced_blk_pct  1.638229
# 5                                         team_ft_pct  1.480301
# 1                                                 day  1.472835
# 0                                               month  1.404025
#
# [114 rows x 2 columns]

# %%
X.corr()['home_away'].sort_values(ascending=False)
# Out:
# home_away                                              1.000000
# travel_distance_by_team_home_away                      0.807283
# home_away_by_team_travel_distance                      0.508346
# travel_distance                                        0.390108
# home_away_by_team_day_of_week                          0.323630
#                                                          ...
# advanced_ortg_by_team_home_away                       -0.217181
# offensive_four_factors_orb_pct_by_team_home_away      -0.227798
# defensive_four_factors_drb_pct_by_team_home_away      -0.253229
# offensive_four_factors_ft_per_fga_by_team_home_away   -0.295397
# advanced_trb_pct_by_team_home_away                    -0.321299
# Name: home_away, Length: 114, dtype: float64

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor

# define features and targets
features = df.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets = df[['team_score', 'opp_score']]

# stratified split by team
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, test_idx = next(gss.split(features, groups=df['team']))

X_train = features.iloc[train_idx]
X_test = features.iloc[test_idx]
y_train = targets.iloc[train_idx]
y_test = targets.iloc[test_idx]

# train model
model = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(random_state=42))

# %%
# get feature importances for team_score prediction
team_score_importance = model.estimators_[0].feature_importances_

# get feature importances for opp_score prediction
opp_score_importance = model.estimators_[1].feature_importances_

# match to feature names
feature_names = features.columns

# build DataFrame
importances_df = (
    pd.DataFrame({
        'feature': feature_names,
        'team_score_importance': team_score_importance,
        'opp_score_importance': opp_score_importance
    })
    .sort_values(by='team_score_importance', ascending=False)
)

importances_df.head(20)  # or whatever number you want to view
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.789104
# 27                   team_vs_opp_homeaway_median_score               0.071171
# 11                                       advanced_pace               0.063676
# 14                                     advanced_ts_pct               0.008506
# 26                            team_vs_opp_median_score               0.004471
# 19                      offensive_four_factors_tov_pct               0.003621
# 4                                          team_3p_pct               0.002133
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.002000
# 66                   advanced_pace_by_team_day_of_week               0.001366
# 68                   advanced_3par_by_team_day_of_week               0.001342
# 7                                      opponent_3p_pct               0.001297
# 17                                    advanced_stl_pct               0.001242
# 23                      defensive_four_factors_drb_pct               0.001200
# 10                                       advanced_drtg               0.001143
# 18                                    advanced_blk_pct               0.001090
# 101  offensive_four_factors_tov_pct_by_team_travel_...               0.001081
# 51    defensive_four_factors_tov_pct_by_team_home_away               0.001010
# 22                      defensive_four_factors_tov_pct               0.000982
# 65                   advanced_drtg_by_team_day_of_week               0.000936
# 24                   defensive_four_factors_ft_per_fga               0.000916
#
#      opp_score_importance
# 9                0.001860
# 27               0.002426
# 11               0.080030
# 14               0.001539
# 26               0.001566
# 19               0.004165
# 4                0.000915
# 79               0.000753
# 66               0.002547
# 68               0.000196
# 7                0.000798
# 17               0.001621
# 23               0.000815
# 10               0.842567
# 18               0.000540
# 101              0.000469
# 51               0.000382
# 22               0.000694
# 65               0.000751
# 24               0.002101

# %%
# show all or more of the ranked features
importances_df.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.789104
# 27                   team_vs_opp_homeaway_median_score               0.071171
# 11                                       advanced_pace               0.063676
# 14                                     advanced_ts_pct               0.008506
# 26                            team_vs_opp_median_score               0.004471
# 19                      offensive_four_factors_tov_pct               0.003621
# 4                                          team_3p_pct               0.002133
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.002000
# 66                   advanced_pace_by_team_day_of_week               0.001366
# 68                   advanced_3par_by_team_day_of_week               0.001342
# 7                                      opponent_3p_pct               0.001297
# 17                                    advanced_stl_pct               0.001242
# 23                      defensive_four_factors_drb_pct               0.001200
# 10                                       advanced_drtg               0.001143
# 18                                    advanced_blk_pct               0.001090
# 101  offensive_four_factors_tov_pct_by_team_travel_...               0.001081
# 51    defensive_four_factors_tov_pct_by_team_home_away               0.001010
# 22                      defensive_four_factors_tov_pct               0.000982
# 65                   advanced_drtg_by_team_day_of_week               0.000936
# 24                   defensive_four_factors_ft_per_fga               0.000916
# 98            advanced_ast_pct_by_team_travel_distance               0.000902
# 15                                    advanced_trb_pct               0.000891
# 16                                    advanced_ast_pct               0.000884
# 12                                        advanced_ftr               0.000871
# 20                      offensive_four_factors_orb_pct               0.000849
# 83   team_home_or_away_median_score_by_team_day_of_...               0.000844
# 39                     advanced_pace_by_team_home_away               0.000840
# 73                advanced_blk_pct_by_team_day_of_week               0.000829
# 0                                                month               0.000807
# 21                      defensive_four_factors_efg_pct               0.000796
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.000780
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.000762
# 69                 advanced_ts_pct_by_team_day_of_week               0.000746
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.000745
# 30                             team_day_median_allowed               0.000742
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.000684
# 100           advanced_blk_pct_by_team_travel_distance               0.000676
# 71                advanced_ast_pct_by_team_day_of_week               0.000672
# 47    offensive_four_factors_tov_pct_by_team_home_away               0.000643
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000626
# 106  defensive_four_factors_drb_pct_by_team_travel_...               0.000620
# 5                                          team_ft_pct               0.000617
# 61                             day_by_team_day_of_week               0.000605
# 6                                      opponent_fg_pct               0.000596
# 86            median_score_against_by_team_day_of_week               0.000589
# 93               advanced_pace_by_team_travel_distance               0.000563
# 8                                      opponent_ft_pct               0.000562
# 13                                       advanced_3par               0.000555
# 95               advanced_3par_by_team_travel_distance               0.000553
# 88                         day_by_team_travel_distance               0.000552
#
#      opp_score_importance
# 9                0.001860
# 27               0.002426
# 11               0.080030
# 14               0.001539
# 26               0.001566
# 19               0.004165
# 4                0.000915
# 79               0.000753
# 66               0.002547
# 68               0.000196
# 7                0.000798
# 17               0.001621
# 23               0.000815
# 10               0.842567
# 18               0.000540
# 101              0.000469
# 51               0.000382
# 22               0.000694
# 65               0.000751
# 24               0.002101
# 98               0.000608
# 15               0.000631
# 16               0.001106
# 12               0.001001
# 20               0.001407
# 83               0.000312
# 39               0.001355
# 73               0.000358
# 0                0.000590
# 21               0.004106
# 104              0.000536
# 82               0.000801
# 69               0.000650
# 105              0.000210
# 30               0.000534
# 77               0.000518
# 100              0.000274
# 71               0.001165
# 47               0.000169
# 76               0.001095
# 106              0.000350
# 5                0.000708
# 61               0.000939
# 6                0.008254
# 86               0.000355
# 93               0.001114
# 8                0.000777
# 13               0.000644
# 95               0.000472
# 88               0.000215

# %%
# show all or more of the ranked features
importances_df.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.001143
# 11                                       advanced_pace               0.063676
# 6                                      opponent_fg_pct               0.000596
# 19                      offensive_four_factors_tov_pct               0.003621
# 21                      defensive_four_factors_efg_pct               0.000796
# 66                   advanced_pace_by_team_day_of_week               0.001366
# 27                   team_vs_opp_homeaway_median_score               0.071171
# 24                   defensive_four_factors_ft_per_fga               0.000916
# 9                                        advanced_ortg               0.789104
# 17                                    advanced_stl_pct               0.001242
# 26                            team_vs_opp_median_score               0.004471
# 14                                     advanced_ts_pct               0.008506
# 20                      offensive_four_factors_orb_pct               0.000849
# 39                     advanced_pace_by_team_home_away               0.000840
# 71                advanced_ast_pct_by_team_day_of_week               0.000672
# 93               advanced_pace_by_team_travel_distance               0.000563
# 16                                    advanced_ast_pct               0.000884
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000626
# 85                median_score_for_by_team_day_of_week               0.000273
# 12                                        advanced_ftr               0.000871
# 61                             day_by_team_day_of_week               0.000605
# 33                                median_score_against               0.000408
# 4                                          team_3p_pct               0.002133
# 67                    advanced_ftr_by_team_day_of_week               0.000543
# 92               advanced_drtg_by_team_travel_distance               0.000320
# 23                      defensive_four_factors_drb_pct               0.001200
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.000762
# 7                                      opponent_3p_pct               0.001297
# 8                                      opponent_ft_pct               0.000562
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.002000
# 65                   advanced_drtg_by_team_day_of_week               0.000936
# 1                                                  day               0.000479
# 5                                          team_ft_pct               0.000617
# 81        team_vs_opp_median_score_by_team_day_of_week               0.000292
# 22                      defensive_four_factors_tov_pct               0.000982
# 72                advanced_stl_pct_by_team_day_of_week               0.000272
# 48    offensive_four_factors_orb_pct_by_team_home_away               0.000395
# 69                 advanced_ts_pct_by_team_day_of_week               0.000746
# 96             advanced_ts_pct_by_team_travel_distance               0.000328
# 13                                       advanced_3par               0.000555
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.000409
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.000537
# 15                                    advanced_trb_pct               0.000891
# 98            advanced_ast_pct_by_team_travel_distance               0.000902
# 0                                                month               0.000807
# 50    defensive_four_factors_efg_pct_by_team_home_away               0.000378
# 18                                    advanced_blk_pct               0.001090
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.000381
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.000780
# 30                             team_day_median_allowed               0.000742
#
#      opp_score_importance
# 10               0.842567
# 11               0.080030
# 6                0.008254
# 19               0.004165
# 21               0.004106
# 66               0.002547
# 27               0.002426
# 24               0.002101
# 9                0.001860
# 17               0.001621
# 26               0.001566
# 14               0.001539
# 20               0.001407
# 39               0.001355
# 71               0.001165
# 93               0.001114
# 16               0.001106
# 76               0.001095
# 85               0.001066
# 12               0.001001
# 61               0.000939
# 33               0.000927
# 4                0.000915
# 67               0.000896
# 92               0.000853
# 23               0.000815
# 82               0.000801
# 7                0.000798
# 8                0.000777
# 79               0.000753
# 65               0.000751
# 1                0.000735
# 5                0.000708
# 81               0.000702
# 22               0.000694
# 72               0.000666
# 48               0.000660
# 69               0.000650
# 96               0.000649
# 13               0.000644
# 75               0.000639
# 80               0.000635
# 15               0.000631
# 98               0.000608
# 0                0.000590
# 50               0.000549
# 18               0.000540
# 78               0.000539
# 104              0.000536
# 30               0.000534

# %%
from google.colab import files
df.to_csv("wnba_model_ready_v1.csv", index=False)
files.download("wnba_model_ready_v1.csv")

# %%
from google.colab import files
# save feature importances
importances_df.to_csv("league_importances.csv", index=False)
files.download("league_importances.csv")

# %%
# Create ATL data subset
df_atl = df[df['team'] == 'ATL'].copy()

# define features and target
features_atl = df_atl.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_atl = df_atl[['team_score', 'opp_score']]

# %%
X_train, X_test, y_train, y_test = train_test_split(features_atl, targets_atl, test_size=0.2, random_state=42)

model_atl = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_atl.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(random_state=42))

# %%
importances_atl = pd.DataFrame({
    'feature': features_atl.columns,
    'team_score_importance': model_atl.estimators_[0].feature_importances_,
    'opp_score_importance': model_atl.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

importances_atl.head(20)
# Out:
#                               feature  team_score_importance  \
# 14                    advanced_ts_pct               0.450337
# 9                       advanced_ortg               0.251102
# 19     offensive_four_factors_tov_pct               0.053520
# 16                   advanced_ast_pct               0.018078
# 20     offensive_four_factors_orb_pct               0.017525
# 27  team_vs_opp_homeaway_median_score               0.017474
# 7                     opponent_3p_pct               0.017239
# 10                      advanced_drtg               0.013249
# 8                     opponent_ft_pct               0.012864
# 4                         team_3p_pct               0.012468
# 1                                 day               0.010692
# 12                       advanced_ftr               0.010029
# 24  defensive_four_factors_ft_per_fga               0.009664
# 17                   advanced_stl_pct               0.009164
# 15                   advanced_trb_pct               0.008807
# 21     defensive_four_factors_efg_pct               0.008195
# 18                   advanced_blk_pct               0.007143
# 13                      advanced_3par               0.005450
# 5                         team_ft_pct               0.004781
# 61            day_by_team_day_of_week               0.004315
#
#     opp_score_importance
# 14              0.004531
# 9               0.012536
# 19              0.020985
# 16              0.007542
# 20              0.011316
# 27              0.003593
# 7               0.002882
# 10              0.641198
# 8               0.001647
# 4               0.003753
# 1               0.007123
# 12              0.011276
# 24              0.006037
# 17              0.033740
# 15              0.006551
# 21              0.009751
# 18              0.007338
# 13              0.004029
# 5               0.007327
# 61              0.001114

# %%
# show all or more of the ranked features
importances_atl.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 14                                     advanced_ts_pct               0.450337
# 9                                        advanced_ortg               0.251102
# 19                      offensive_four_factors_tov_pct               0.053520
# 16                                    advanced_ast_pct               0.018078
# 20                      offensive_four_factors_orb_pct               0.017525
# 27                   team_vs_opp_homeaway_median_score               0.017474
# 7                                      opponent_3p_pct               0.017239
# 10                                       advanced_drtg               0.013249
# 8                                      opponent_ft_pct               0.012864
# 4                                          team_3p_pct               0.012468
# 1                                                  day               0.010692
# 12                                        advanced_ftr               0.010029
# 24                   defensive_four_factors_ft_per_fga               0.009664
# 17                                    advanced_stl_pct               0.009164
# 15                                    advanced_trb_pct               0.008807
# 21                      defensive_four_factors_efg_pct               0.008195
# 18                                    advanced_blk_pct               0.007143
# 13                                       advanced_3par               0.005450
# 5                                          team_ft_pct               0.004781
# 61                             day_by_team_day_of_week               0.004315
# 23                      defensive_four_factors_drb_pct               0.004095
# 6                                      opponent_fg_pct               0.003872
# 70                advanced_trb_pct_by_team_day_of_week               0.003329
# 29                               team_day_median_score               0.002833
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.002738
# 22                      defensive_four_factors_tov_pct               0.002706
# 73                advanced_blk_pct_by_team_day_of_week               0.002540
# 26                            team_vs_opp_median_score               0.002024
# 60                           month_by_team_day_of_week               0.001833
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.001776
# 91               advanced_ortg_by_team_travel_distance               0.001608
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.001596
# 81        team_vs_opp_median_score_by_team_day_of_week               0.001548
# 107  defensive_four_factors_ft_per_fga_by_team_trav...               0.001541
# 69                 advanced_ts_pct_by_team_day_of_week               0.001483
# 67                    advanced_ftr_by_team_day_of_week               0.001428
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.001414
# 88                         day_by_team_travel_distance               0.001403
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.001309
# 66                   advanced_pace_by_team_day_of_week               0.001209
# 11                                       advanced_pace               0.001110
# 64                   advanced_ortg_by_team_day_of_week               0.000932
# 72                advanced_stl_pct_by_team_day_of_week               0.000796
# 30                             team_day_median_allowed               0.000684
# 71                advanced_ast_pct_by_team_day_of_week               0.000630
# 3                                             win_loss               0.000540
# 62                       home_away_by_team_day_of_week               0.000538
# 65                   advanced_drtg_by_team_day_of_week               0.000529
# 96             advanced_ts_pct_by_team_travel_distance               0.000447
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000398
#
#      opp_score_importance
# 14               0.004531
# 9                0.012536
# 19               0.020985
# 16               0.007542
# 20               0.011316
# 27               0.003593
# 7                0.002882
# 10               0.641198
# 8                0.001647
# 4                0.003753
# 1                0.007123
# 12               0.011276
# 24               0.006037
# 17               0.033740
# 15               0.006551
# 21               0.009751
# 18               0.007338
# 13               0.004029
# 5                0.007327
# 61               0.001114
# 23               0.001970
# 6                0.046115
# 70               0.002307
# 29               0.002372
# 82               0.003767
# 22               0.008346
# 73               0.001176
# 26               0.002345
# 60               0.000586
# 75               0.005690
# 91               0.000158
# 80               0.000432
# 81               0.005298
# 107              0.000601
# 69               0.000875
# 67               0.000987
# 78               0.001811
# 88               0.000030
# 104              0.000083
# 66               0.000802
# 11               0.048323
# 64               0.000546
# 72               0.001222
# 30               0.000163
# 71               0.000720
# 3                0.005910
# 62               0.001036
# 65               0.000434
# 96               0.000211
# 76               0.001898

# %%
# show all or more of the ranked features
importances_atl.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.013249
# 11                                       advanced_pace               0.001110
# 6                                      opponent_fg_pct               0.003872
# 17                                    advanced_stl_pct               0.009164
# 0                                                month               0.000360
# 19                      offensive_four_factors_tov_pct               0.053520
# 9                                        advanced_ortg               0.251102
# 20                      offensive_four_factors_orb_pct               0.017525
# 12                                        advanced_ftr               0.010029
# 21                      defensive_four_factors_efg_pct               0.008195
# 22                      defensive_four_factors_tov_pct               0.002706
# 16                                    advanced_ast_pct               0.018078
# 18                                    advanced_blk_pct               0.007143
# 5                                          team_ft_pct               0.004781
# 1                                                  day               0.010692
# 15                                    advanced_trb_pct               0.008807
# 24                   defensive_four_factors_ft_per_fga               0.009664
# 3                                             win_loss               0.000540
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.001776
# 81        team_vs_opp_median_score_by_team_day_of_week               0.001548
# 14                                     advanced_ts_pct               0.450337
# 13                                       advanced_3par               0.005450
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.002738
# 4                                          team_3p_pct               0.012468
# 27                   team_vs_opp_homeaway_median_score               0.017474
# 7                                      opponent_3p_pct               0.017239
# 68                   advanced_3par_by_team_day_of_week               0.000255
# 29                               team_day_median_score               0.002833
# 26                            team_vs_opp_median_score               0.002024
# 70                advanced_trb_pct_by_team_day_of_week               0.003329
# 23                      defensive_four_factors_drb_pct               0.004095
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000398
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.001414
# 106  defensive_four_factors_drb_pct_by_team_travel_...               0.000090
# 8                                      opponent_ft_pct               0.012864
# 37                     advanced_ortg_by_team_home_away               0.000367
# 72                advanced_stl_pct_by_team_day_of_week               0.000796
# 73                advanced_blk_pct_by_team_day_of_week               0.002540
# 61                             day_by_team_day_of_week               0.004315
# 62                       home_away_by_team_day_of_week               0.000538
# 108                day_of_week_by_team_travel_distance               0.000104
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.000152
# 67                    advanced_ftr_by_team_day_of_week               0.001428
# 94                advanced_ftr_by_team_travel_distance               0.000080
# 69                 advanced_ts_pct_by_team_day_of_week               0.001483
# 66                   advanced_pace_by_team_day_of_week               0.001209
# 55          team_vs_opp_median_score_by_team_home_away               0.000095
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.000283
# 71                advanced_ast_pct_by_team_day_of_week               0.000630
# 98            advanced_ast_pct_by_team_travel_distance               0.000185
#
#      opp_score_importance
# 10               0.641198
# 11               0.048323
# 6                0.046115
# 17               0.033740
# 0                0.026202
# 19               0.020985
# 9                0.012536
# 20               0.011316
# 12               0.011276
# 21               0.009751
# 22               0.008346
# 16               0.007542
# 18               0.007338
# 5                0.007327
# 1                0.007123
# 15               0.006551
# 24               0.006037
# 3                0.005910
# 75               0.005690
# 81               0.005298
# 14               0.004531
# 13               0.004029
# 82               0.003767
# 4                0.003753
# 27               0.003593
# 7                0.002882
# 68               0.002501
# 29               0.002372
# 26               0.002345
# 70               0.002307
# 23               0.001970
# 76               0.001898
# 78               0.001811
# 106              0.001777
# 8                0.001647
# 37               0.001490
# 72               0.001222
# 73               0.001176
# 61               0.001114
# 62               0.001036
# 108              0.001030
# 105              0.001008
# 67               0.000987
# 94               0.000888
# 69               0.000875
# 66               0.000802
# 55               0.000749
# 74               0.000731
# 71               0.000720
# 98               0.000646

# %%
from google.colab import files
# save feature importances
importances_atl.to_csv("atl_importances.csv", index=False)
files.download("atl_importances.csv")

# %%
# load the player game logs CSV from the data folder
df = pd.read_csv("LHL-final-final-project/data/wnba_model_ready_v1.csv")


# preview
df.head()
# Out:
#   team  month  day  home_away  opp  win_loss  team_score  opp_score  \
# 0  ATL      5   15          2  LAS         1          92         81
# 1  ATL      5   18          2  PHO         2          85         88
# 2  ATL      5   21          1  DAL         1          83         78
# 3  ATL      5   26          1  MIN         2          79         92
# 4  ATL      5   29          2  WAS         1          73         67
#
#    team_3p_pct  team_ft_pct  ...  \
# 0        0.471        0.842  ...
# 1        0.435        0.778  ...
# 2        0.318        0.727  ...
# 3        0.273        0.786  ...
# 4        0.286        0.714  ...
#
#    defensive_four_factors_efg_pct_by_team_travel_distance  \
# 0                                              0.473
# 1                                              0.464
# 2                                              0.460
# 3                                              0.473
# 4                                              0.500
#
#    defensive_four_factors_tov_pct_by_team_travel_distance  \
# 0                                              14.05
# 1                                              12.20
# 2                                              11.70
# 3                                              14.05
# 4                                              14.40
#
#    defensive_four_factors_drb_pct_by_team_travel_distance  \
# 0                                               77.6
# 1                                               79.7
# 2                                               71.8
# 3                                               77.6
# 4                                               79.5
#
#    defensive_four_factors_ft_per_fga_by_team_travel_distance  \
# 0                                             0.1815
# 1                                             0.3050
# 2                                             0.2270
# 3                                             0.1815
# 4                                             0.2000
#
#    day_of_week_by_team_travel_distance  \
# 0                                  3.0
# 1                                  2.0
# 2                                  4.0
# 3                                  3.0
# 4                                  4.0
#
#    team_vs_opp_median_score_by_team_travel_distance  \
# 0                                              75.0
# 1                                              76.0
# 2                                              81.0
# 3                                              75.0
# 4                                              75.0
#
#    team_vs_opp_homeaway_median_score_by_team_travel_distance  \
# 0                                               70.0
# 1                                               76.0
# 2                                               75.5
# 3                                               70.0
# 4                                               76.5
#
#    team_home_or_away_median_score_by_team_travel_distance  \
# 0                                               78.5
# 1                                               78.0
# 2                                               78.0
# 3                                               78.5
# 4                                               78.0
#
#    team_day_median_score_by_team_travel_distance  \
# 0                                           76.0
# 1                                           76.0
# 2                                           73.0
# 3                                           76.0
# 4                                           76.0
#
#    team_day_median_allowed_by_team_travel_distance
# 0                                             80.0
# 1                                             80.0
# 2                                             78.0
# 3                                             80.0
# 4                                             80.0
#
# [5 rows x 118 columns]

# %%
# Create CHI data subset
df_chi = df[df['team'] == 'CHI'].copy()

# define features and target
features_chi = df_chi.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_chi = df_chi[['team_score', 'opp_score']]

# Train model
X_train, X_test, y_train, y_test = train_test_split(features_chi, targets_chi, test_size=0.2, random_state=42)

model_chi = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_chi.fit(X_train, y_train)


importances_chi = pd.DataFrame({
    'feature': features_chi.columns,
    'team_score_importance': model_chi.estimators_[0].feature_importances_,
    'opp_score_importance': model_chi.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

# %%
# show all or more of the ranked features
importances_chi.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.499736
# 27                   team_vs_opp_homeaway_median_score               0.136476
# 11                                       advanced_pace               0.093623
# 3                                             win_loss               0.059917
# 14                                     advanced_ts_pct               0.041564
# 15                                    advanced_trb_pct               0.017154
# 22                      defensive_four_factors_tov_pct               0.017074
# 12                                        advanced_ftr               0.011171
# 23                      defensive_four_factors_drb_pct               0.010997
# 10                                       advanced_drtg               0.010501
# 8                                      opponent_ft_pct               0.007282
# 19                      offensive_four_factors_tov_pct               0.006352
# 16                                    advanced_ast_pct               0.006288
# 17                                    advanced_stl_pct               0.006066
# 13                                       advanced_3par               0.005646
# 7                                      opponent_3p_pct               0.005086
# 5                                          team_ft_pct               0.004821
# 18                                    advanced_blk_pct               0.004207
# 24                   defensive_four_factors_ft_per_fga               0.004065
# 6                                      opponent_fg_pct               0.003916
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.002986
# 21                      defensive_four_factors_efg_pct               0.002858
# 20                      offensive_four_factors_orb_pct               0.002797
# 0                                                month               0.002222
# 25                                         day_of_week               0.002204
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.002185
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.001866
# 4                                          team_3p_pct               0.001648
# 1                                                  day               0.001610
# 71                advanced_ast_pct_by_team_day_of_week               0.001597
# 70                advanced_trb_pct_by_team_day_of_week               0.001477
# 67                    advanced_ftr_by_team_day_of_week               0.001370
# 26                            team_vs_opp_median_score               0.001237
# 64                   advanced_ortg_by_team_day_of_week               0.001192
# 92               advanced_drtg_by_team_travel_distance               0.001139
# 107  defensive_four_factors_ft_per_fga_by_team_trav...               0.000937
# 93               advanced_pace_by_team_travel_distance               0.000891
# 30                             team_day_median_allowed               0.000809
# 97            advanced_trb_pct_by_team_travel_distance               0.000777
# 106  defensive_four_factors_drb_pct_by_team_travel_...               0.000764
# 61                             day_by_team_day_of_week               0.000709
# 81        team_vs_opp_median_score_by_team_day_of_week               0.000623
# 29                               team_day_median_score               0.000622
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000610
# 58                  median_score_for_by_team_home_away               0.000546
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.000537
# 66                   advanced_pace_by_team_day_of_week               0.000535
# 35                               day_by_team_home_away               0.000519
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.000500
# 69                 advanced_ts_pct_by_team_day_of_week               0.000497
#
#      opp_score_importance
# 9                0.002854
# 27               0.005037
# 11               0.003157
# 3                0.000061
# 14               0.004965
# 15               0.003654
# 22               0.001474
# 12               0.002678
# 23               0.003666
# 10               0.722572
# 8                0.001359
# 19               0.002903
# 16               0.020638
# 17               0.004390
# 13               0.017185
# 7                0.039947
# 5                0.006070
# 18               0.004741
# 24               0.007819
# 6                0.010219
# 82               0.002632
# 21               0.021644
# 20               0.006044
# 0                0.000722
# 25               0.000973
# 79               0.002954
# 80               0.001797
# 4                0.009573
# 1                0.032701
# 71               0.003348
# 70               0.002751
# 67               0.000731
# 26               0.008241
# 64               0.000280
# 92               0.000703
# 107              0.000391
# 93               0.000551
# 30               0.000633
# 97               0.000307
# 106              0.000745
# 61               0.000830
# 81               0.002199
# 29               0.000114
# 76               0.000887
# 58               0.000081
# 77               0.000376
# 66               0.002754
# 35               0.000030
# 104              0.000116
# 69               0.000818

# %%
# show all or more of the ranked features
importances_chi.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.010501
# 7                                      opponent_3p_pct               0.005086
# 1                                                  day               0.001610
# 21                      defensive_four_factors_efg_pct               0.002858
# 16                                    advanced_ast_pct               0.006288
# 13                                       advanced_3par               0.005646
# 6                                      opponent_fg_pct               0.003916
# 4                                          team_3p_pct               0.001648
# 26                            team_vs_opp_median_score               0.001237
# 24                   defensive_four_factors_ft_per_fga               0.004065
# 65                   advanced_drtg_by_team_day_of_week               0.000410
# 5                                          team_ft_pct               0.004821
# 20                      offensive_four_factors_orb_pct               0.002797
# 27                   team_vs_opp_homeaway_median_score               0.136476
# 14                                     advanced_ts_pct               0.041564
# 18                                    advanced_blk_pct               0.004207
# 17                                    advanced_stl_pct               0.006066
# 23                      defensive_four_factors_drb_pct               0.010997
# 15                                    advanced_trb_pct               0.017154
# 71                advanced_ast_pct_by_team_day_of_week               0.001597
# 11                                       advanced_pace               0.093623
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.002185
# 19                      offensive_four_factors_tov_pct               0.006352
# 9                                        advanced_ortg               0.499736
# 66                   advanced_pace_by_team_day_of_week               0.000535
# 70                advanced_trb_pct_by_team_day_of_week               0.001477
# 12                                        advanced_ftr               0.011171
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.002986
# 81        team_vs_opp_median_score_by_team_day_of_week               0.000623
# 85                median_score_for_by_team_day_of_week               0.000429
# 68                   advanced_3par_by_team_day_of_week               0.000464
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.001866
# 22                      defensive_four_factors_tov_pct               0.017074
# 8                                      opponent_ft_pct               0.007282
# 60                           month_by_team_day_of_week               0.000156
# 73                advanced_blk_pct_by_team_day_of_week               0.000150
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.000270
# 31                                     travel_distance               0.000211
# 25                                         day_of_week               0.002204
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000610
# 110  team_vs_opp_homeaway_median_score_by_team_trav...               0.000331
# 87                       month_by_team_travel_distance               0.000323
# 101  offensive_four_factors_tov_pct_by_team_travel_...               0.000052
# 61                             day_by_team_day_of_week               0.000709
# 69                 advanced_ts_pct_by_team_day_of_week               0.000497
# 103  offensive_four_factors_ft_per_fga_by_team_trav...               0.000299
# 106  defensive_four_factors_drb_pct_by_team_travel_...               0.000764
# 67                    advanced_ftr_by_team_day_of_week               0.001370
# 0                                                month               0.002222
# 92               advanced_drtg_by_team_travel_distance               0.001139
#
#      opp_score_importance
# 10               0.722572
# 7                0.039947
# 1                0.032701
# 21               0.021644
# 16               0.020638
# 13               0.017185
# 6                0.010219
# 4                0.009573
# 26               0.008241
# 24               0.007819
# 65               0.007551
# 5                0.006070
# 20               0.006044
# 27               0.005037
# 14               0.004965
# 18               0.004741
# 17               0.004390
# 23               0.003666
# 15               0.003654
# 71               0.003348
# 11               0.003157
# 79               0.002954
# 19               0.002903
# 9                0.002854
# 66               0.002754
# 70               0.002751
# 12               0.002678
# 82               0.002632
# 81               0.002199
# 85               0.002091
# 68               0.001932
# 80               0.001797
# 22               0.001474
# 8                0.001359
# 60               0.001256
# 73               0.001249
# 74               0.001120
# 31               0.000998
# 25               0.000973
# 76               0.000887
# 110              0.000884
# 87               0.000881
# 101              0.000844
# 61               0.000830
# 69               0.000818
# 103              0.000781
# 106              0.000745
# 67               0.000731
# 0                0.000722
# 92               0.000703

# %%
from google.colab import files
# save feature importances
importances_chi.to_csv("chi_importances.csv", index=False)
files.download("chi_importances.csv")

# %%
# Create CON data subset
df_con = df[df['team'] == 'CON'].copy()

# define features and target
features_con = df_con.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_con = df_con[['team_score', 'opp_score']]

# Train model
X_train, X_test, y_train, y_test = train_test_split(features_con, targets_con, test_size=0.2, random_state=42)

model_con = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_con.fit(X_train, y_train)

importances_con = pd.DataFrame({
    'feature': features_con.columns,
    'team_score_importance': model_con.estimators_[0].feature_importances_,
    'opp_score_importance': model_con.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

# %%
# show all or more of the ranked features
importances_con.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.655248
# 14                                     advanced_ts_pct               0.081441
# 27                   team_vs_opp_homeaway_median_score               0.061179
# 11                                       advanced_pace               0.021311
# 24                   defensive_four_factors_ft_per_fga               0.017102
# 15                                    advanced_trb_pct               0.011234
# 26                            team_vs_opp_median_score               0.009990
# 16                                    advanced_ast_pct               0.008725
# 23                      defensive_four_factors_drb_pct               0.008000
# 5                                          team_ft_pct               0.006828
# 19                      offensive_four_factors_tov_pct               0.006278
# 20                      offensive_four_factors_orb_pct               0.006044
# 1                                                  day               0.005939
# 18                                    advanced_blk_pct               0.005391
# 4                                          team_3p_pct               0.005261
# 13                                       advanced_3par               0.005113
# 12                                        advanced_ftr               0.004473
# 7                                      opponent_3p_pct               0.004190
# 68                   advanced_3par_by_team_day_of_week               0.003958
# 86            median_score_against_by_team_day_of_week               0.003852
# 22                      defensive_four_factors_tov_pct               0.003786
# 10                                       advanced_drtg               0.003325
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.002835
# 6                                      opponent_fg_pct               0.002812
# 17                                    advanced_stl_pct               0.002589
# 8                                      opponent_ft_pct               0.002486
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.002290
# 70                advanced_trb_pct_by_team_day_of_week               0.002154
# 66                   advanced_pace_by_team_day_of_week               0.002053
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.001805
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.001583
# 108                day_of_week_by_team_travel_distance               0.001506
# 107  defensive_four_factors_ft_per_fga_by_team_trav...               0.001409
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.001387
# 81        team_vs_opp_median_score_by_team_day_of_week               0.001360
# 21                      defensive_four_factors_efg_pct               0.001304
# 103  offensive_four_factors_ft_per_fga_by_team_trav...               0.001287
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.001265
# 85                median_score_for_by_team_day_of_week               0.001254
# 93               advanced_pace_by_team_travel_distance               0.001153
# 29                               team_day_median_score               0.001104
# 32                                    median_score_for               0.001102
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.001094
# 62                       home_away_by_team_day_of_week               0.001067
# 30                             team_day_median_allowed               0.001027
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.000946
# 61                             day_by_team_day_of_week               0.000932
# 110  team_vs_opp_homeaway_median_score_by_team_trav...               0.000917
# 87                       month_by_team_travel_distance               0.000902
# 113    team_day_median_allowed_by_team_travel_distance               0.000880
#
#      opp_score_importance
# 9                0.005863
# 14               0.005844
# 27               0.005091
# 11               0.054595
# 24               0.005340
# 15               0.017871
# 26               0.002055
# 16               0.010270
# 23               0.005196
# 5                0.009705
# 19               0.008158
# 20               0.009749
# 1                0.021377
# 18               0.005162
# 4                0.005031
# 13               0.002635
# 12               0.007020
# 7                0.009004
# 68               0.002763
# 86               0.000060
# 22               0.002820
# 10               0.416197
# 105              0.000502
# 6                0.203576
# 17               0.002676
# 8                0.004341
# 74               0.000822
# 70               0.000515
# 66               0.000869
# 77               0.000406
# 82               0.000833
# 108              0.000294
# 107              0.000390
# 79               0.001219
# 81               0.001340
# 21               0.134012
# 103              0.000253
# 76               0.000308
# 85               0.000302
# 93               0.000460
# 29               0.000417
# 32               0.000248
# 80               0.002985
# 62               0.000376
# 30               0.000705
# 104              0.001587
# 61               0.002131
# 110              0.000377
# 87               0.000155
# 113              0.001328

# %%
# show all or more of the ranked features
importances_con.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.003325
# 6                                      opponent_fg_pct               0.002812
# 21                      defensive_four_factors_efg_pct               0.001304
# 11                                       advanced_pace               0.021311
# 1                                                  day               0.005939
# 15                                    advanced_trb_pct               0.011234
# 16                                    advanced_ast_pct               0.008725
# 20                      offensive_four_factors_orb_pct               0.006044
# 5                                          team_ft_pct               0.006828
# 7                                      opponent_3p_pct               0.004190
# 19                      offensive_four_factors_tov_pct               0.006278
# 12                                        advanced_ftr               0.004473
# 9                                        advanced_ortg               0.655248
# 14                                     advanced_ts_pct               0.081441
# 24                   defensive_four_factors_ft_per_fga               0.017102
# 23                      defensive_four_factors_drb_pct               0.008000
# 18                                    advanced_blk_pct               0.005391
# 27                   team_vs_opp_homeaway_median_score               0.061179
# 4                                          team_3p_pct               0.005261
# 8                                      opponent_ft_pct               0.002486
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.001094
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.000178
# 22                      defensive_four_factors_tov_pct               0.003786
# 68                   advanced_3par_by_team_day_of_week               0.003958
# 58                  median_score_for_by_team_home_away               0.000021
# 17                                    advanced_stl_pct               0.002589
# 13                                       advanced_3par               0.005113
# 61                             day_by_team_day_of_week               0.000932
# 26                            team_vs_opp_median_score               0.009990
# 67                    advanced_ftr_by_team_day_of_week               0.000689
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.000946
# 73                advanced_blk_pct_by_team_day_of_week               0.000325
# 81        team_vs_opp_median_score_by_team_day_of_week               0.001360
# 113    team_day_median_allowed_by_team_travel_distance               0.000880
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.001387
# 54                       day_of_week_by_team_home_away               0.000012
# 65                   advanced_drtg_by_team_day_of_week               0.000422
# 66                   advanced_pace_by_team_day_of_week               0.002053
# 106  defensive_four_factors_drb_pct_by_team_travel_...               0.000833
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.001583
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.002290
# 71                advanced_ast_pct_by_team_day_of_week               0.000489
# 60                           month_by_team_day_of_week               0.000654
# 30                             team_day_median_allowed               0.001027
# 89                   home_away_by_team_travel_distance               0.000049
# 69                 advanced_ts_pct_by_team_day_of_week               0.000824
# 101  offensive_four_factors_tov_pct_by_team_travel_...               0.000545
# 91               advanced_ortg_by_team_travel_distance               0.000696
# 99            advanced_stl_pct_by_team_travel_distance               0.000818
# 25                                         day_of_week               0.000606
#
#      opp_score_importance
# 10               0.416197
# 6                0.203576
# 21               0.134012
# 11               0.054595
# 1                0.021377
# 15               0.017871
# 16               0.010270
# 20               0.009749
# 5                0.009705
# 7                0.009004
# 19               0.008158
# 12               0.007020
# 9                0.005863
# 14               0.005844
# 24               0.005340
# 23               0.005196
# 18               0.005162
# 27               0.005091
# 4                0.005031
# 8                0.004341
# 80               0.002985
# 78               0.002873
# 22               0.002820
# 68               0.002763
# 58               0.002683
# 17               0.002676
# 13               0.002635
# 61               0.002131
# 26               0.002055
# 67               0.001838
# 104              0.001587
# 73               0.001463
# 81               0.001340
# 113              0.001328
# 79               0.001219
# 54               0.001103
# 65               0.000966
# 66               0.000869
# 106              0.000867
# 82               0.000833
# 74               0.000822
# 71               0.000780
# 60               0.000733
# 30               0.000705
# 89               0.000678
# 69               0.000667
# 101              0.000651
# 91               0.000555
# 99               0.000548
# 25               0.000538

# %%
from google.colab import files
# save feature importances
importances_con.to_csv("con_importances.csv", index=False)
files.download("con_importances.csv")

# %%
# Create DAL data subset
df_dal = df[df['team'] == 'DAL'].copy()

# define features and target
features_dal = df_dal.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_dal = df_dal[['team_score', 'opp_score']]

# Train model
X_train, X_test, y_train, y_test = train_test_split(features_dal, targets_dal, test_size=0.2, random_state=42)

model_dal = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_dal.fit(X_train, y_train)

importances_dal = pd.DataFrame({
    'feature': features_dal.columns,
    'team_score_importance': model_dal.estimators_[0].feature_importances_,
    'opp_score_importance': model_dal.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

# %%
# show all or more of the ranked features
importances_dal.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.578885
# 14                                     advanced_ts_pct               0.160180
# 27                   team_vs_opp_homeaway_median_score               0.097947
# 15                                    advanced_trb_pct               0.013723
# 26                            team_vs_opp_median_score               0.010418
# 10                                       advanced_drtg               0.009756
# 19                      offensive_four_factors_tov_pct               0.009360
# 7                                      opponent_3p_pct               0.007810
# 20                      offensive_four_factors_orb_pct               0.007519
# 21                      defensive_four_factors_efg_pct               0.006993
# 18                                    advanced_blk_pct               0.006549
# 4                                          team_3p_pct               0.005609
# 17                                    advanced_stl_pct               0.005179
# 0                                                month               0.003718
# 23                      defensive_four_factors_drb_pct               0.003425
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.003220
# 13                                       advanced_3par               0.003207
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.002755
# 24                   defensive_four_factors_ft_per_fga               0.002597
# 62                       home_away_by_team_day_of_week               0.002480
# 6                                      opponent_fg_pct               0.002432
# 1                                                  day               0.002417
# 37                     advanced_ortg_by_team_home_away               0.002301
# 68                   advanced_3par_by_team_day_of_week               0.002221
# 65                   advanced_drtg_by_team_day_of_week               0.002052
# 61                             day_by_team_day_of_week               0.002010
# 25                                         day_of_week               0.001973
# 66                   advanced_pace_by_team_day_of_week               0.001898
# 71                advanced_ast_pct_by_team_day_of_week               0.001846
# 84                 travel_distance_by_team_day_of_week               0.001719
# 5                                          team_ft_pct               0.001618
# 73                advanced_blk_pct_by_team_day_of_week               0.001578
# 22                      defensive_four_factors_tov_pct               0.001511
# 11                                       advanced_pace               0.001413
# 16                                    advanced_ast_pct               0.001298
# 83   team_home_or_away_median_score_by_team_day_of_...               0.001286
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.001276
# 67                    advanced_ftr_by_team_day_of_week               0.001259
# 89                   home_away_by_team_travel_distance               0.001233
# 92               advanced_drtg_by_team_travel_distance               0.001191
# 31                                     travel_distance               0.001074
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.001006
# 69                 advanced_ts_pct_by_team_day_of_week               0.000989
# 72                advanced_stl_pct_by_team_day_of_week               0.000953
# 91               advanced_ortg_by_team_travel_distance               0.000944
# 8                                      opponent_ft_pct               0.000920
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.000883
# 70                advanced_trb_pct_by_team_day_of_week               0.000839
# 81        team_vs_opp_median_score_by_team_day_of_week               0.000833
# 12                                        advanced_ftr               0.000823
#
#      opp_score_importance
# 9                0.008019
# 14               0.005643
# 27               0.007748
# 15               0.009715
# 26               0.010628
# 10               0.568623
# 19               0.001126
# 7                0.052607
# 20               0.010718
# 21               0.131440
# 18               0.009818
# 4                0.006028
# 17               0.004483
# 0                0.003852
# 23               0.002828
# 77               0.001025
# 13               0.021483
# 104              0.000991
# 24               0.002171
# 62               0.001867
# 6                0.011654
# 1                0.004738
# 37               0.000084
# 68               0.002699
# 65               0.004181
# 61               0.001641
# 25               0.001263
# 66               0.001176
# 71               0.004201
# 84               0.009043
# 5                0.004683
# 73               0.000279
# 22               0.005773
# 11               0.004466
# 16               0.003881
# 83               0.000264
# 78               0.001116
# 67               0.001670
# 89               0.000029
# 92               0.000346
# 31               0.000187
# 105              0.000205
# 69               0.001233
# 72               0.004160
# 91               0.000255
# 8                0.014759
# 79               0.002681
# 70               0.004710
# 81               0.002006
# 12               0.014427

# %%
# show all or more of the ranked features
importances_dal.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.009756
# 21                      defensive_four_factors_efg_pct               0.006993
# 7                                      opponent_3p_pct               0.007810
# 13                                       advanced_3par               0.003207
# 8                                      opponent_ft_pct               0.000920
# 12                                        advanced_ftr               0.000823
# 6                                      opponent_fg_pct               0.002432
# 20                      offensive_four_factors_orb_pct               0.007519
# 26                            team_vs_opp_median_score               0.010418
# 18                                    advanced_blk_pct               0.006549
# 15                                    advanced_trb_pct               0.013723
# 84                 travel_distance_by_team_day_of_week               0.001719
# 9                                        advanced_ortg               0.578885
# 27                   team_vs_opp_homeaway_median_score               0.097947
# 4                                          team_3p_pct               0.005609
# 22                      defensive_four_factors_tov_pct               0.001511
# 14                                     advanced_ts_pct               0.160180
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000527
# 1                                                  day               0.002417
# 70                advanced_trb_pct_by_team_day_of_week               0.000839
# 5                                          team_ft_pct               0.001618
# 17                                    advanced_stl_pct               0.005179
# 11                                       advanced_pace               0.001413
# 71                advanced_ast_pct_by_team_day_of_week               0.001846
# 65                   advanced_drtg_by_team_day_of_week               0.002052
# 72                advanced_stl_pct_by_team_day_of_week               0.000953
# 16                                    advanced_ast_pct               0.001298
# 0                                                month               0.003718
# 30                             team_day_median_allowed               0.000544
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.000580
# 23                      defensive_four_factors_drb_pct               0.003425
# 68                   advanced_3par_by_team_day_of_week               0.002221
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.000883
# 85                median_score_for_by_team_day_of_week               0.000160
# 24                   defensive_four_factors_ft_per_fga               0.002597
# 81        team_vs_opp_median_score_by_team_day_of_week               0.000833
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.000342
# 62                       home_away_by_team_day_of_week               0.002480
# 97            advanced_trb_pct_by_team_travel_distance               0.000421
# 29                               team_day_median_score               0.000083
# 67                    advanced_ftr_by_team_day_of_week               0.001259
# 61                             day_by_team_day_of_week               0.002010
# 32                                    median_score_for               0.000221
# 102  offensive_four_factors_orb_pct_by_team_travel_...               0.000719
# 25                                         day_of_week               0.001973
# 69                 advanced_ts_pct_by_team_day_of_week               0.000989
# 66                   advanced_pace_by_team_day_of_week               0.001898
# 19                      offensive_four_factors_tov_pct               0.009360
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.001276
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.003220
#
#      opp_score_importance
# 10               0.568623
# 21               0.131440
# 7                0.052607
# 13               0.021483
# 8                0.014759
# 12               0.014427
# 6                0.011654
# 20               0.010718
# 26               0.010628
# 18               0.009818
# 15               0.009715
# 84               0.009043
# 9                0.008019
# 27               0.007748
# 4                0.006028
# 22               0.005773
# 14               0.005643
# 76               0.005116
# 1                0.004738
# 70               0.004710
# 5                0.004683
# 17               0.004483
# 11               0.004466
# 71               0.004201
# 65               0.004181
# 72               0.004160
# 16               0.003881
# 0                0.003852
# 30               0.003302
# 80               0.002932
# 23               0.002828
# 68               0.002699
# 79               0.002681
# 85               0.002469
# 24               0.002171
# 81               0.002006
# 75               0.002002
# 62               0.001867
# 97               0.001799
# 29               0.001707
# 67               0.001670
# 61               0.001641
# 32               0.001385
# 102              0.001349
# 25               0.001263
# 69               0.001233
# 66               0.001176
# 19               0.001126
# 78               0.001116
# 77               0.001025

# %%
from google.colab import files
# save feature importances
importances_dal.to_csv("dal_importances.csv", index=False)
files.download("dal_importances.csv")

# %%
# Create IND data subset
df_ind = df[df['team'] == 'IND'].copy()

# define features and target
features_ind = df_ind.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_ind = df_ind[['team_score', 'opp_score']]

# Train model
X_train, X_test, y_train, y_test = train_test_split(features_ind, targets_ind, test_size=0.2, random_state=42)

model_ind = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_ind.fit(X_train, y_train)

importances_ind = pd.DataFrame({
    'feature': features_ind.columns,
    'team_score_importance': model_ind.estimators_[0].feature_importances_,
    'opp_score_importance': model_ind.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

# %%
# show all or more of the ranked features
importances_ind.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                               feature  team_score_importance  \
# 9                                       advanced_ortg               0.397738
# 27                  team_vs_opp_homeaway_median_score               0.274837
# 14                                    advanced_ts_pct               0.092523
# 26                           team_vs_opp_median_score               0.040816
# 23                     defensive_four_factors_drb_pct               0.028225
# 4                                         team_3p_pct               0.013122
# 0                                               month               0.011392
# 19                     offensive_four_factors_tov_pct               0.010079
# 15                                   advanced_trb_pct               0.007675
# 12                                       advanced_ftr               0.007523
# 10                                      advanced_drtg               0.007371
# 1                                                 day               0.006327
# 6                                     opponent_fg_pct               0.006026
# 11                                      advanced_pace               0.005460
# 5                                         team_ft_pct               0.004816
# 7                                     opponent_3p_pct               0.004772
# 82  team_vs_opp_homeaway_median_score_by_team_day_...               0.004628
# 22                     defensive_four_factors_tov_pct               0.004361
# 21                     defensive_four_factors_efg_pct               0.004361
# 13                                      advanced_3par               0.003896
# 8                                     opponent_ft_pct               0.003790
# 76  offensive_four_factors_ft_per_fga_by_team_day_...               0.003766
# 17                                   advanced_stl_pct               0.003487
# 64                  advanced_ortg_by_team_day_of_week               0.003399
# 68                  advanced_3par_by_team_day_of_week               0.003312
# 20                     offensive_four_factors_orb_pct               0.002991
# 16                                   advanced_ast_pct               0.002853
# 18                                   advanced_blk_pct               0.002641
# 24                  defensive_four_factors_ft_per_fga               0.002402
# 83  team_home_or_away_median_score_by_team_day_of_...               0.002175
# 3                                            win_loss               0.001903
# 36                         win_loss_by_team_home_away               0.001796
# 74  offensive_four_factors_tov_pct_by_team_day_of_...               0.001789
# 81       team_vs_opp_median_score_by_team_day_of_week               0.001209
# 25                                        day_of_week               0.001075
# 80  defensive_four_factors_ft_per_fga_by_team_day_...               0.000998
# 61                            day_by_team_day_of_week               0.000990
# 78  defensive_four_factors_tov_pct_by_team_day_of_...               0.000988
# 33                               median_score_against               0.000933
# 29                              team_day_median_score               0.000816
# 91              advanced_ortg_by_team_travel_distance               0.000773
# 30                            team_day_median_allowed               0.000745
# 51   defensive_four_factors_tov_pct_by_team_home_away               0.000743
# 72               advanced_stl_pct_by_team_day_of_week               0.000695
# 70               advanced_trb_pct_by_team_day_of_week               0.000662
# 69                advanced_ts_pct_by_team_day_of_week               0.000619
# 60                          month_by_team_day_of_week               0.000579
# 57                  travel_distance_by_team_home_away               0.000567
# 62                      home_away_by_team_day_of_week               0.000559
# 37                    advanced_ortg_by_team_home_away               0.000535
#
#     opp_score_importance
# 9               0.007333
# 27              0.004458
# 14              0.013095
# 26              0.000848
# 23              0.003855
# 4               0.011997
# 0               0.005623
# 19              0.031164
# 15              0.002398
# 12              0.002869
# 10              0.682746
# 1               0.007714
# 6               0.041293
# 11              0.017108
# 5               0.003510
# 7               0.012133
# 82              0.002927
# 22              0.004767
# 21              0.025362
# 13              0.006831
# 8               0.004426
# 76              0.001208
# 17              0.008855
# 64              0.000697
# 68              0.000490
# 20              0.006945
# 16              0.007273
# 18              0.010553
# 24              0.019191
# 83              0.001207
# 3               0.023821
# 36              0.000170
# 74              0.000177
# 81              0.000771
# 25              0.000909
# 80              0.000746
# 61              0.000278
# 78              0.000267
# 33              0.000177
# 29              0.001351
# 91              0.000125
# 30              0.000294
# 51              0.000096
# 72              0.000427
# 70              0.000522
# 69              0.001647
# 60              0.000155
# 57              0.000414
# 62              0.000845
# 37              0.000004

# %%
# show all or more of the ranked features
importances_ind.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.007371
# 6                                      opponent_fg_pct               0.006026
# 19                      offensive_four_factors_tov_pct               0.010079
# 21                      defensive_four_factors_efg_pct               0.004361
# 3                                             win_loss               0.001903
# 24                   defensive_four_factors_ft_per_fga               0.002402
# 11                                       advanced_pace               0.005460
# 14                                     advanced_ts_pct               0.092523
# 7                                      opponent_3p_pct               0.004772
# 4                                          team_3p_pct               0.013122
# 18                                    advanced_blk_pct               0.002641
# 17                                    advanced_stl_pct               0.003487
# 1                                                  day               0.006327
# 9                                        advanced_ortg               0.397738
# 16                                    advanced_ast_pct               0.002853
# 20                      offensive_four_factors_orb_pct               0.002991
# 13                                       advanced_3par               0.003896
# 0                                                month               0.011392
# 22                      defensive_four_factors_tov_pct               0.004361
# 27                   team_vs_opp_homeaway_median_score               0.274837
# 8                                      opponent_ft_pct               0.003790
# 23                      defensive_four_factors_drb_pct               0.028225
# 5                                          team_ft_pct               0.004816
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.004628
# 12                                        advanced_ftr               0.007523
# 15                                    advanced_trb_pct               0.007675
# 66                   advanced_pace_by_team_day_of_week               0.000223
# 67                    advanced_ftr_by_team_day_of_week               0.000308
# 69                 advanced_ts_pct_by_team_day_of_week               0.000619
# 29                               team_day_median_score               0.000816
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.003766
# 83   team_home_or_away_median_score_by_team_day_of_...               0.002175
# 102  offensive_four_factors_orb_pct_by_team_travel_...               0.000466
# 25                                         day_of_week               0.001075
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.000122
# 26                            team_vs_opp_median_score               0.040816
# 62                       home_away_by_team_day_of_week               0.000559
# 81        team_vs_opp_median_score_by_team_day_of_week               0.001209
# 48    offensive_four_factors_orb_pct_by_team_home_away               0.000196
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.000998
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.000195
# 64                   advanced_ortg_by_team_day_of_week               0.003399
# 47    offensive_four_factors_tov_pct_by_team_home_away               0.000239
# 100           advanced_blk_pct_by_team_travel_distance               0.000203
# 92               advanced_drtg_by_team_travel_distance               0.000405
# 103  offensive_four_factors_ft_per_fga_by_team_trav...               0.000446
# 70                advanced_trb_pct_by_team_day_of_week               0.000662
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.000376
# 94                advanced_ftr_by_team_travel_distance               0.000359
# 95               advanced_3par_by_team_travel_distance               0.000416
#
#      opp_score_importance
# 10               0.682746
# 6                0.041293
# 19               0.031164
# 21               0.025362
# 3                0.023821
# 24               0.019191
# 11               0.017108
# 14               0.013095
# 7                0.012133
# 4                0.011997
# 18               0.010553
# 17               0.008855
# 1                0.007714
# 9                0.007333
# 16               0.007273
# 20               0.006945
# 13               0.006831
# 0                0.005623
# 22               0.004767
# 27               0.004458
# 8                0.004426
# 23               0.003855
# 5                0.003510
# 82               0.002927
# 12               0.002869
# 15               0.002398
# 66               0.002140
# 67               0.001729
# 69               0.001647
# 29               0.001351
# 76               0.001208
# 83               0.001207
# 102              0.001084
# 25               0.000909
# 75               0.000864
# 26               0.000848
# 62               0.000845
# 81               0.000771
# 48               0.000759
# 80               0.000746
# 79               0.000718
# 64               0.000697
# 47               0.000679
# 100              0.000556
# 92               0.000555
# 103              0.000535
# 70               0.000522
# 105              0.000521
# 94               0.000520
# 95               0.000510

# %%
from google.colab import files
# save feature importances
importances_ind.to_csv("ind_importances.csv", index=False)
files.download("ind_importances.csv")

# %%
# Create LAS data subset
df_las = df[df['team'] == 'LAS'].copy()

# define features and target
features_las = df_las.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_las = df_las[['team_score', 'opp_score']]

# Train model
X_train, X_test, y_train, y_test = train_test_split(features_las, targets_las, test_size=0.2, random_state=42)

model_las = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_las.fit(X_train, y_train)

importances_las = pd.DataFrame({
    'feature': features_las.columns,
    'team_score_importance': model_las.estimators_[0].feature_importances_,
    'opp_score_importance': model_las.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

# %%
# show all or more of the ranked features
importances_las.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.683922
# 27                   team_vs_opp_homeaway_median_score               0.075575
# 14                                     advanced_ts_pct               0.067601
# 1                                                  day               0.016163
# 21                      defensive_four_factors_efg_pct               0.015775
# 6                                      opponent_fg_pct               0.012137
# 22                      defensive_four_factors_tov_pct               0.010810
# 17                                    advanced_stl_pct               0.010647
# 4                                          team_3p_pct               0.008335
# 11                                       advanced_pace               0.006588
# 19                      offensive_four_factors_tov_pct               0.005836
# 15                                    advanced_trb_pct               0.005157
# 20                      offensive_four_factors_orb_pct               0.004962
# 65                   advanced_drtg_by_team_day_of_week               0.004855
# 23                      defensive_four_factors_drb_pct               0.004744
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.003742
# 5                                          team_ft_pct               0.003605
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.003337
# 26                            team_vs_opp_median_score               0.002755
# 10                                       advanced_drtg               0.002713
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.002612
# 33                                median_score_against               0.002253
# 24                   defensive_four_factors_ft_per_fga               0.002251
# 97            advanced_trb_pct_by_team_travel_distance               0.002190
# 18                                    advanced_blk_pct               0.002182
# 12                                        advanced_ftr               0.002113
# 107  defensive_four_factors_ft_per_fga_by_team_trav...               0.001947
# 106  defensive_four_factors_drb_pct_by_team_travel_...               0.001786
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.001731
# 113    team_day_median_allowed_by_team_travel_distance               0.001641
# 7                                      opponent_3p_pct               0.001293
# 0                                                month               0.001275
# 94                advanced_ftr_by_team_travel_distance               0.001156
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.000999
# 8                                      opponent_ft_pct               0.000956
# 103  offensive_four_factors_ft_per_fga_by_team_trav...               0.000883
# 3                                             win_loss               0.000858
# 51    defensive_four_factors_tov_pct_by_team_home_away               0.000804
# 38                     advanced_drtg_by_team_home_away               0.000718
# 16                                    advanced_ast_pct               0.000716
# 46                  advanced_blk_pct_by_team_home_away               0.000665
# 41                     advanced_3par_by_team_home_away               0.000661
# 68                   advanced_3par_by_team_day_of_week               0.000650
# 50    defensive_four_factors_efg_pct_by_team_home_away               0.000643
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.000639
# 35                               day_by_team_home_away               0.000628
# 67                    advanced_ftr_by_team_day_of_week               0.000626
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.000625
# 60                           month_by_team_day_of_week               0.000617
# 48    offensive_four_factors_orb_pct_by_team_home_away               0.000597
#
#      opp_score_importance
# 9                0.040604
# 27               0.014754
# 14               0.026025
# 1                0.008221
# 21               0.038267
# 6                0.050634
# 22               0.038331
# 17               0.002236
# 4                0.008338
# 11               0.039459
# 19               0.005536
# 15               0.031030
# 20               0.002679
# 65               0.000949
# 23               0.000627
# 76               0.000448
# 5                0.001994
# 77               0.001477
# 26               0.002501
# 10               0.525805
# 104              0.000236
# 33               0.002642
# 24               0.050494
# 97               0.000439
# 18               0.003700
# 12               0.009892
# 107              0.001111
# 106              0.000178
# 105              0.000793
# 113              0.000095
# 7                0.003736
# 0                0.001263
# 94               0.001145
# 74               0.008950
# 8                0.009406
# 103              0.000172
# 3                0.001416
# 51               0.000423
# 38               0.000268
# 16               0.000971
# 46               0.000393
# 41               0.000862
# 68               0.000443
# 50               0.000691
# 82               0.001965
# 35               0.000683
# 67               0.000169
# 75               0.002467
# 60               0.000060
# 48               0.001168

# %%
# show all or more of the ranked features
importances_las.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.002713
# 6                                      opponent_fg_pct               0.012137
# 24                   defensive_four_factors_ft_per_fga               0.002251
# 9                                        advanced_ortg               0.683922
# 11                                       advanced_pace               0.006588
# 22                      defensive_four_factors_tov_pct               0.010810
# 21                      defensive_four_factors_efg_pct               0.015775
# 15                                    advanced_trb_pct               0.005157
# 14                                     advanced_ts_pct               0.067601
# 27                   team_vs_opp_homeaway_median_score               0.075575
# 13                                       advanced_3par               0.000211
# 12                                        advanced_ftr               0.002113
# 8                                      opponent_ft_pct               0.000956
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.000999
# 4                                          team_3p_pct               0.008335
# 1                                                  day               0.016163
# 19                      offensive_four_factors_tov_pct               0.005836
# 85                median_score_for_by_team_day_of_week               0.000044
# 7                                      opponent_3p_pct               0.001293
# 18                                    advanced_blk_pct               0.002182
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.000230
# 71                advanced_ast_pct_by_team_day_of_week               0.000556
# 20                      offensive_four_factors_orb_pct               0.004962
# 33                                median_score_against               0.002253
# 26                            team_vs_opp_median_score               0.002755
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.000625
# 17                                    advanced_stl_pct               0.010647
# 37                     advanced_ortg_by_team_home_away               0.000036
# 5                                          team_ft_pct               0.003605
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.000639
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.003337
# 73                advanced_blk_pct_by_team_day_of_week               0.000279
# 72                advanced_stl_pct_by_team_day_of_week               0.000205
# 3                                             win_loss               0.000858
# 30                             team_day_median_allowed               0.000098
# 0                                                month               0.001275
# 44                  advanced_ast_pct_by_team_home_away               0.000040
# 62                       home_away_by_team_day_of_week               0.000244
# 108                day_of_week_by_team_travel_distance               0.000588
# 48    offensive_four_factors_orb_pct_by_team_home_away               0.000597
# 94                advanced_ftr_by_team_travel_distance               0.001156
# 107  defensive_four_factors_ft_per_fga_by_team_trav...               0.001947
# 31                                     travel_distance               0.000055
# 100           advanced_blk_pct_by_team_travel_distance               0.000020
# 84                 travel_distance_by_team_day_of_week               0.000572
# 52    defensive_four_factors_drb_pct_by_team_home_away               0.000200
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.000237
# 16                                    advanced_ast_pct               0.000716
# 65                   advanced_drtg_by_team_day_of_week               0.004855
# 81        team_vs_opp_median_score_by_team_day_of_week               0.000069
#
#      opp_score_importance
# 10               0.525805
# 6                0.050634
# 24               0.050494
# 9                0.040604
# 11               0.039459
# 22               0.038331
# 21               0.038267
# 15               0.031030
# 14               0.026025
# 27               0.014754
# 13               0.011824
# 12               0.009892
# 8                0.009406
# 74               0.008950
# 4                0.008338
# 1                0.008221
# 19               0.005536
# 85               0.004662
# 7                0.003736
# 18               0.003700
# 79               0.003184
# 71               0.002735
# 20               0.002679
# 33               0.002642
# 26               0.002501
# 75               0.002467
# 17               0.002236
# 37               0.002014
# 5                0.001994
# 82               0.001965
# 77               0.001477
# 73               0.001474
# 72               0.001462
# 3                0.001416
# 30               0.001410
# 0                0.001263
# 44               0.001261
# 62               0.001217
# 108              0.001192
# 48               0.001168
# 94               0.001145
# 107              0.001111
# 31               0.001071
# 100              0.001071
# 84               0.001062
# 52               0.001024
# 78               0.001008
# 16               0.000971
# 65               0.000949
# 81               0.000912

# %%
from google.colab import files
# save feature importances
importances_las.to_csv("las_importances.csv", index=False)
files.download("las_importances.csv")

# %%
# Create MIN data subset
df_min = df[df['team'] == 'MIN'].copy()

# define features and target
features_min = df_min.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_min = df_min[['team_score', 'opp_score']]

# Train model
X_train, X_test, y_train, y_test = train_test_split(features_min, targets_min, test_size=0.2, random_state=42)

model_min = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_min.fit(X_train, y_train)

importances_min = pd.DataFrame({
    'feature': features_min.columns,
    'team_score_importance': model_min.estimators_[0].feature_importances_,
    'opp_score_importance': model_min.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

# %%
# show top features by team_score importance
importances_min.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                               feature  team_score_importance  \
# 14                                    advanced_ts_pct               0.470444
# 9                                       advanced_ortg               0.201857
# 4                                         team_3p_pct               0.042120
# 24                  defensive_four_factors_ft_per_fga               0.034729
# 27                  team_vs_opp_homeaway_median_score               0.033483
# 20                     offensive_four_factors_orb_pct               0.016912
# 5                                         team_ft_pct               0.014544
# 12                                       advanced_ftr               0.013434
# 13                                      advanced_3par               0.011331
# 26                           team_vs_opp_median_score               0.011133
# 19                     offensive_four_factors_tov_pct               0.009732
# 18                                   advanced_blk_pct               0.008388
# 15                                   advanced_trb_pct               0.008368
# 0                                               month               0.007895
# 29                              team_day_median_score               0.006966
# 11                                      advanced_pace               0.006016
# 23                     defensive_four_factors_drb_pct               0.006009
# 80  defensive_four_factors_ft_per_fga_by_team_day_...               0.005647
# 3                                            win_loss               0.005482
# 64                  advanced_ortg_by_team_day_of_week               0.004594
# 17                                   advanced_stl_pct               0.004227
# 63                       win_loss_by_team_day_of_week               0.003885
# 7                                     opponent_3p_pct               0.003489
# 16                                   advanced_ast_pct               0.003395
# 71               advanced_ast_pct_by_team_day_of_week               0.003208
# 96            advanced_ts_pct_by_team_travel_distance               0.003050
# 79  defensive_four_factors_drb_pct_by_team_day_of_...               0.002984
# 25                                        day_of_week               0.002906
# 30                            team_day_median_allowed               0.002856
# 75  offensive_four_factors_orb_pct_by_team_day_of_...               0.002562
# 99           advanced_stl_pct_by_team_travel_distance               0.002428
# 10                                      advanced_drtg               0.002366
# 70               advanced_trb_pct_by_team_day_of_week               0.002278
# 73               advanced_blk_pct_by_team_day_of_week               0.002254
# 21                     defensive_four_factors_efg_pct               0.002102
# 66                  advanced_pace_by_team_day_of_week               0.002089
# 83  team_home_or_away_median_score_by_team_day_of_...               0.002039
# 91              advanced_ortg_by_team_travel_distance               0.002035
# 22                     defensive_four_factors_tov_pct               0.001984
# 81       team_vs_opp_median_score_by_team_day_of_week               0.001898
# 6                                     opponent_fg_pct               0.001822
# 1                                                 day               0.001702
# 74  offensive_four_factors_tov_pct_by_team_day_of_...               0.001643
# 77  defensive_four_factors_efg_pct_by_team_day_of_...               0.001540
# 69                advanced_ts_pct_by_team_day_of_week               0.001393
# 8                                     opponent_ft_pct               0.001379
# 32                                   median_score_for               0.001259
# 92              advanced_drtg_by_team_travel_distance               0.001175
# 82  team_vs_opp_homeaway_median_score_by_team_day_...               0.001035
# 68                  advanced_3par_by_team_day_of_week               0.000943
#
#     opp_score_importance
# 14              0.003506
# 9               0.009382
# 4               0.001983
# 24              0.019637
# 27              0.015486
# 20              0.003647
# 5               0.002624
# 12              0.036434
# 13              0.020486
# 26              0.011577
# 19              0.007448
# 18              0.008763
# 15              0.001709
# 0               0.002466
# 29              0.001682
# 11              0.032831
# 23              0.006123
# 80              0.004597
# 3               0.004593
# 64              0.009194
# 17              0.008811
# 63              0.000167
# 7               0.012192
# 16              0.009330
# 71              0.002943
# 96              0.000565
# 79              0.001803
# 25              0.000644
# 30              0.011327
# 75              0.000188
# 99              0.000161
# 10              0.517255
# 70              0.001680
# 73              0.000450
# 21              0.031669
# 66              0.014053
# 83              0.000206
# 91              0.000529
# 22              0.033168
# 81              0.000291
# 6               0.098068
# 1               0.005114
# 74              0.000776
# 77              0.000508
# 69              0.000482
# 8               0.006182
# 32              0.000104
# 92              0.000551
# 82              0.000077
# 68              0.005774

# %%
# show top features by opp_score importance
importances_min.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.002366
# 6                                      opponent_fg_pct               0.001822
# 12                                        advanced_ftr               0.013434
# 22                      defensive_four_factors_tov_pct               0.001984
# 11                                       advanced_pace               0.006016
# 21                      defensive_four_factors_efg_pct               0.002102
# 13                                       advanced_3par               0.011331
# 24                   defensive_four_factors_ft_per_fga               0.034729
# 27                   team_vs_opp_homeaway_median_score               0.033483
# 66                   advanced_pace_by_team_day_of_week               0.002089
# 7                                      opponent_3p_pct               0.003489
# 26                            team_vs_opp_median_score               0.011133
# 30                             team_day_median_allowed               0.002856
# 9                                        advanced_ortg               0.201857
# 16                                    advanced_ast_pct               0.003395
# 64                   advanced_ortg_by_team_day_of_week               0.004594
# 17                                    advanced_stl_pct               0.004227
# 18                                    advanced_blk_pct               0.008388
# 19                      offensive_four_factors_tov_pct               0.009732
# 8                                      opponent_ft_pct               0.001379
# 23                      defensive_four_factors_drb_pct               0.006009
# 68                   advanced_3par_by_team_day_of_week               0.000943
# 1                                                  day               0.001702
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.005647
# 3                                             win_loss               0.005482
# 20                      offensive_four_factors_orb_pct               0.016912
# 14                                     advanced_ts_pct               0.470444
# 71                advanced_ast_pct_by_team_day_of_week               0.003208
# 5                                          team_ft_pct               0.014544
# 0                                                month               0.007895
# 84                 travel_distance_by_team_day_of_week               0.000313
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.000088
# 4                                          team_3p_pct               0.042120
# 65                   advanced_drtg_by_team_day_of_week               0.000783
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.002984
# 15                                    advanced_trb_pct               0.008368
# 29                               team_day_median_score               0.006966
# 70                advanced_trb_pct_by_team_day_of_week               0.002278
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000068
# 88                         day_by_team_travel_distance               0.000003
# 37                     advanced_ortg_by_team_home_away               0.000086
# 86            median_score_against_by_team_day_of_week               0.000209
# 85                median_score_for_by_team_day_of_week               0.000565
# 106  defensive_four_factors_drb_pct_by_team_travel_...               0.000266
# 54                       day_of_week_by_team_home_away               0.000054
# 94                advanced_ftr_by_team_travel_distance               0.000356
# 60                           month_by_team_day_of_week               0.000618
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.001643
# 61                             day_by_team_day_of_week               0.000313
# 51    defensive_four_factors_tov_pct_by_team_home_away               0.000006
#
#      opp_score_importance
# 10               0.517255
# 6                0.098068
# 12               0.036434
# 22               0.033168
# 11               0.032831
# 21               0.031669
# 13               0.020486
# 24               0.019637
# 27               0.015486
# 66               0.014053
# 7                0.012192
# 26               0.011577
# 30               0.011327
# 9                0.009382
# 16               0.009330
# 64               0.009194
# 17               0.008811
# 18               0.008763
# 19               0.007448
# 8                0.006182
# 23               0.006123
# 68               0.005774
# 1                0.005114
# 80               0.004597
# 3                0.004593
# 20               0.003647
# 14               0.003506
# 71               0.002943
# 5                0.002624
# 0                0.002466
# 84               0.002185
# 78               0.002150
# 4                0.001983
# 65               0.001848
# 79               0.001803
# 15               0.001709
# 29               0.001682
# 70               0.001680
# 76               0.001464
# 88               0.001350
# 37               0.001243
# 86               0.001220
# 85               0.001153
# 106              0.001129
# 54               0.000975
# 94               0.000960
# 60               0.000885
# 74               0.000776
# 61               0.000727
# 51               0.000711

# %%
from google.colab import files
# save feature importances
importances_min.to_csv("min_importances.csv", index=False)
files.download("min_importances.csv")

# %%
# Create NYL data subset
df_nyl = df[df['team'] == 'NYL'].copy()

# define features and target
features_nyl = df_nyl.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_nyl = df_nyl[['team_score', 'opp_score']]

# Train model
X_train, X_test, y_train, y_test = train_test_split(features_nyl, targets_nyl, test_size=0.2, random_state=42)

model_nyl = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_nyl.fit(X_train, y_train)

importances_nyl = pd.DataFrame({
    'feature': features_nyl.columns,
    'team_score_importance': model_nyl.estimators_[0].feature_importances_,
    'opp_score_importance': model_nyl.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

# %%
# show top features by team_score importance
importances_nyl.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.627155
# 14                                     advanced_ts_pct               0.177830
# 11                                       advanced_pace               0.045340
# 7                                      opponent_3p_pct               0.026923
# 27                   team_vs_opp_homeaway_median_score               0.013177
# 19                      offensive_four_factors_tov_pct               0.010453
# 4                                          team_3p_pct               0.007879
# 26                            team_vs_opp_median_score               0.007485
# 21                      defensive_four_factors_efg_pct               0.007314
# 10                                       advanced_drtg               0.005522
# 23                      defensive_four_factors_drb_pct               0.004734
# 13                                       advanced_3par               0.004672
# 20                      offensive_four_factors_orb_pct               0.003955
# 22                      defensive_four_factors_tov_pct               0.003318
# 3                                             win_loss               0.003227
# 24                   defensive_four_factors_ft_per_fga               0.002768
# 70                advanced_trb_pct_by_team_day_of_week               0.002578
# 6                                      opponent_fg_pct               0.002470
# 15                                    advanced_trb_pct               0.002102
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.002033
# 1                                                  day               0.001950
# 83   team_home_or_away_median_score_by_team_day_of_...               0.001902
# 17                                    advanced_stl_pct               0.001777
# 103  offensive_four_factors_ft_per_fga_by_team_trav...               0.001461
# 16                                    advanced_ast_pct               0.001397
# 66                   advanced_pace_by_team_day_of_week               0.001370
# 8                                      opponent_ft_pct               0.001268
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.001217
# 18                                    advanced_blk_pct               0.001217
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.001125
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.001123
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.001081
# 88                         day_by_team_travel_distance               0.001034
# 110  team_vs_opp_homeaway_median_score_by_team_trav...               0.000954
# 12                                        advanced_ftr               0.000906
# 33                                median_score_against               0.000894
# 50    defensive_four_factors_efg_pct_by_team_home_away               0.000817
# 30                             team_day_median_allowed               0.000811
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.000791
# 5                                          team_ft_pct               0.000789
# 109   team_vs_opp_median_score_by_team_travel_distance               0.000753
# 108                day_of_week_by_team_travel_distance               0.000649
# 0                                                month               0.000605
# 25                                         day_of_week               0.000593
# 96             advanced_ts_pct_by_team_travel_distance               0.000548
# 69                 advanced_ts_pct_by_team_day_of_week               0.000532
# 87                       month_by_team_travel_distance               0.000528
# 93               advanced_pace_by_team_travel_distance               0.000509
# 67                    advanced_ftr_by_team_day_of_week               0.000429
# 73                advanced_blk_pct_by_team_day_of_week               0.000407
#
#      opp_score_importance
# 9                0.004271
# 14               0.003746
# 11               0.012360
# 7                0.004320
# 27               0.005820
# 19               0.003125
# 4                0.003722
# 26               0.002103
# 21               0.031292
# 10               0.734214
# 23               0.003211
# 13               0.002604
# 20               0.003027
# 22               0.007187
# 3                0.000007
# 24               0.006070
# 70               0.000675
# 6                0.022440
# 15               0.002269
# 78               0.000829
# 1                0.002092
# 83               0.000015
# 17               0.015867
# 103              0.002878
# 16               0.037709
# 66               0.003160
# 8                0.005005
# 82               0.000902
# 18               0.006582
# 74               0.003926
# 76               0.001290
# 75               0.000810
# 88               0.000573
# 110              0.000189
# 12               0.006128
# 33               0.002624
# 50               0.000025
# 30               0.000473
# 77               0.004968
# 5                0.001271
# 109              0.000273
# 108              0.000214
# 0                0.008794
# 25               0.002837
# 96               0.000022
# 69               0.001459
# 87               0.000024
# 93               0.001035
# 67               0.000138
# 73               0.000282

# %%
# show top features by opp_score importance
importances_nyl.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.005522
# 16                                    advanced_ast_pct               0.001397
# 21                      defensive_four_factors_efg_pct               0.007314
# 6                                      opponent_fg_pct               0.002470
# 17                                    advanced_stl_pct               0.001777
# 11                                       advanced_pace               0.045340
# 0                                                month               0.000605
# 22                      defensive_four_factors_tov_pct               0.003318
# 18                                    advanced_blk_pct               0.001217
# 12                                        advanced_ftr               0.000906
# 24                   defensive_four_factors_ft_per_fga               0.002768
# 27                   team_vs_opp_homeaway_median_score               0.013177
# 8                                      opponent_ft_pct               0.001268
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.000791
# 101  offensive_four_factors_tov_pct_by_team_travel_...               0.000249
# 7                                      opponent_3p_pct               0.026923
# 9                                        advanced_ortg               0.627155
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.001125
# 71                advanced_ast_pct_by_team_day_of_week               0.000371
# 14                                     advanced_ts_pct               0.177830
# 4                                          team_3p_pct               0.007879
# 23                      defensive_four_factors_drb_pct               0.004734
# 66                   advanced_pace_by_team_day_of_week               0.001370
# 19                      offensive_four_factors_tov_pct               0.010453
# 20                      offensive_four_factors_orb_pct               0.003955
# 103  offensive_four_factors_ft_per_fga_by_team_trav...               0.001461
# 81        team_vs_opp_median_score_by_team_day_of_week               0.000402
# 25                                         day_of_week               0.000593
# 33                                median_score_against               0.000894
# 13                                       advanced_3par               0.004672
# 31                                     travel_distance               0.000159
# 15                                    advanced_trb_pct               0.002102
# 113    team_day_median_allowed_by_team_travel_distance               0.000167
# 26                            team_vs_opp_median_score               0.007485
# 1                                                  day               0.001950
# 102  offensive_four_factors_orb_pct_by_team_travel_...               0.000205
# 64                   advanced_ortg_by_team_day_of_week               0.000394
# 41                     advanced_3par_by_team_home_away               0.000050
# 69                 advanced_ts_pct_by_team_day_of_week               0.000532
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.001123
# 5                                          team_ft_pct               0.000789
# 98            advanced_ast_pct_by_team_travel_distance               0.000155
# 93               advanced_pace_by_team_travel_distance               0.000509
# 99            advanced_stl_pct_by_team_travel_distance               0.000383
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.001217
# 95               advanced_3par_by_team_travel_distance               0.000125
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.002033
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.001081
# 60                           month_by_team_day_of_week               0.000097
# 68                   advanced_3par_by_team_day_of_week               0.000356
#
#      opp_score_importance
# 10               0.734214
# 16               0.037709
# 21               0.031292
# 6                0.022440
# 17               0.015867
# 11               0.012360
# 0                0.008794
# 22               0.007187
# 18               0.006582
# 12               0.006128
# 24               0.006070
# 27               0.005820
# 8                0.005005
# 77               0.004968
# 101              0.004618
# 7                0.004320
# 9                0.004271
# 74               0.003926
# 71               0.003750
# 14               0.003746
# 4                0.003722
# 23               0.003211
# 66               0.003160
# 19               0.003125
# 20               0.003027
# 103              0.002878
# 81               0.002854
# 25               0.002837
# 33               0.002624
# 13               0.002604
# 31               0.002397
# 15               0.002269
# 113              0.002123
# 26               0.002103
# 1                0.002092
# 102              0.001990
# 64               0.001875
# 41               0.001568
# 69               0.001459
# 76               0.001290
# 5                0.001271
# 98               0.001052
# 93               0.001035
# 99               0.001012
# 82               0.000902
# 95               0.000856
# 78               0.000829
# 75               0.000810
# 60               0.000735
# 68               0.000695

# %%
from google.colab import files
# save feature importances
importances_nyl.to_csv("nyl_importances.csv", index=False)
files.download("nyl_importances.csv")

# %%
# Create PHO data subset
df_pho = df[df['team'] == 'PHO'].copy()

# define features and target
features_pho = df_pho.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_pho = df_pho[['team_score', 'opp_score']]

# Train model
X_train, X_test, y_train, y_test = train_test_split(features_pho, targets_pho, test_size=0.2, random_state=42)

model_pho = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_pho.fit(X_train, y_train)

importances_pho = pd.DataFrame({
    'feature': features_pho.columns,
    'team_score_importance': model_pho.estimators_[0].feature_importances_,
    'opp_score_importance': model_pho.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

# %%
# show top features by team_score importance
importances_pho.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.435872
# 14                                     advanced_ts_pct               0.167835
# 3                                             win_loss               0.062581
# 27                   team_vs_opp_homeaway_median_score               0.039856
# 21                      defensive_four_factors_efg_pct               0.026688
# 6                                      opponent_fg_pct               0.025944
# 4                                          team_3p_pct               0.022989
# 26                            team_vs_opp_median_score               0.022256
# 10                                       advanced_drtg               0.014405
# 12                                        advanced_ftr               0.013675
# 8                                      opponent_ft_pct               0.012878
# 19                      offensive_four_factors_tov_pct               0.012818
# 22                      defensive_four_factors_tov_pct               0.011303
# 15                                    advanced_trb_pct               0.010978
# 11                                       advanced_pace               0.010951
# 7                                      opponent_3p_pct               0.008082
# 24                   defensive_four_factors_ft_per_fga               0.006639
# 61                             day_by_team_day_of_week               0.005779
# 30                             team_day_median_allowed               0.005314
# 1                                                  day               0.004791
# 91               advanced_ortg_by_team_travel_distance               0.004669
# 13                                       advanced_3par               0.003779
# 18                                    advanced_blk_pct               0.003725
# 31                                     travel_distance               0.003646
# 20                      offensive_four_factors_orb_pct               0.003594
# 16                                    advanced_ast_pct               0.003166
# 93               advanced_pace_by_team_travel_distance               0.002526
# 17                                    advanced_stl_pct               0.002181
# 66                   advanced_pace_by_team_day_of_week               0.002068
# 23                      defensive_four_factors_drb_pct               0.001985
# 72                advanced_stl_pct_by_team_day_of_week               0.001954
# 89                   home_away_by_team_travel_distance               0.001896
# 113    team_day_median_allowed_by_team_travel_distance               0.001804
# 101  offensive_four_factors_tov_pct_by_team_travel_...               0.001776
# 67                    advanced_ftr_by_team_day_of_week               0.001753
# 0                                                month               0.001712
# 110  team_vs_opp_homeaway_median_score_by_team_trav...               0.001644
# 94                advanced_ftr_by_team_travel_distance               0.001617
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.001585
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.001511
# 109   team_vs_opp_median_score_by_team_travel_distance               0.001507
# 69                 advanced_ts_pct_by_team_day_of_week               0.001449
# 5                                          team_ft_pct               0.001368
# 111  team_home_or_away_median_score_by_team_travel_...               0.001339
# 68                   advanced_3par_by_team_day_of_week               0.001271
# 92               advanced_drtg_by_team_travel_distance               0.001258
# 32                                    median_score_for               0.001019
# 84                 travel_distance_by_team_day_of_week               0.001002
# 64                   advanced_ortg_by_team_day_of_week               0.001000
# 95               advanced_3par_by_team_travel_distance               0.000942
#
#      opp_score_importance
# 9                0.003157
# 14               0.001334
# 3                0.000619
# 27               0.002922
# 21               0.076908
# 6                0.520782
# 4                0.004575
# 26               0.000562
# 10               0.184516
# 12               0.006463
# 8                0.014508
# 19               0.009408
# 22               0.006362
# 15               0.005744
# 11               0.021577
# 7                0.001793
# 24               0.019291
# 61               0.000978
# 30               0.000582
# 1                0.006191
# 91               0.001120
# 13               0.010586
# 18               0.001178
# 31               0.000114
# 20               0.005632
# 16               0.015744
# 93               0.001167
# 17               0.002784
# 66               0.003019
# 23               0.005648
# 72               0.000343
# 89               0.000011
# 113              0.000022
# 101              0.000075
# 67               0.001262
# 0                0.000632
# 110              0.000061
# 94               0.001105
# 77               0.000687
# 76               0.000771
# 109              0.000172
# 69               0.005811
# 5                0.009238
# 111              0.000014
# 68               0.004372
# 92               0.000591
# 32               0.000269
# 84               0.000933
# 64               0.000791
# 95               0.000019

# %%
# show top features by opp_score importance
importances_pho.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 6                                      opponent_fg_pct               0.025944
# 10                                       advanced_drtg               0.014405
# 21                      defensive_four_factors_efg_pct               0.026688
# 11                                       advanced_pace               0.010951
# 24                   defensive_four_factors_ft_per_fga               0.006639
# 16                                    advanced_ast_pct               0.003166
# 8                                      opponent_ft_pct               0.012878
# 13                                       advanced_3par               0.003779
# 19                      offensive_four_factors_tov_pct               0.012818
# 5                                          team_ft_pct               0.001368
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.000828
# 12                                        advanced_ftr               0.013675
# 22                      defensive_four_factors_tov_pct               0.011303
# 1                                                  day               0.004791
# 69                 advanced_ts_pct_by_team_day_of_week               0.001449
# 15                                    advanced_trb_pct               0.010978
# 23                      defensive_four_factors_drb_pct               0.001985
# 20                      offensive_four_factors_orb_pct               0.003594
# 4                                          team_3p_pct               0.022989
# 68                   advanced_3par_by_team_day_of_week               0.001271
# 9                                        advanced_ortg               0.435872
# 66                   advanced_pace_by_team_day_of_week               0.002068
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.000851
# 27                   team_vs_opp_homeaway_median_score               0.039856
# 73                advanced_blk_pct_by_team_day_of_week               0.000799
# 17                                    advanced_stl_pct               0.002181
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.000293
# 29                               team_day_median_score               0.000080
# 35                               day_by_team_home_away               0.000692
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.000751
# 102  offensive_four_factors_orb_pct_by_team_travel_...               0.000527
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.000124
# 7                                      opponent_3p_pct               0.008082
# 103  offensive_four_factors_ft_per_fga_by_team_trav...               0.000508
# 98            advanced_ast_pct_by_team_travel_distance               0.000864
# 14                                     advanced_ts_pct               0.167835
# 67                    advanced_ftr_by_team_day_of_week               0.001753
# 18                                    advanced_blk_pct               0.003725
# 93               advanced_pace_by_team_travel_distance               0.002526
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.000915
# 91               advanced_ortg_by_team_travel_distance               0.004669
# 94                advanced_ftr_by_team_travel_distance               0.001617
# 61                             day_by_team_day_of_week               0.005779
# 84                 travel_distance_by_team_day_of_week               0.001002
# 70                advanced_trb_pct_by_team_day_of_week               0.000497
# 64                   advanced_ortg_by_team_day_of_week               0.001000
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.001511
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.001585
# 25                                         day_of_week               0.000166
# 0                                                month               0.001712
#
#      opp_score_importance
# 6                0.520782
# 10               0.184516
# 21               0.076908
# 11               0.021577
# 24               0.019291
# 16               0.015744
# 8                0.014508
# 13               0.010586
# 19               0.009408
# 5                0.009238
# 75               0.006950
# 12               0.006463
# 22               0.006362
# 1                0.006191
# 69               0.005811
# 15               0.005744
# 23               0.005648
# 20               0.005632
# 4                0.004575
# 68               0.004372
# 9                0.003157
# 66               0.003019
# 79               0.002926
# 27               0.002922
# 73               0.002841
# 17               0.002784
# 80               0.002527
# 29               0.002216
# 35               0.001976
# 82               0.001903
# 102              0.001834
# 74               0.001797
# 7                0.001793
# 103              0.001422
# 98               0.001337
# 14               0.001334
# 67               0.001262
# 18               0.001178
# 93               0.001167
# 78               0.001167
# 91               0.001120
# 94               0.001105
# 61               0.000978
# 84               0.000933
# 70               0.000911
# 64               0.000791
# 76               0.000771
# 77               0.000687
# 25               0.000685
# 0                0.000632

# %%
from google.colab import files
# save feature importances
importances_pho.to_csv("pho_importances.csv", index=False)
files.download("pho_importances.csv")

# %%
# Create SEA data subset
df_sea = df[df['team'] == 'SEA'].copy()

# define features and target
features_sea = df_sea.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_sea = df_sea[['team_score', 'opp_score']]

# Train model
X_train, X_test, y_train, y_test = train_test_split(features_sea, targets_sea, test_size=0.2, random_state=42)

model_sea = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_sea.fit(X_train, y_train)

importances_sea = pd.DataFrame({
    'feature': features_sea.columns,
    'team_score_importance': model_sea.estimators_[0].feature_importances_,
    'opp_score_importance': model_sea.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

# %%
# show top features by team_score importance
importances_sea.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.493531
# 14                                     advanced_ts_pct               0.152638
# 5                                          team_ft_pct               0.062982
# 11                                       advanced_pace               0.041423
# 27                   team_vs_opp_homeaway_median_score               0.021832
# 12                                        advanced_ftr               0.019920
# 4                                          team_3p_pct               0.017900
# 20                      offensive_four_factors_orb_pct               0.015178
# 0                                                month               0.012406
# 26                            team_vs_opp_median_score               0.011711
# 22                      defensive_four_factors_tov_pct               0.010951
# 30                             team_day_median_allowed               0.009998
# 23                      defensive_four_factors_drb_pct               0.009870
# 8                                      opponent_ft_pct               0.009815
# 13                                       advanced_3par               0.007839
# 69                 advanced_ts_pct_by_team_day_of_week               0.007503
# 18                                    advanced_blk_pct               0.007474
# 17                                    advanced_stl_pct               0.007166
# 7                                      opponent_3p_pct               0.006269
# 19                      offensive_four_factors_tov_pct               0.006191
# 29                               team_day_median_score               0.005351
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.004508
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.004475
# 64                   advanced_ortg_by_team_day_of_week               0.003400
# 10                                       advanced_drtg               0.003021
# 73                advanced_blk_pct_by_team_day_of_week               0.002564
# 1                                                  day               0.002421
# 6                                      opponent_fg_pct               0.002411
# 24                   defensive_four_factors_ft_per_fga               0.002351
# 65                   advanced_drtg_by_team_day_of_week               0.002214
# 21                      defensive_four_factors_efg_pct               0.002185
# 85                median_score_for_by_team_day_of_week               0.001950
# 15                                    advanced_trb_pct               0.001855
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.001831
# 16                                    advanced_ast_pct               0.001386
# 25                                         day_of_week               0.001347
# 81        team_vs_opp_median_score_by_team_day_of_week               0.001308
# 113    team_day_median_allowed_by_team_travel_distance               0.001303
# 66                   advanced_pace_by_team_day_of_week               0.001267
# 62                       home_away_by_team_day_of_week               0.000902
# 67                    advanced_ftr_by_team_day_of_week               0.000859
# 92               advanced_drtg_by_team_travel_distance               0.000819
# 93               advanced_pace_by_team_travel_distance               0.000787
# 97            advanced_trb_pct_by_team_travel_distance               0.000715
# 106  defensive_four_factors_drb_pct_by_team_travel_...               0.000705
# 37                     advanced_ortg_by_team_home_away               0.000619
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.000586
# 102  offensive_four_factors_orb_pct_by_team_travel_...               0.000577
# 95               advanced_3par_by_team_travel_distance               0.000572
# 71                advanced_ast_pct_by_team_day_of_week               0.000559
#
#      opp_score_importance
# 9                0.005980
# 14               0.001480
# 5                0.003610
# 11               0.009078
# 27               0.000880
# 12               0.008709
# 4                0.004929
# 20               0.001418
# 0                0.000329
# 26               0.008894
# 22               0.009976
# 30               0.000480
# 23               0.005394
# 8                0.005591
# 13               0.001483
# 69               0.000851
# 18               0.002876
# 17               0.017622
# 7                0.010170
# 19               0.011953
# 29               0.000967
# 75               0.004054
# 76               0.005026
# 64               0.000720
# 10               0.593749
# 73               0.000566
# 1                0.017465
# 6                0.054638
# 24               0.006629
# 65               0.000210
# 21               0.111957
# 85               0.000232
# 15               0.006668
# 80               0.004043
# 16               0.034779
# 25               0.005149
# 81               0.000758
# 113              0.000156
# 66               0.004307
# 62               0.000124
# 67               0.002649
# 92               0.001069
# 93               0.000401
# 97               0.000139
# 106              0.000130
# 37               0.000034
# 105              0.000280
# 102              0.000470
# 95               0.000296
# 71               0.001124

# %%
# show top features by opp_score importance
importances_sea.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.003021
# 21                      defensive_four_factors_efg_pct               0.002185
# 6                                      opponent_fg_pct               0.002411
# 16                                    advanced_ast_pct               0.001386
# 17                                    advanced_stl_pct               0.007166
# 1                                                  day               0.002421
# 19                      offensive_four_factors_tov_pct               0.006191
# 7                                      opponent_3p_pct               0.006269
# 22                      defensive_four_factors_tov_pct               0.010951
# 11                                       advanced_pace               0.041423
# 26                            team_vs_opp_median_score               0.011711
# 12                                        advanced_ftr               0.019920
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.000206
# 15                                    advanced_trb_pct               0.001855
# 24                   defensive_four_factors_ft_per_fga               0.002351
# 9                                        advanced_ortg               0.493531
# 8                                      opponent_ft_pct               0.009815
# 23                      defensive_four_factors_drb_pct               0.009870
# 25                                         day_of_week               0.001347
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.004475
# 4                                          team_3p_pct               0.017900
# 66                   advanced_pace_by_team_day_of_week               0.001267
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.004508
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.001831
# 68                   advanced_3par_by_team_day_of_week               0.000272
# 72                advanced_stl_pct_by_team_day_of_week               0.000506
# 5                                          team_ft_pct               0.062982
# 18                                    advanced_blk_pct               0.007474
# 67                    advanced_ftr_by_team_day_of_week               0.000859
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.000066
# 13                                       advanced_3par               0.007839
# 14                                     advanced_ts_pct               0.152638
# 20                      offensive_four_factors_orb_pct               0.015178
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.000054
# 71                advanced_ast_pct_by_team_day_of_week               0.000559
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.000301
# 92               advanced_drtg_by_team_travel_distance               0.000819
# 29                               team_day_median_score               0.005351
# 70                advanced_trb_pct_by_team_day_of_week               0.000246
# 27                   team_vs_opp_homeaway_median_score               0.021832
# 69                 advanced_ts_pct_by_team_day_of_week               0.007503
# 81        team_vs_opp_median_score_by_team_day_of_week               0.001308
# 64                   advanced_ortg_by_team_day_of_week               0.003400
# 49   offensive_four_factors_ft_per_fga_by_team_home...               0.000023
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.000293
# 73                advanced_blk_pct_by_team_day_of_week               0.002564
# 91               advanced_ortg_by_team_travel_distance               0.000341
# 107  defensive_four_factors_ft_per_fga_by_team_trav...               0.000044
# 30                             team_day_median_allowed               0.009998
# 102  offensive_four_factors_orb_pct_by_team_travel_...               0.000577
#
#      opp_score_importance
# 10               0.593749
# 21               0.111957
# 6                0.054638
# 16               0.034779
# 17               0.017622
# 1                0.017465
# 19               0.011953
# 7                0.010170
# 22               0.009976
# 11               0.009078
# 26               0.008894
# 12               0.008709
# 82               0.007266
# 15               0.006668
# 24               0.006629
# 9                0.005980
# 8                0.005591
# 23               0.005394
# 25               0.005149
# 76               0.005026
# 4                0.004929
# 66               0.004307
# 75               0.004054
# 80               0.004043
# 68               0.003863
# 72               0.003725
# 5                0.003610
# 18               0.002876
# 67               0.002649
# 77               0.002196
# 13               0.001483
# 14               0.001480
# 20               0.001418
# 78               0.001319
# 71               0.001124
# 74               0.001090
# 92               0.001069
# 29               0.000967
# 70               0.000929
# 27               0.000880
# 69               0.000851
# 81               0.000758
# 64               0.000720
# 49               0.000600
# 104              0.000599
# 73               0.000566
# 91               0.000538
# 107              0.000516
# 30               0.000480
# 102              0.000470

# %%
from google.colab import files
# save feature importances
importances_sea.to_csv("sea_importances.csv", index=False)
files.download("sea_importances.csv")

# %%
# Create WAS data subset
df_was = df[df['team'] == 'WAS'].copy()

# define features and target
features_was = df_was.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_was = df_was[['team_score', 'opp_score']]

# Train model
X_train, X_test, y_train, y_test = train_test_split(features_was, targets_was, test_size=0.2, random_state=42)

model_was = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_was.fit(X_train, y_train)

importances_was = pd.DataFrame({
    'feature': features_was.columns,
    'team_score_importance': model_was.estimators_[0].feature_importances_,
    'opp_score_importance': model_was.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

# %%
# show top features by team_score importance
importances_was.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.799454
# 27                   team_vs_opp_homeaway_median_score               0.035831
# 14                                     advanced_ts_pct               0.014024
# 13                                       advanced_3par               0.011262
# 4                                          team_3p_pct               0.010084
# 26                            team_vs_opp_median_score               0.008856
# 8                                      opponent_ft_pct               0.008847
# 16                                    advanced_ast_pct               0.007293
# 11                                       advanced_pace               0.006306
# 20                      offensive_four_factors_orb_pct               0.006156
# 69                 advanced_ts_pct_by_team_day_of_week               0.006021
# 68                   advanced_3par_by_team_day_of_week               0.005314
# 24                   defensive_four_factors_ft_per_fga               0.004755
# 1                                                  day               0.003571
# 23                      defensive_four_factors_drb_pct               0.003436
# 10                                       advanced_drtg               0.002573
# 7                                      opponent_3p_pct               0.002492
# 21                      defensive_four_factors_efg_pct               0.002473
# 12                                        advanced_ftr               0.002390
# 15                                    advanced_trb_pct               0.002163
# 0                                                month               0.002067
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.002064
# 17                                    advanced_stl_pct               0.002010
# 61                             day_by_team_day_of_week               0.001731
# 6                                      opponent_fg_pct               0.001687
# 72                advanced_stl_pct_by_team_day_of_week               0.001630
# 97            advanced_trb_pct_by_team_travel_distance               0.001616
# 33                                median_score_against               0.001614
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.001518
# 25                                         day_of_week               0.001510
# 30                             team_day_median_allowed               0.001506
# 5                                          team_ft_pct               0.001491
# 79   defensive_four_factors_drb_pct_by_team_day_of_...               0.001390
# 60                           month_by_team_day_of_week               0.001270
# 107  defensive_four_factors_ft_per_fga_by_team_trav...               0.001224
# 71                advanced_ast_pct_by_team_day_of_week               0.001220
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.001218
# 49   offensive_four_factors_ft_per_fga_by_team_home...               0.001183
# 81        team_vs_opp_median_score_by_team_day_of_week               0.001183
# 100           advanced_blk_pct_by_team_travel_distance               0.001170
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.001169
# 98            advanced_ast_pct_by_team_travel_distance               0.001160
# 70                advanced_trb_pct_by_team_day_of_week               0.001078
# 109   team_vs_opp_median_score_by_team_travel_distance               0.000994
# 67                    advanced_ftr_by_team_day_of_week               0.000974
# 93               advanced_pace_by_team_travel_distance               0.000923
# 103  offensive_four_factors_ft_per_fga_by_team_trav...               0.000914
# 106  defensive_four_factors_drb_pct_by_team_travel_...               0.000891
# 31                                     travel_distance               0.000837
# 19                      offensive_four_factors_tov_pct               0.000824
#
#      opp_score_importance
# 9                0.009387
# 27               0.000771
# 14               0.008597
# 13               0.002027
# 4                0.008752
# 26               0.000939
# 8                0.013089
# 16               0.014156
# 11               0.036963
# 20               0.009457
# 69               0.001306
# 68               0.002246
# 24               0.017554
# 1                0.008808
# 23               0.002235
# 10               0.702318
# 7                0.008295
# 21               0.036178
# 12               0.010650
# 15               0.004938
# 0                0.001042
# 77               0.000855
# 17               0.012181
# 61               0.001242
# 6                0.014602
# 72               0.000128
# 97               0.000369
# 33               0.000092
# 105              0.000161
# 25               0.000172
# 30               0.000445
# 5                0.001770
# 79               0.000362
# 60               0.000319
# 107              0.000187
# 71               0.000181
# 80               0.000232
# 49               0.000127
# 81               0.003522
# 100              0.000166
# 78               0.004446
# 98               0.000110
# 70               0.000591
# 109              0.002895
# 67               0.001150
# 93               0.000868
# 103              0.001306
# 106              0.000235
# 31               0.000961
# 19               0.003629

# %%
# show top features by opp_score importance
importances_was.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.002573
# 11                                       advanced_pace               0.006306
# 21                      defensive_four_factors_efg_pct               0.002473
# 24                   defensive_four_factors_ft_per_fga               0.004755
# 6                                      opponent_fg_pct               0.001687
# 16                                    advanced_ast_pct               0.007293
# 8                                      opponent_ft_pct               0.008847
# 17                                    advanced_stl_pct               0.002010
# 12                                        advanced_ftr               0.002390
# 20                      offensive_four_factors_orb_pct               0.006156
# 9                                        advanced_ortg               0.799454
# 1                                                  day               0.003571
# 4                                          team_3p_pct               0.010084
# 14                                     advanced_ts_pct               0.014024
# 22                      defensive_four_factors_tov_pct               0.000783
# 7                                      opponent_3p_pct               0.002492
# 91               advanced_ortg_by_team_travel_distance               0.000350
# 15                                    advanced_trb_pct               0.002163
# 78   defensive_four_factors_tov_pct_by_team_day_of_...               0.001169
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.000500
# 19                      offensive_four_factors_tov_pct               0.000824
# 81        team_vs_opp_median_score_by_team_day_of_week               0.001183
# 66                   advanced_pace_by_team_day_of_week               0.000362
# 109   team_vs_opp_median_score_by_team_travel_distance               0.000994
# 18                                    advanced_blk_pct               0.000494
# 68                   advanced_3par_by_team_day_of_week               0.005314
# 23                      defensive_four_factors_drb_pct               0.003436
# 64                   advanced_ortg_by_team_day_of_week               0.000391
# 13                                       advanced_3par               0.011262
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.000782
# 76   offensive_four_factors_ft_per_fga_by_team_day_...               0.000584
# 44                  advanced_ast_pct_by_team_home_away               0.000105
# 5                                          team_ft_pct               0.001491
# 73                advanced_blk_pct_by_team_day_of_week               0.000295
# 65                   advanced_drtg_by_team_day_of_week               0.000276
# 104  defensive_four_factors_efg_pct_by_team_travel_...               0.000351
# 103  offensive_four_factors_ft_per_fga_by_team_trav...               0.000914
# 69                 advanced_ts_pct_by_team_day_of_week               0.006021
# 61                             day_by_team_day_of_week               0.001731
# 67                    advanced_ftr_by_team_day_of_week               0.000974
# 0                                                month               0.002067
# 31                                     travel_distance               0.000837
# 26                            team_vs_opp_median_score               0.008856
# 85                median_score_for_by_team_day_of_week               0.000392
# 29                               team_day_median_score               0.000046
# 93               advanced_pace_by_team_travel_distance               0.000923
# 32                                    median_score_for               0.000270
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.002064
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.000052
# 27                   team_vs_opp_homeaway_median_score               0.035831
#
#      opp_score_importance
# 10               0.702318
# 11               0.036963
# 21               0.036178
# 24               0.017554
# 6                0.014602
# 16               0.014156
# 8                0.013089
# 17               0.012181
# 12               0.010650
# 20               0.009457
# 9                0.009387
# 1                0.008808
# 4                0.008752
# 14               0.008597
# 22               0.008398
# 7                0.008295
# 91               0.006884
# 15               0.004938
# 78               0.004446
# 75               0.003985
# 19               0.003629
# 81               0.003522
# 66               0.003109
# 109              0.002895
# 18               0.002717
# 68               0.002246
# 23               0.002235
# 64               0.002186
# 13               0.002027
# 82               0.001889
# 76               0.001811
# 44               0.001777
# 5                0.001770
# 73               0.001726
# 65               0.001597
# 104              0.001434
# 103              0.001306
# 69               0.001306
# 61               0.001242
# 67               0.001150
# 0                0.001042
# 31               0.000961
# 26               0.000939
# 85               0.000891
# 29               0.000876
# 93               0.000868
# 32               0.000866
# 77               0.000855
# 74               0.000825
# 27               0.000771

# %%
from google.colab import files
# save feature importances
importances_was.to_csv("was_importances.csv", index=False)
files.download("was_importances.csv")

# %%
# Create LVA data subset
df_lva = df[df['team'] == 'LVA'].copy()

# define features and target
features_lva = df_lva.drop(columns=['team_score', 'opp_score', 'team', 'opp'], errors='ignore')
targets_lva = df_lva[['team_score', 'opp_score']]

# Train model
X_train, X_test, y_train, y_test = train_test_split(features_lva, targets_lva, test_size=0.2, random_state=42)

model_lva = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model_lva.fit(X_train, y_train)

importances_lva = pd.DataFrame({
    'feature': features_lva.columns,
    'team_score_importance': model_lva.estimators_[0].feature_importances_,
    'opp_score_importance': model_lva.estimators_[1].feature_importances_,
}).sort_values(by='team_score_importance', ascending=False)

# %%
# show top features by team_score importance
importances_lva.sort_values(by='team_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 9                                        advanced_ortg               0.512396
# 14                                     advanced_ts_pct               0.264178
# 27                   team_vs_opp_homeaway_median_score               0.093995
# 26                            team_vs_opp_median_score               0.027050
# 15                                    advanced_trb_pct               0.005291
# 19                      offensive_four_factors_tov_pct               0.004751
# 18                                    advanced_blk_pct               0.004740
# 75   offensive_four_factors_orb_pct_by_team_day_of_...               0.004535
# 13                                       advanced_3par               0.004345
# 11                                       advanced_pace               0.003985
# 7                                      opponent_3p_pct               0.003910
# 12                                        advanced_ftr               0.003710
# 23                      defensive_four_factors_drb_pct               0.003216
# 1                                                  day               0.002813
# 61                             day_by_team_day_of_week               0.002751
# 17                                    advanced_stl_pct               0.002651
# 8                                      opponent_ft_pct               0.002651
# 71                advanced_ast_pct_by_team_day_of_week               0.002509
# 20                      offensive_four_factors_orb_pct               0.002236
# 21                      defensive_four_factors_efg_pct               0.002213
# 81        team_vs_opp_median_score_by_team_day_of_week               0.002045
# 51    defensive_four_factors_tov_pct_by_team_home_away               0.001937
# 66                   advanced_pace_by_team_day_of_week               0.001728
# 59              median_score_against_by_team_home_away               0.001723
# 22                      defensive_four_factors_tov_pct               0.001722
# 46                  advanced_blk_pct_by_team_home_away               0.001621
# 5                                          team_ft_pct               0.001559
# 60                           month_by_team_day_of_week               0.001448
# 10                                       advanced_drtg               0.001431
# 16                                    advanced_ast_pct               0.001376
# 92               advanced_drtg_by_team_travel_distance               0.001344
# 47    offensive_four_factors_tov_pct_by_team_home_away               0.001187
# 53   defensive_four_factors_ft_per_fga_by_team_home...               0.001151
# 35                               day_by_team_home_away               0.001090
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.001079
# 49   offensive_four_factors_ft_per_fga_by_team_home...               0.001005
# 33                                median_score_against               0.000970
# 3                                             win_loss               0.000930
# 24                   defensive_four_factors_ft_per_fga               0.000925
# 4                                          team_3p_pct               0.000886
# 6                                      opponent_fg_pct               0.000839
# 0                                                month               0.000808
# 95               advanced_3par_by_team_travel_distance               0.000791
# 38                     advanced_drtg_by_team_home_away               0.000777
# 52    defensive_four_factors_drb_pct_by_team_home_away               0.000709
# 93               advanced_pace_by_team_travel_distance               0.000664
# 41                     advanced_3par_by_team_home_away               0.000654
# 45                  advanced_stl_pct_by_team_home_away               0.000629
# 44                  advanced_ast_pct_by_team_home_away               0.000595
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.000570
#
#      opp_score_importance
# 9                0.005935
# 14               0.002102
# 27               0.005149
# 26               0.004712
# 15               0.003077
# 19               0.001430
# 18               0.000985
# 75               0.000342
# 13               0.003158
# 11               0.006585
# 7                0.002553
# 12               0.001043
# 23               0.001403
# 1                0.002751
# 61               0.002009
# 17               0.003342
# 8                0.009053
# 71               0.000473
# 20               0.002824
# 21               0.028570
# 81               0.000668
# 51               0.000003
# 66               0.001128
# 59               0.000003
# 22               0.006335
# 46               0.000048
# 5                0.004903
# 60               0.015393
# 10               0.822671
# 16               0.001584
# 92               0.000092
# 47               0.000008
# 53               0.000114
# 35               0.000031
# 105              0.000415
# 49               0.000000
# 33               0.000452
# 3                0.000402
# 24               0.001183
# 4                0.008292
# 6                0.018685
# 0                0.006878
# 95               0.000051
# 38               0.000019
# 52               0.000014
# 93               0.000040
# 41               0.000038
# 45               0.000074
# 44               0.000059
# 77               0.000944

# %%
# show top features by opp_score importance
importances_lva.sort_values(by='opp_score_importance', ascending=False).head(50)
# Out:
#                                                feature  team_score_importance  \
# 10                                       advanced_drtg               0.001431
# 21                      defensive_four_factors_efg_pct               0.002213
# 6                                      opponent_fg_pct               0.000839
# 60                           month_by_team_day_of_week               0.001448
# 8                                      opponent_ft_pct               0.002651
# 4                                          team_3p_pct               0.000886
# 0                                                month               0.000808
# 11                                       advanced_pace               0.003985
# 22                      defensive_four_factors_tov_pct               0.001722
# 9                                        advanced_ortg               0.512396
# 27                   team_vs_opp_homeaway_median_score               0.093995
# 5                                          team_ft_pct               0.001559
# 26                            team_vs_opp_median_score               0.027050
# 17                                    advanced_stl_pct               0.002651
# 13                                       advanced_3par               0.004345
# 15                                    advanced_trb_pct               0.005291
# 20                      offensive_four_factors_orb_pct               0.002236
# 1                                                  day               0.002813
# 7                                      opponent_3p_pct               0.003910
# 68                   advanced_3par_by_team_day_of_week               0.000462
# 80   defensive_four_factors_ft_per_fga_by_team_day_...               0.000166
# 14                                     advanced_ts_pct               0.264178
# 61                             day_by_team_day_of_week               0.002751
# 72                advanced_stl_pct_by_team_day_of_week               0.000142
# 16                                    advanced_ast_pct               0.001376
# 82   team_vs_opp_homeaway_median_score_by_team_day_...               0.000024
# 19                      offensive_four_factors_tov_pct               0.004751
# 73                advanced_blk_pct_by_team_day_of_week               0.000081
# 23                      defensive_four_factors_drb_pct               0.003216
# 74   offensive_four_factors_tov_pct_by_team_day_of_...               0.000036
# 24                   defensive_four_factors_ft_per_fga               0.000925
# 66                   advanced_pace_by_team_day_of_week               0.001728
# 12                                        advanced_ftr               0.003710
# 97            advanced_trb_pct_by_team_travel_distance               0.000180
# 30                             team_day_median_allowed               0.000129
# 18                                    advanced_blk_pct               0.004740
# 77   defensive_four_factors_efg_pct_by_team_day_of_...               0.000570
# 81        team_vs_opp_median_score_by_team_day_of_week               0.002045
# 31                                     travel_distance               0.000142
# 86            median_score_against_by_team_day_of_week               0.000299
# 69                 advanced_ts_pct_by_team_day_of_week               0.000238
# 67                    advanced_ftr_by_team_day_of_week               0.000173
# 71                advanced_ast_pct_by_team_day_of_week               0.002509
# 33                                median_score_against               0.000970
# 89                   home_away_by_team_travel_distance               0.000154
# 100           advanced_blk_pct_by_team_travel_distance               0.000168
# 29                               team_day_median_score               0.000037
# 99            advanced_stl_pct_by_team_travel_distance               0.000171
# 105  defensive_four_factors_tov_pct_by_team_travel_...               0.001079
# 3                                             win_loss               0.000930
#
#      opp_score_importance
# 10               0.822671
# 21               0.028570
# 6                0.018685
# 60               0.015393
# 8                0.009053
# 4                0.008292
# 0                0.006878
# 11               0.006585
# 22               0.006335
# 9                0.005935
# 27               0.005149
# 5                0.004903
# 26               0.004712
# 17               0.003342
# 13               0.003158
# 15               0.003077
# 20               0.002824
# 1                0.002751
# 7                0.002553
# 68               0.002407
# 80               0.002396
# 14               0.002102
# 61               0.002009
# 72               0.001872
# 16               0.001584
# 82               0.001552
# 19               0.001430
# 73               0.001425
# 23               0.001403
# 74               0.001292
# 24               0.001183
# 66               0.001128
# 12               0.001043
# 97               0.000995
# 30               0.000992
# 18               0.000985
# 77               0.000944
# 81               0.000668
# 31               0.000631
# 86               0.000548
# 69               0.000532
# 67               0.000521
# 71               0.000473
# 33               0.000452
# 89               0.000446
# 100              0.000445
# 29               0.000439
# 99               0.000423
# 105              0.000415
# 3                0.000402

# %%
from google.colab import files
# save feature importances
importances_lva.to_csv("lva_importances.csv", index=False)
files.download("lva_importances.csv")

# %%
# list of team abbreviations in alphabetical order
teams = ['ATL', 'CHI', 'CON', 'DAL', 'IND', 'LAS', 'LVA', 'MIN', 'NYL', 'PHO', 'SEA', 'WAS']

# load and tag each importance CSV
dfs = []
for team in teams:
    df_team = pd.read_csv(f"{team.lower()}_importances.csv")
    df_team['team'] = team
    dfs.append(df_team)

# vertically merge into one long DataFrame
all_importances = pd.concat(dfs, ignore_index=True)

# %%
print(all_importances)
# Out:
#                                               feature  team_score_importance  \
# 0                                     advanced_ts_pct               0.450337
# 1                                       advanced_ortg               0.251102
# 2                      offensive_four_factors_tov_pct               0.053520
# 3                                    advanced_ast_pct               0.018078
# 4                      offensive_four_factors_orb_pct               0.017525
# ...                                               ...                    ...
# 1363                       win_loss_by_team_home_away               0.000000
# 1364          team_day_median_score_by_team_home_away               0.000000
# 1365                 win_loss_by_team_travel_distance               0.000000
# 1366    team_day_median_score_by_team_travel_distance               0.000000
# 1367  team_day_median_allowed_by_team_travel_distance               0.000000
#
#       opp_score_importance team
# 0                 0.004531  ATL
# 1                 0.012536  ATL
# 2                 0.020985  ATL
# 3                 0.007542  ATL
# 4                 0.011316  ATL
# ...                    ...  ...
# 1363              0.000000  WAS
# 1364              0.000000  WAS
# 1365              0.000011  WAS
# 1366              0.000000  WAS
# 1367              0.000000  WAS
#
# [1368 rows x 4 columns]

# %%
# filter where either importance meets threshold
threshold = 0.005
filtered = all_importances[
    (all_importances['team_score_importance'] >= threshold) |
    (all_importances['opp_score_importance'] >= threshold)
]

# separate counts for each type
team_score_counts = (
    filtered[filtered['team_score_importance'] >= threshold]
    .groupby('team')['feature']
    .nunique()
    .reset_index(name='team_score_count')
)

opp_score_counts = (
    filtered[filtered['opp_score_importance'] >= threshold]
    .groupby('team')['feature']
    .nunique()
    .reset_index(name='opp_score_count')
)

# merge the two counts together
team_feature_counts = pd.merge(team_score_counts, opp_score_counts, on='team', how='outer').fillna(0)
team_feature_counts[['team_score_count', 'opp_score_count']] = team_feature_counts[['team_score_count', 'opp_score_count']].astype(int)

display(team_feature_counts)
# Out:
#    team  team_score_count  opp_score_count
# 0   ATL                18               20
# 1   CHI                16               14
# 2   CON                16               19
# 3   DAL                13               18
# 4   IND                14               18
# 5   LAS                12               17
# 6   LVA                 5               11
# 7   MIN                19               23
# 8   NYL                10               13
# 9   PHO                19               18
# 10  SEA                21               20
# 11  WAS                12               17

# %%
# count how many teams each feature appears in at or above threshold
team_score_feature_counts = (
    filtered[filtered['team_score_importance'] >= threshold]
    .groupby('feature')['team']
    .nunique()
    .reset_index(name='team_score_team_count')
)

opp_score_feature_counts = (
    filtered[filtered['opp_score_importance'] >= threshold]
    .groupby('feature')['team']
    .nunique()
    .reset_index(name='opp_score_team_count')
)

# merge both counts into one view
feature_team_counts = pd.merge(team_score_feature_counts, opp_score_feature_counts, on='feature', how='outer').fillna(0)
feature_team_counts[['team_score_team_count', 'opp_score_team_count']] = feature_team_counts[['team_score_team_count', 'opp_score_team_count']].astype(int)

display(feature_team_counts.sort_values(by='team_score_team_count', ascending=False))
# Out:
#                                               feature  team_score_team_count  \
# 7                                       advanced_ortg                     12
# 14                                    advanced_ts_pct                     12
# 38                  team_vs_opp_homeaway_median_score                     12
# 29                     offensive_four_factors_tov_pct                     10
# 34                                        team_3p_pct                     10
# 10                                      advanced_pace                      9
# 13                                   advanced_trb_pct                      9
# 40                           team_vs_opp_median_score                      9
# 4                                       advanced_drtg                      6
# 27                     offensive_four_factors_orb_pct                      6
# 0                                       advanced_3par                      6
# 6                                        advanced_ftr                      6
# 31                                    opponent_3p_pct                      6
# 20                     defensive_four_factors_efg_pct                      5
# 33                                    opponent_ft_pct                      5
# 19                     defensive_four_factors_drb_pct                      5
# 3                                    advanced_blk_pct                      5
# 12                                   advanced_stl_pct                      5
# 21                  defensive_four_factors_ft_per_fga                      4
# 2                                    advanced_ast_pct                      4
# 16                                                day                      4
# 23                     defensive_four_factors_tov_pct                      4
# 37                                        team_ft_pct                      3
# 24                                              month                      3
# 32                                    opponent_fg_pct                      3
# 43                                           win_loss                      3
# 35                            team_day_median_allowed                      2
# 36                              team_day_median_score                      2
# 15                advanced_ts_pct_by_team_day_of_week                      2
# 1                   advanced_3par_by_team_day_of_week                      1
# 17                            day_by_team_day_of_week                      1
# 22  defensive_four_factors_ft_per_fga_by_team_day_...                      1
# 11                  advanced_pace_by_team_day_of_week                      0
# 9               advanced_ortg_by_team_travel_distance                      0
# 8                   advanced_ortg_by_team_day_of_week                      0
# 5                   advanced_drtg_by_team_day_of_week                      0
# 26  offensive_four_factors_ft_per_fga_by_team_day_...                      0
# 25                          month_by_team_day_of_week                      0
# 18                                        day_of_week                      0
# 30  offensive_four_factors_tov_pct_by_team_day_of_...                      0
# 28  offensive_four_factors_orb_pct_by_team_day_of_...                      0
# 39  team_vs_opp_homeaway_median_score_by_team_day_...                      0
# 41       team_vs_opp_median_score_by_team_day_of_week                      0
# 42                travel_distance_by_team_day_of_week                      0
#
#     opp_score_team_count
# 7                      9
# 14                     5
# 38                     7
# 29                     7
# 34                     7
# 10                    10
# 13                     6
# 40                     4
# 4                     12
# 27                     7
# 0                      6
# 6                      9
# 31                     7
# 20                    12
# 33                     8
# 19                     4
# 3                      6
# 12                     6
# 21                    10
# 2                      9
# 16                     9
# 23                     9
# 37                     4
# 24                     4
# 32                    12
# 43                     2
# 35                     1
# 36                     0
# 15                     1
# 1                      1
# 17                     0
# 22                     0
# 11                     1
# 9                      1
# 8                      1
# 5                      1
# 26                     2
# 25                     1
# 18                     1
# 30                     1
# 28                     2
# 39                     1
# 41                     1
# 42                     1

# %%
feature_team_counts.shape[0]
# Out:
# 44

# %%
# get max importance values for your final features
feature_importance_summary = (
    all_importances[all_importances['feature'].isin(feature_team_counts['feature'])]
    .groupby('feature')[['team_score_importance', 'opp_score_importance']]
    .max()
    .reset_index()
    .sort_values(by='team_score_importance', ascending=False)
)

display(feature_importance_summary)
# Out:
#                                               feature  team_score_importance  \
# 7                                       advanced_ortg               0.799454
# 14                                    advanced_ts_pct               0.470444
# 38                  team_vs_opp_homeaway_median_score               0.274837
# 10                                      advanced_pace               0.093623
# 37                                        team_ft_pct               0.062982
# 43                                           win_loss               0.062581
# 29                     offensive_four_factors_tov_pct               0.053520
# 34                                        team_3p_pct               0.042120
# 40                           team_vs_opp_median_score               0.040816
# 21                  defensive_four_factors_ft_per_fga               0.034729
# 19                     defensive_four_factors_drb_pct               0.028225
# 31                                    opponent_3p_pct               0.026923
# 20                     defensive_four_factors_efg_pct               0.026688
# 32                                    opponent_fg_pct               0.025944
# 6                                        advanced_ftr               0.019920
# 2                                    advanced_ast_pct               0.018078
# 27                     offensive_four_factors_orb_pct               0.017525
# 13                                   advanced_trb_pct               0.017154
# 23                     defensive_four_factors_tov_pct               0.017074
# 16                                                day               0.016163
# 4                                       advanced_drtg               0.014405
# 33                                    opponent_ft_pct               0.012878
# 24                                              month               0.012406
# 0                                       advanced_3par               0.011331
# 12                                   advanced_stl_pct               0.010647
# 35                            team_day_median_allowed               0.009998
# 3                                    advanced_blk_pct               0.008388
# 15                advanced_ts_pct_by_team_day_of_week               0.007503
# 36                              team_day_median_score               0.006966
# 17                            day_by_team_day_of_week               0.005779
# 22  defensive_four_factors_ft_per_fga_by_team_day_...               0.005647
# 1                   advanced_3par_by_team_day_of_week               0.005314
# 5                   advanced_drtg_by_team_day_of_week               0.004855
# 9               advanced_ortg_by_team_travel_distance               0.004669
# 39  team_vs_opp_homeaway_median_score_by_team_day_...               0.004628
# 8                   advanced_ortg_by_team_day_of_week               0.004594
# 28  offensive_four_factors_orb_pct_by_team_day_of_...               0.004535
# 26  offensive_four_factors_ft_per_fga_by_team_day_...               0.004475
# 18                                        day_of_week               0.002906
# 30  offensive_four_factors_tov_pct_by_team_day_of_...               0.002290
# 11                  advanced_pace_by_team_day_of_week               0.002089
# 41       team_vs_opp_median_score_by_team_day_of_week               0.002045
# 25                          month_by_team_day_of_week               0.001833
# 42                travel_distance_by_team_day_of_week               0.001719
#
#     opp_score_importance
# 7               0.040604
# 14              0.026025
# 38              0.015486
# 10              0.054595
# 37              0.009705
# 43              0.023821
# 29              0.031164
# 34              0.011997
# 40              0.011577
# 21              0.050494
# 19              0.006123
# 31              0.052607
# 20              0.134012
# 32              0.520782
# 6               0.036434
# 2               0.037709
# 27              0.011316
# 13              0.031030
# 23              0.038331
# 16              0.032701
# 4               0.822671
# 33              0.014759
# 24              0.026202
# 0               0.021483
# 12              0.033740
# 35              0.011327
# 3               0.010553
# 15              0.005811
# 36              0.002372
# 17              0.002131
# 22              0.004597
# 1               0.005774
# 5               0.007551
# 9               0.006884
# 39              0.007266
# 8               0.009194
# 28              0.006950
# 26              0.005116
# 18              0.005149
# 30              0.008950
# 11              0.014053
# 41              0.005298
# 25              0.015393
# 42              0.009043

# %%
features_to_check = [
    'advanced_ts_pct_by_team_day_of_week',
    'team_day_median_score',
    'day_by_team_day_of_week',
    'defensive_four_factors_ft_per_fga_by_team_day_of_week',
    'advanced_3par_by_team_day_of_week',
    'advanced_drtg_by_team_day_of_week',
    'advanced_ortg_by_team_travel_distance',
    'team_vs_opp_homeaway_median_score_by_team_day_of_week',
    'advanced_ortg_by_team_day_of_week',
    'offensive_four_factors_orb_pct_by_team_day_of_week',
    'offensive_four_factors_ft_per_fga_by_team_day_of_week',
    'day_of_week',
    'offensive_four_factors_tov_pct_by_team_day_of_week',
    'advanced_pace_by_team_day_of_week',
    'team_vs_opp_median_score_by_team_day_of_week',
    'month_by_team_day_of_week',
    'travel_distance_by_team_day_of_week'
]

# %%
# Compute max importance for the features you're checking
importance_check = (
    all_importances[all_importances['feature'].isin(features_to_check)]
    .groupby('feature')[['team_score_importance', 'opp_score_importance']]
    .max()
    .reset_index()
)

# Isolate features to drop (both importances < 0.01)
drop_list = importance_check[
    (importance_check['team_score_importance'] < 0.01) &
    (importance_check['opp_score_importance'] < 0.01)
]['feature'].tolist()

# Drop them from feature_team_counts
feature_team_counts = feature_team_counts[
    ~feature_team_counts['feature'].isin(drop_list)
].reset_index(drop=True)

# %%
feature_team_counts['feature'].tolist()
# Out:
# ['advanced_3par',
#  'advanced_ast_pct',
#  'advanced_blk_pct',
#  'advanced_drtg',
#  'advanced_ftr',
#  'advanced_ortg',
#  'advanced_pace',
#  'advanced_pace_by_team_day_of_week',
#  'advanced_stl_pct',
#  'advanced_trb_pct',
#  'advanced_ts_pct',
#  'day',
#  'defensive_four_factors_drb_pct',
#  'defensive_four_factors_efg_pct',
#  'defensive_four_factors_ft_per_fga',
#  'defensive_four_factors_tov_pct',
#  'month',
#  'month_by_team_day_of_week',
#  'offensive_four_factors_orb_pct',
#  'offensive_four_factors_tov_pct',
#  'opponent_3p_pct',
#  'opponent_fg_pct',
#  'opponent_ft_pct',
#  'team_3p_pct',
#  'team_day_median_allowed',
#  'team_ft_pct',
#  'team_vs_opp_homeaway_median_score',
#  'team_vs_opp_median_score',
#  'win_loss']

# %%
# final feature list
model_features = feature_team_counts['feature'].tolist()

# columns needed for modeling
columns_to_keep = model_features + ['team', 'opp', 'team_score', 'opp_score']

# create the modeling-ready DataFrame
df_final = df[columns_to_keep].copy()

# %%
df_final.shape
# Out:
# (480, 33)

# %%
from google.colab import files

# re-save with final feature set
df_final.to_csv("wnba_model_ready_v2.csv", index=False)
files.download("wnba_model_ready_v2.csv")

# %%
from google.colab import files

# re-save with final feature set
df.to_csv("wnba_model_ready_v1.csv", index=False)
files.download("wnba_model_ready_v1.csv")
